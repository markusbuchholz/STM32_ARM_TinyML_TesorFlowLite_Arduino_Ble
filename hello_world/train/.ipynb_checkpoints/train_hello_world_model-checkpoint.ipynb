# %% [markdown]
# # Train a basic TensorFlow Lite for Microcontrollers model
#
# This notebook demonstrates the process of training a 2.5 kB model using TensorFlow and converting it for use with TensorFlow Lite for Microcontrollers.
#
# Deep learning networks learn to model patterns in underlying data. Here, we're going to train a network to model data generated by a [sine](https://en.wikipedia.org/wiki/Sine) function. This will result in a model that can take a value, `x`, and predict its sine, `y`.
#
# The model created in this notebook is used in the [hello_world](https://github.com/tensorflow/tensorflow/tree/master/tensorflow/lite/micro/examples/hello_world) example for [TensorFlow Lite for MicroControllers](https://www.tensorflow.org/lite/microcontrollers/overview).
#
# <table class="tfo-notebook-buttons" align="left">
#   <td>
#     <a target="_blank" href="https://colab.research.google.com/github/tensorflow/tensorflow/blob/master/tensorflow/lite/micro/examples/hello_world/train/train_hello_world_model.ipynb"><img src="https://www.tensorflow.org/images/colab_logo_32px.png" />Run in Google Colab</a>
#   </td>
#   <td>
#     <a target="_blank" href="https://github.com/tensorflow/tensorflow/blob/master/tensorflow/lite/micro/examples/hello_world/train/train_hello_world_model.ipynb"><img src="https://www.tensorflow.org/images/GitHub-Mark-32px.png" />View source on GitHub</a>
#   </td>
# </table>

# %% [markdown]
# **Training is much faster using GPU acceleration.** Before you proceed, ensure you are using a GPU runtime by going to **Runtime -> Change runtime type** and set **Hardware accelerator: GPU**.

# %% [markdown]
# ## Configure Defaults

# %%
# Define paths to model files
import os
import tensorflow as tf
MODELS_DIR = 'models/'
if not os.path.exists(MODELS_DIR):
    os.mkdir(MODELS_DIR)
MODEL_TF = MODELS_DIR + 'model.pb'
MODEL_NO_QUANT_TFLITE = MODELS_DIR + 'model_no_quant.tflite'
MODEL_TFLITE = MODELS_DIR + 'model.tflite'
MODEL_TFLITE_MICRO = MODELS_DIR + 'model.cc'

# %% [markdown]
# ## Setup Environment
#
# Install Dependencies

# %%
#! pip install -q tensorflow==2

# %% [markdown]
# Set Seed for Repeatable Results

# %%
# Set a "seed" value, so we get the same random numbers each time we run this
# notebook for reproducible results.
# Numpy is a math library
import numpy as np
np.random.seed(1) # numpy seed
# TensorFlow is an open source machine learning library
#import tensorflow as tf
#tf.random.set_seed(1) # tensorflow global random seed

# %% [markdown]
# Import Dependencies

# %%
# Keras is TensorFlow's high-level API for deep learning
from tensorflow import keras
# Matplotlib is a graphing library
import matplotlib.pyplot as plt
# Math is Python's math library
import math

# %% [markdown]
# ## Dataset

# %% [markdown]
# ### 1. Generate Data
#
# The code in the following cell will generate a set of random `x` values, calculate their sine values, and display them on a graph.

# %%
# Number of sample datapoints
SAMPLES = 1000

# Generate a uniformly distributed set of random numbers in the range from
# 0 to 2π, which covers a complete sine wave oscillation
x_values = np.random.uniform(
    low=0, high=2*math.pi, size=SAMPLES).astype(np.float32)

# Shuffle the values to guarantee they're not in order
np.random.shuffle(x_values)

# Calculate the corresponding sine values
y_values = np.sin(x_values).astype(np.float32)

# Plot our data. The 'b.' argument tells the library to print blue dots.
plt.plot(x_values, y_values, 'b.')
plt.show()

# %% [markdown]
# ### 2. Add Noise
# Since it was generated directly by the sine function, our data fits a nice, smooth curve.
#
# However, machine learning models are good at extracting underlying meaning from messy, real world data. To demonstrate this, we can add some noise to our data to approximate something more life-like.
#
# In the following cell, we'll add some random noise to each value, then draw a new graph:

# %%
# Add a small random number to each y value
y_values += 0.1 * np.random.randn(*y_values.shape)

# Plot our data
plt.plot(x_values, y_values, 'b.')
plt.show()

# %% [markdown]
# ### 3. Split the Data
# We now have a noisy dataset that approximates real world data. We'll be using this to train our model.
#
# To evaluate the accuracy of the model we train, we'll need to compare its predictions to real data and check how well they match up. This evaluation happens during training (where it is referred to as validation) and after training (referred to as testing) It's important in both cases that we use fresh data that was not already used to train the model.
#
# The data is split as follows:
#   1. Training: 60%
#   2. Validation: 20%
#   3. Testing: 20%
#
# The following code will split our data and then plots each set as a different color:

# %%
# We'll use 60% of our data for training and 20% for testing. The remaining 20%
# will be used for validation. Calculate the indices of each section.
TRAIN_SPLIT =  int(0.6 * SAMPLES)
TEST_SPLIT = int(0.2 * SAMPLES + TRAIN_SPLIT)

# Use np.split to chop our data into three parts.
# The second argument to np.split is an array of indices where the data will be
# split. We provide two indices, so the data will be divided into three chunks.
x_train, x_test, x_validate = np.split(x_values, [TRAIN_SPLIT, TEST_SPLIT])
y_train, y_test, y_validate = np.split(y_values, [TRAIN_SPLIT, TEST_SPLIT])

# Double check that our splits add up correctly
assert (x_train.size + x_validate.size + x_test.size) ==  SAMPLES

# Plot the data in each partition in different colors:
plt.plot(x_train, y_train, 'b.', label="Train")
plt.plot(x_test, y_test, 'r.', label="Test")
plt.plot(x_validate, y_validate, 'y.', label="Validate")
plt.legend()
plt.show()

# %% [markdown]
# ## Training

# %% [markdown]
# ### 1. Design the Model
# We're going to build a simple neural network model that will take an input value (in this case, `x`) and use it to predict a numeric output value (the sine of `x`). This type of problem is called a _regression_. It will use _layers_ of _neurons_ to attempt to learn any patterns underlying the training data, so it can make predictions.
#
# To begin with, we'll define two layers. The first layer takes a single input (our `x` value) and runs it through 8 neurons. Based on this input, each neuron will become _activated_ to a certain degree based on its internal state (its _weight_ and _bias_ values). A neuron's degree of activation is expressed as a number.
#
# The activation numbers from our first layer will be fed as inputs to our second layer, which is a single neuron. It will apply its own weights and bias to these inputs and calculate its own activation, which will be output as our `y` value.
#
# **Note:** To learn more about how neural networks function, you can explore the [Learn TensorFlow](https://codelabs.developers.google.com/codelabs/tensorflow-lab1-helloworld) codelabs.
#
# The code in the following cell defines our model using [Keras](https://www.tensorflow.org/guide/keras), TensorFlow's high-level API for creating deep learning networks. Once the network is defined, we _compile_ it, specifying parameters that determine how it will be trained:

# %%
# We'll use Keras to create a simple model architecture
model_1 = tf.keras.Sequential()

# First layer takes a scalar input and feeds it through 8 "neurons". The
# neurons decide whether to activate based on the 'relu' activation function.
model_1.add(keras.layers.Dense(8, activation='relu', input_shape=(1,)))

# Final layer is a single neuron, since we want to output a single value
model_1.add(keras.layers.Dense(1))

# Compile the model using a standard optimizer and loss function for regression
model_1.compile(optimizer='adam', loss='mse', metrics=['mae'])
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0712 11:48:26.879073 139734278874944 deprecation.py:506] From /home/markus/.local/lib/python3.6/site-packages/tensorflow_core/python/ops/resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.

# %% [markdown]
# ### 2. Train the Model
# Once we've defined the model, we can use our data to _train_ it. Training involves passing an `x` value into the neural network, checking how far the network's output deviates from the expected `y` value, and adjusting the neurons' weights and biases so that the output is more likely to be correct the next time.
#
# Training runs this process on the full dataset multiple times, and each full run-through is known as an _epoch_. The number of epochs to run during training is a parameter we can set.
#
# During each epoch, data is run through the network in multiple _batches_. Each batch, several pieces of data are passed into the network, producing output values. These outputs' correctness is measured in aggregate and the network's weights and biases are adjusted accordingly, once per batch. The _batch size_ is also a parameter we can set.
#
# The code in the following cell uses the `x` and `y` values from our training data to train the model. It runs for 500 _epochs_, with 64 pieces of data in each _batch_. We also pass in some data for _validation_. As you will see when you run the cell, training can take a while to complete:

# %%
# Train the model on our training data while validating on our validation set
history_1 = model_1.fit(x_train, y_train, epochs=500, batch_size=64,
                    validation_data=(x_validate, y_validate))
# Out:
# Train on 600 samples, validate on 200 samples
# Epoch 1/500
# 600/600 [==============================] - 1s 963us/sample - loss: 0.4329 - mean_absolute_error: 0.5439 - val_loss: 0.4326 - val_mean_absolute_error: 0.5639
# Epoch 2/500
# 600/600 [==============================] - 0s 32us/sample - loss: 0.4099 - mean_absolute_error: 0.5446 - val_loss: 0.4235 - val_mean_absolute_error: 0.5628
# Epoch 3/500
# 600/600 [==============================] - 0s 24us/sample - loss: 0.4010 - mean_absolute_error: 0.5441 - val_loss: 0.4137 - val_mean_absolute_error: 0.5566
# Epoch 4/500
# 600/600 [==============================] - 0s 29us/sample - loss: 0.3913 - mean_absolute_error: 0.5373 - val_loss: 0.4037 - val_mean_absolute_error: 0.5503
# Epoch 5/500
# 600/600 [==============================] - 0s 22us/sample - loss: 0.3812 - mean_absolute_error: 0.5276 - val_loss: 0.3927 - val_mean_absolute_error: 0.5412
# Epoch 6/500
# 600/600 [==============================] - 0s 26us/sample - loss: 0.3715 - mean_absolute_error: 0.5182 - val_loss: 0.3827 - val_mean_absolute_error: 0.5342
# Epoch 7/500
# 600/600 [==============================] - 0s 25us/sample - loss: 0.3621 - mean_absolute_error: 0.5118 - val_loss: 0.3736 - val_mean_absolute_error: 0.5288
# Epoch 8/500
# 600/600 [==============================] - 0s 26us/sample - loss: 0.3530 - mean_absolute_error: 0.5059 - val_loss: 0.3643 - val_mean_absolute_error: 0.5224
# Epoch 9/500
# 600/600 [==============================] - 0s 26us/sample - loss: 0.3443 - mean_absolute_error: 0.4991 - val_loss: 0.3554 - val_mean_absolute_error: 0.5165
# Epoch 10/500
# 600/600 [==============================] - 0s 28us/sample - loss: 0.3358 - mean_absolute_error: 0.4921 - val_loss: 0.3465 - val_mean_absolute_error: 0.5097
# Epoch 11/500
# 600/600 [==============================] - 0s 25us/sample - loss: 0.3276 - mean_absolute_error: 0.4856 - val_loss: 0.3382 - val_mean_absolute_error: 0.5046
# Epoch 12/500
# 600/600 [==============================] - 0s 29us/sample - loss: 0.3194 - mean_absolute_error: 0.4799 - val_loss: 0.3303 - val_mean_absolute_error: 0.4993
# Epoch 13/500
# 600/600 [==============================] - 0s 21us/sample - loss: 0.3121 - mean_absolute_error: 0.4736 - val_loss: 0.3226 - val_mean_absolute_error: 0.4933
# Epoch 14/500
# 600/600 [==============================] - 0s 31us/sample - loss: 0.3044 - mean_absolute_error: 0.4691 - val_loss: 0.3157 - val_mean_absolute_error: 0.4901
# Epoch 15/500
# 600/600 [==============================] - 0s 23us/sample - loss: 0.2975 - mean_absolute_error: 0.4650 - val_loss: 0.3088 - val_mean_absolute_error: 0.4855
# Epoch 16/500
# 600/600 [==============================] - 0s 32us/sample - loss: 0.2910 - mean_absolute_error: 0.4608 - val_loss: 0.3017 - val_mean_absolute_error: 0.4807
# Epoch 17/500
# 600/600 [==============================] - 0s 22us/sample - loss: 0.2840 - mean_absolute_error: 0.4549 - val_loss: 0.2947 - val_mean_absolute_error: 0.4751
# Epoch 18/500
# 600/600 [==============================] - 0s 32us/sample - loss: 0.2776 - mean_absolute_error: 0.4495 - val_loss: 0.2883 - val_mean_absolute_error: 0.4703
# Epoch 19/500
# 600/600 [==============================] - 0s 23us/sample - loss: 0.2726 - mean_absolute_error: 0.4446 - val_loss: 0.2820 - val_mean_absolute_error: 0.4641
# Epoch 20/500
# 600/600 [==============================] - 0s 34us/sample - loss: 0.2655 - mean_absolute_error: 0.4397 - val_loss: 0.2764 - val_mean_absolute_error: 0.4618
# Epoch 21/500
# 600/600 [==============================] - 0s 20us/sample - loss: 0.2601 - mean_absolute_error: 0.4370 - val_loss: 0.2712 - val_mean_absolute_error: 0.4585
# Epoch 22/500
# 600/600 [==============================] - 0s 31us/sample - loss: 0.2548 - mean_absolute_error: 0.4331 - val_loss: 0.2656 - val_mean_absolute_error: 0.4537
# Epoch 23/500
# 600/600 [==============================] - 0s 21us/sample - loss: 0.2493 - mean_absolute_error: 0.4282 - val_loss: 0.2600 - val_mean_absolute_error: 0.4476
# Epoch 24/500
# 600/600 [==============================] - 0s 30us/sample - loss: 0.2464 - mean_absolute_error: 0.4248 - val_loss: 0.2553 - val_mean_absolute_error: 0.4427
# Epoch 25/500
# 600/600 [==============================] - 0s 23us/sample - loss: 0.2399 - mean_absolute_error: 0.4204 - val_loss: 0.2507 - val_mean_absolute_error: 0.4411
# Epoch 26/500
# 600/600 [==============================] - 0s 27us/sample - loss: 0.2357 - mean_absolute_error: 0.4181 - val_loss: 0.2467 - val_mean_absolute_error: 0.4385
# Epoch 27/500
# 600/600 [==============================] - 0s 22us/sample - loss: 0.2321 - mean_absolute_error: 0.4159 - val_loss: 0.2429 - val_mean_absolute_error: 0.4360
# Epoch 28/500
# 600/600 [==============================] - 0s 27us/sample - loss: 0.2280 - mean_absolute_error: 0.4123 - val_loss: 0.2376 - val_mean_absolute_error: 0.4296
# Epoch 29/500
# 600/600 [==============================] - 0s 21us/sample - loss: 0.2235 - mean_absolute_error: 0.4086 - val_loss: 0.2339 - val_mean_absolute_error: 0.4270
# Epoch 30/500
# 600/600 [==============================] - 0s 33us/sample - loss: 0.2199 - mean_absolute_error: 0.4060 - val_loss: 0.2302 - val_mean_absolute_error: 0.4240
# Epoch 31/500
# 600/600 [==============================] - 0s 30us/sample - loss: 0.2169 - mean_absolute_error: 0.4031 - val_loss: 0.2266 - val_mean_absolute_error: 0.4198
# Epoch 32/500
# 600/600 [==============================] - 0s 25us/sample - loss: 0.2132 - mean_absolute_error: 0.4000 - val_loss: 0.2235 - val_mean_absolute_error: 0.4183
# Epoch 33/500
# 600/600 [==============================] - 0s 26us/sample - loss: 0.2098 - mean_absolute_error: 0.3980 - val_loss: 0.2213 - val_mean_absolute_error: 0.4173
# Epoch 34/500
# 600/600 [==============================] - 0s 24us/sample - loss: 0.2077 - mean_absolute_error: 0.3962 - val_loss: 0.2179 - val_mean_absolute_error: 0.4141
# Epoch 35/500
# 600/600 [==============================] - 0s 26us/sample - loss: 0.2044 - mean_absolute_error: 0.3934 - val_loss: 0.2150 - val_mean_absolute_error: 0.4111
# Epoch 36/500
# 600/600 [==============================] - 0s 24us/sample - loss: 0.2021 - mean_absolute_error: 0.3909 - val_loss: 0.2124 - val_mean_absolute_error: 0.4082
# Epoch 37/500
# 600/600 [==============================] - 0s 25us/sample - loss: 0.1998 - mean_absolute_error: 0.3890 - val_loss: 0.2102 - val_mean_absolute_error: 0.4070
# Epoch 38/500
# 600/600 [==============================] - 0s 26us/sample - loss: 0.1974 - mean_absolute_error: 0.3868 - val_loss: 0.2079 - val_mean_absolute_error: 0.4044
# Epoch 39/500
# 600/600 [==============================] - 0s 26us/sample - loss: 0.1953 - mean_absolute_error: 0.3850 - val_loss: 0.2062 - val_mean_absolute_error: 0.4032
# Epoch 40/500
# 600/600 [==============================] - 0s 23us/sample - loss: 0.1936 - mean_absolute_error: 0.3834 - val_loss: 0.2040 - val_mean_absolute_error: 0.4008
# Epoch 41/500
# 600/600 [==============================] - 0s 21us/sample - loss: 0.1914 - mean_absolute_error: 0.3813 - val_loss: 0.2023 - val_mean_absolute_error: 0.3991
# Epoch 42/500
# 600/600 [==============================] - 0s 22us/sample - loss: 0.1900 - mean_absolute_error: 0.3798 - val_loss: 0.2006 - val_mean_absolute_error: 0.3970
# Epoch 43/500
# 600/600 [==============================] - 0s 22us/sample - loss: 0.1888 - mean_absolute_error: 0.3782 - val_loss: 0.1991 - val_mean_absolute_error: 0.3940
# Epoch 44/500
# 600/600 [==============================] - 0s 24us/sample - loss: 0.1873 - mean_absolute_error: 0.3766 - val_loss: 0.1981 - val_mean_absolute_error: 0.3949
# Epoch 45/500
# 600/600 [==============================] - 0s 21us/sample - loss: 0.1855 - mean_absolute_error: 0.3749 - val_loss: 0.1965 - val_mean_absolute_error: 0.3926
# Epoch 46/500
# 600/600 [==============================] - 0s 27us/sample - loss: 0.1842 - mean_absolute_error: 0.3734 - val_loss: 0.1952 - val_mean_absolute_error: 0.3908
# Epoch 47/500
# 600/600 [==============================] - 0s 21us/sample - loss: 0.1828 - mean_absolute_error: 0.3718 - val_loss: 0.1941 - val_mean_absolute_error: 0.3895
# Epoch 48/500
# 600/600 [==============================] - 0s 24us/sample - loss: 0.1817 - mean_absolute_error: 0.3704 - val_loss: 0.1931 - val_mean_absolute_error: 0.3883
# Epoch 49/500
# 600/600 [==============================] - 0s 22us/sample - loss: 0.1812 - mean_absolute_error: 0.3694 - val_loss: 0.1918 - val_mean_absolute_error: 0.3854
# Epoch 50/500
# 600/600 [==============================] - 0s 25us/sample - loss: 0.1796 - mean_absolute_error: 0.3678 - val_loss: 0.1914 - val_mean_absolute_error: 0.3864
# Epoch 51/500
# 600/600 [==============================] - 0s 27us/sample - loss: 0.1789 - mean_absolute_error: 0.3671 - val_loss: 0.1903 - val_mean_absolute_error: 0.3848
# Epoch 52/500
# 600/600 [==============================] - 0s 27us/sample - loss: 0.1779 - mean_absolute_error: 0.3655 - val_loss: 0.1893 - val_mean_absolute_error: 0.3828
# Epoch 53/500
# 600/600 [==============================] - 0s 21us/sample - loss: 0.1770 - mean_absolute_error: 0.3645 - val_loss: 0.1886 - val_mean_absolute_error: 0.3818
# Epoch 54/500
# 600/600 [==============================] - 0s 21us/sample - loss: 0.1764 - mean_absolute_error: 0.3635 - val_loss: 0.1878 - val_mean_absolute_error: 0.3793
# Epoch 55/500
# 600/600 [==============================] - 0s 22us/sample - loss: 0.1758 - mean_absolute_error: 0.3627 - val_loss: 0.1875 - val_mean_absolute_error: 0.3806
# Epoch 56/500
# 600/600 [==============================] - 0s 20us/sample - loss: 0.1746 - mean_absolute_error: 0.3613 - val_loss: 0.1866 - val_mean_absolute_error: 0.3788
# Epoch 57/500
# 600/600 [==============================] - 0s 25us/sample - loss: 0.1741 - mean_absolute_error: 0.3605 - val_loss: 0.1859 - val_mean_absolute_error: 0.3771
# Epoch 58/500
# 600/600 [==============================] - 0s 20us/sample - loss: 0.1737 - mean_absolute_error: 0.3597 - val_loss: 0.1856 - val_mean_absolute_error: 0.3772
# Epoch 59/500
# 600/600 [==============================] - 0s 25us/sample - loss: 0.1742 - mean_absolute_error: 0.3590 - val_loss: 0.1849 - val_mean_absolute_error: 0.3737
# Epoch 60/500
# 600/600 [==============================] - 0s 20us/sample - loss: 0.1722 - mean_absolute_error: 0.3577 - val_loss: 0.1847 - val_mean_absolute_error: 0.3757
# Epoch 61/500
# 600/600 [==============================] - 0s 24us/sample - loss: 0.1719 - mean_absolute_error: 0.3573 - val_loss: 0.1847 - val_mean_absolute_error: 0.3758
# Epoch 62/500
# 600/600 [==============================] - 0s 22us/sample - loss: 0.1714 - mean_absolute_error: 0.3563 - val_loss: 0.1836 - val_mean_absolute_error: 0.3733
# Epoch 63/500
# 600/600 [==============================] - 0s 22us/sample - loss: 0.1709 - mean_absolute_error: 0.3557 - val_loss: 0.1834 - val_mean_absolute_error: 0.3732
# Epoch 64/500
# 600/600 [==============================] - 0s 27us/sample - loss: 0.1705 - mean_absolute_error: 0.3550 - val_loss: 0.1828 - val_mean_absolute_error: 0.3715
# Epoch 65/500
# 600/600 [==============================] - 0s 22us/sample - loss: 0.1699 - mean_absolute_error: 0.3542 - val_loss: 0.1824 - val_mean_absolute_error: 0.3703
# Epoch 66/500
# 600/600 [==============================] - 0s 26us/sample - loss: 0.1696 - mean_absolute_error: 0.3536 - val_loss: 0.1824 - val_mean_absolute_error: 0.3709
# Epoch 67/500
# 600/600 [==============================] - 0s 20us/sample - loss: 0.1693 - mean_absolute_error: 0.3531 - val_loss: 0.1820 - val_mean_absolute_error: 0.3701
# Epoch 68/500
# 600/600 [==============================] - 0s 26us/sample - loss: 0.1691 - mean_absolute_error: 0.3525 - val_loss: 0.1819 - val_mean_absolute_error: 0.3699
# Epoch 69/500
# 600/600 [==============================] - 0s 20us/sample - loss: 0.1685 - mean_absolute_error: 0.3518 - val_loss: 0.1814 - val_mean_absolute_error: 0.3686
# Epoch 70/500
# 600/600 [==============================] - 0s 24us/sample - loss: 0.1681 - mean_absolute_error: 0.3510 - val_loss: 0.1810 - val_mean_absolute_error: 0.3664
# Epoch 71/500
# 600/600 [==============================] - 0s 21us/sample - loss: 0.1679 - mean_absolute_error: 0.3505 - val_loss: 0.1808 - val_mean_absolute_error: 0.3668
# Epoch 72/500
# 600/600 [==============================] - 0s 20us/sample - loss: 0.1676 - mean_absolute_error: 0.3499 - val_loss: 0.1805 - val_mean_absolute_error: 0.3664
# Epoch 73/500
# 600/600 [==============================] - 0s 26us/sample - loss: 0.1672 - mean_absolute_error: 0.3494 - val_loss: 0.1805 - val_mean_absolute_error: 0.3666
# Epoch 74/500
# 600/600 [==============================] - 0s 22us/sample - loss: 0.1672 - mean_absolute_error: 0.3489 - val_loss: 0.1800 - val_mean_absolute_error: 0.3641
# Epoch 75/500
# 600/600 [==============================] - 0s 26us/sample - loss: 0.1665 - mean_absolute_error: 0.3480 - val_loss: 0.1801 - val_mean_absolute_error: 0.3656
# Epoch 76/500
# 600/600 [==============================] - 0s 20us/sample - loss: 0.1666 - mean_absolute_error: 0.3481 - val_loss: 0.1797 - val_mean_absolute_error: 0.3643
# Epoch 77/500
# 600/600 [==============================] - 0s 26us/sample - loss: 0.1660 - mean_absolute_error: 0.3473 - val_loss: 0.1796 - val_mean_absolute_error: 0.3643
# Epoch 78/500
# 600/600 [==============================] - 0s 21us/sample - loss: 0.1662 - mean_absolute_error: 0.3474 - val_loss: 0.1793 - val_mean_absolute_error: 0.3625
# Epoch 79/500
# 600/600 [==============================] - 0s 25us/sample - loss: 0.1652 - mean_absolute_error: 0.3464 - val_loss: 0.1801 - val_mean_absolute_error: 0.3658
# Epoch 80/500
# 600/600 [==============================] - 0s 21us/sample - loss: 0.1659 - mean_absolute_error: 0.3469 - val_loss: 0.1791 - val_mean_absolute_error: 0.3635
# Epoch 81/500
# 600/600 [==============================] - 0s 21us/sample - loss: 0.1650 - mean_absolute_error: 0.3457 - val_loss: 0.1792 - val_mean_absolute_error: 0.3638
# Epoch 82/500
# 600/600 [==============================] - 0s 24us/sample - loss: 0.1647 - mean_absolute_error: 0.3452 - val_loss: 0.1787 - val_mean_absolute_error: 0.3621
# Epoch 83/500
# 600/600 [==============================] - 0s 20us/sample - loss: 0.1645 - mean_absolute_error: 0.3448 - val_loss: 0.1786 - val_mean_absolute_error: 0.3620
# Epoch 84/500
# 600/600 [==============================] - 0s 28us/sample - loss: 0.1644 - mean_absolute_error: 0.3444 - val_loss: 0.1788 - val_mean_absolute_error: 0.3628
# Epoch 85/500
# 600/600 [==============================] - 0s 20us/sample - loss: 0.1642 - mean_absolute_error: 0.3444 - val_loss: 0.1786 - val_mean_absolute_error: 0.3624
# Epoch 86/500
# 600/600 [==============================] - 0s 26us/sample - loss: 0.1638 - mean_absolute_error: 0.3437 - val_loss: 0.1781 - val_mean_absolute_error: 0.3609
# Epoch 87/500
# 600/600 [==============================] - 0s 20us/sample - loss: 0.1641 - mean_absolute_error: 0.3435 - val_loss: 0.1779 - val_mean_absolute_error: 0.3599
# Epoch 88/500
# 600/600 [==============================] - 0s 25us/sample - loss: 0.1648 - mean_absolute_error: 0.3445 - val_loss: 0.1786 - val_mean_absolute_error: 0.3625
# Epoch 89/500
# 600/600 [==============================] - 0s 21us/sample - loss: 0.1634 - mean_absolute_error: 0.3430 - val_loss: 0.1777 - val_mean_absolute_error: 0.3597
# Epoch 90/500
# 600/600 [==============================] - 0s 25us/sample - loss: 0.1631 - mean_absolute_error: 0.3424 - val_loss: 0.1776 - val_mean_absolute_error: 0.3593
# Epoch 91/500
# 600/600 [==============================] - 0s 22us/sample - loss: 0.1631 - mean_absolute_error: 0.3422 - val_loss: 0.1775 - val_mean_absolute_error: 0.3573
# Epoch 92/500
# 600/600 [==============================] - 0s 20us/sample - loss: 0.1636 - mean_absolute_error: 0.3425 - val_loss: 0.1778 - val_mean_absolute_error: 0.3603
# Epoch 93/500
# 600/600 [==============================] - 0s 27us/sample - loss: 0.1625 - mean_absolute_error: 0.3416 - val_loss: 0.1774 - val_mean_absolute_error: 0.3590
# Epoch 94/500
# 600/600 [==============================] - 0s 22us/sample - loss: 0.1624 - mean_absolute_error: 0.3411 - val_loss: 0.1774 - val_mean_absolute_error: 0.3591
# Epoch 95/500
# 600/600 [==============================] - 0s 27us/sample - loss: 0.1624 - mean_absolute_error: 0.3410 - val_loss: 0.1771 - val_mean_absolute_error: 0.3582
# Epoch 96/500
# 600/600 [==============================] - 0s 21us/sample - loss: 0.1626 - mean_absolute_error: 0.3416 - val_loss: 0.1778 - val_mean_absolute_error: 0.3603
# Epoch 97/500
# 600/600 [==============================] - 0s 26us/sample - loss: 0.1629 - mean_absolute_error: 0.3410 - val_loss: 0.1769 - val_mean_absolute_error: 0.3562
# Epoch 98/500
# 600/600 [==============================] - 0s 21us/sample - loss: 0.1618 - mean_absolute_error: 0.3399 - val_loss: 0.1770 - val_mean_absolute_error: 0.3580
# Epoch 99/500
# 600/600 [==============================] - 0s 26us/sample - loss: 0.1616 - mean_absolute_error: 0.3399 - val_loss: 0.1770 - val_mean_absolute_error: 0.3583
# Epoch 100/500
# 600/600 [==============================] - 0s 20us/sample - loss: 0.1614 - mean_absolute_error: 0.3395 - val_loss: 0.1767 - val_mean_absolute_error: 0.3565
# Epoch 101/500
# 600/600 [==============================] - 0s 24us/sample - loss: 0.1612 - mean_absolute_error: 0.3389 - val_loss: 0.1766 - val_mean_absolute_error: 0.3561
# Epoch 102/500
# 600/600 [==============================] - 0s 21us/sample - loss: 0.1612 - mean_absolute_error: 0.3388 - val_loss: 0.1765 - val_mean_absolute_error: 0.3560
# Epoch 103/500
# 600/600 [==============================] - 0s 21us/sample - loss: 0.1610 - mean_absolute_error: 0.3388 - val_loss: 0.1768 - val_mean_absolute_error: 0.3576
# Epoch 104/500
# 600/600 [==============================] - 0s 26us/sample - loss: 0.1609 - mean_absolute_error: 0.3389 - val_loss: 0.1771 - val_mean_absolute_error: 0.3584
# Epoch 105/500
# 600/600 [==============================] - 0s 20us/sample - loss: 0.1608 - mean_absolute_error: 0.3384 - val_loss: 0.1764 - val_mean_absolute_error: 0.3564
# Epoch 106/500
# 600/600 [==============================] - 0s 24us/sample - loss: 0.1608 - mean_absolute_error: 0.3382 - val_loss: 0.1763 - val_mean_absolute_error: 0.3554
# Epoch 107/500
# 600/600 [==============================] - 0s 20us/sample - loss: 0.1606 - mean_absolute_error: 0.3379 - val_loss: 0.1766 - val_mean_absolute_error: 0.3574
# Epoch 108/500
# 600/600 [==============================] - 0s 25us/sample - loss: 0.1601 - mean_absolute_error: 0.3377 - val_loss: 0.1762 - val_mean_absolute_error: 0.3557
# Epoch 109/500
# 600/600 [==============================] - 0s 21us/sample - loss: 0.1606 - mean_absolute_error: 0.3372 - val_loss: 0.1761 - val_mean_absolute_error: 0.3541
# Epoch 110/500
# 600/600 [==============================] - 0s 24us/sample - loss: 0.1600 - mean_absolute_error: 0.3369 - val_loss: 0.1762 - val_mean_absolute_error: 0.3559
# Epoch 111/500
# 600/600 [==============================] - 0s 22us/sample - loss: 0.1600 - mean_absolute_error: 0.3373 - val_loss: 0.1764 - val_mean_absolute_error: 0.3568
# Epoch 112/500
# 600/600 [==============================] - 0s 20us/sample - loss: 0.1609 - mean_absolute_error: 0.3384 - val_loss: 0.1767 - val_mean_absolute_error: 0.3576
# Epoch 113/500
# 600/600 [==============================] - 0s 26us/sample - loss: 0.1607 - mean_absolute_error: 0.3374 - val_loss: 0.1760 - val_mean_absolute_error: 0.3534
# Epoch 114/500
# 600/600 [==============================] - 0s 20us/sample - loss: 0.1601 - mean_absolute_error: 0.3371 - val_loss: 0.1761 - val_mean_absolute_error: 0.3559
# Epoch 115/500
# 600/600 [==============================] - 0s 25us/sample - loss: 0.1595 - mean_absolute_error: 0.3367 - val_loss: 0.1760 - val_mean_absolute_error: 0.3556
# Epoch 116/500
# 600/600 [==============================] - 0s 19us/sample - loss: 0.1597 - mean_absolute_error: 0.3364 - val_loss: 0.1758 - val_mean_absolute_error: 0.3534
# Epoch 117/500
# 600/600 [==============================] - 0s 23us/sample - loss: 0.1594 - mean_absolute_error: 0.3359 - val_loss: 0.1759 - val_mean_absolute_error: 0.3553
# Epoch 118/500
# 600/600 [==============================] - 0s 20us/sample - loss: 0.1592 - mean_absolute_error: 0.3361 - val_loss: 0.1760 - val_mean_absolute_error: 0.3555
# Epoch 119/500
# 600/600 [==============================] - 0s 19us/sample - loss: 0.1594 - mean_absolute_error: 0.3361 - val_loss: 0.1757 - val_mean_absolute_error: 0.3538
# Epoch 120/500
# 600/600 [==============================] - 0s 24us/sample - loss: 0.1590 - mean_absolute_error: 0.3354 - val_loss: 0.1757 - val_mean_absolute_error: 0.3544
# Epoch 121/500
# 600/600 [==============================] - 0s 22us/sample - loss: 0.1588 - mean_absolute_error: 0.3354 - val_loss: 0.1761 - val_mean_absolute_error: 0.3561
# Epoch 122/500
# 600/600 [==============================] - 0s 27us/sample - loss: 0.1591 - mean_absolute_error: 0.3359 - val_loss: 0.1760 - val_mean_absolute_error: 0.3558
# Epoch 123/500
# 600/600 [==============================] - 0s 24us/sample - loss: 0.1591 - mean_absolute_error: 0.3352 - val_loss: 0.1755 - val_mean_absolute_error: 0.3528
# Epoch 124/500
# 600/600 [==============================] - 0s 26us/sample - loss: 0.1591 - mean_absolute_error: 0.3354 - val_loss: 0.1759 - val_mean_absolute_error: 0.3552
# Epoch 125/500
# 600/600 [==============================] - 0s 21us/sample - loss: 0.1587 - mean_absolute_error: 0.3351 - val_loss: 0.1756 - val_mean_absolute_error: 0.3540
# Epoch 126/500
# 600/600 [==============================] - 0s 26us/sample - loss: 0.1602 - mean_absolute_error: 0.3353 - val_loss: 0.1756 - val_mean_absolute_error: 0.3512
# Epoch 127/500
# 600/600 [==============================] - 0s 21us/sample - loss: 0.1601 - mean_absolute_error: 0.3363 - val_loss: 0.1763 - val_mean_absolute_error: 0.3561
# Epoch 128/500
# 600/600 [==============================] - 0s 24us/sample - loss: 0.1589 - mean_absolute_error: 0.3353 - val_loss: 0.1758 - val_mean_absolute_error: 0.3548
# Epoch 129/500
# 600/600 [==============================] - 0s 21us/sample - loss: 0.1582 - mean_absolute_error: 0.3341 - val_loss: 0.1753 - val_mean_absolute_error: 0.3523
# Epoch 130/500
# 600/600 [==============================] - 0s 20us/sample - loss: 0.1589 - mean_absolute_error: 0.3337 - val_loss: 0.1754 - val_mean_absolute_error: 0.3511
# Epoch 131/500
# 600/600 [==============================] - 0s 26us/sample - loss: 0.1585 - mean_absolute_error: 0.3332 - val_loss: 0.1753 - val_mean_absolute_error: 0.3528
# Epoch 132/500
# 600/600 [==============================] - 0s 21us/sample - loss: 0.1583 - mean_absolute_error: 0.3344 - val_loss: 0.1766 - val_mean_absolute_error: 0.3564
# Epoch 133/500
# 600/600 [==============================] - 0s 26us/sample - loss: 0.1586 - mean_absolute_error: 0.3346 - val_loss: 0.1753 - val_mean_absolute_error: 0.3531
# Epoch 134/500
# 600/600 [==============================] - 0s 20us/sample - loss: 0.1580 - mean_absolute_error: 0.3337 - val_loss: 0.1752 - val_mean_absolute_error: 0.3529
# Epoch 135/500
# 600/600 [==============================] - 0s 25us/sample - loss: 0.1581 - mean_absolute_error: 0.3340 - val_loss: 0.1756 - val_mean_absolute_error: 0.3544
# Epoch 136/500
# 600/600 [==============================] - 0s 20us/sample - loss: 0.1578 - mean_absolute_error: 0.3338 - val_loss: 0.1752 - val_mean_absolute_error: 0.3528
# Epoch 137/500
# 600/600 [==============================] - 0s 25us/sample - loss: 0.1580 - mean_absolute_error: 0.3328 - val_loss: 0.1751 - val_mean_absolute_error: 0.3508
# Epoch 138/500
# 600/600 [==============================] - 0s 22us/sample - loss: 0.1576 - mean_absolute_error: 0.3326 - val_loss: 0.1752 - val_mean_absolute_error: 0.3530
# Epoch 139/500
# 600/600 [==============================] - 0s 21us/sample - loss: 0.1581 - mean_absolute_error: 0.3337 - val_loss: 0.1759 - val_mean_absolute_error: 0.3553
# Epoch 140/500
# 600/600 [==============================] - 0s 23us/sample - loss: 0.1575 - mean_absolute_error: 0.3331 - val_loss: 0.1750 - val_mean_absolute_error: 0.3523
# Epoch 141/500
# 600/600 [==============================] - 0s 21us/sample - loss: 0.1575 - mean_absolute_error: 0.3324 - val_loss: 0.1750 - val_mean_absolute_error: 0.3510
# Epoch 142/500
# 600/600 [==============================] - 0s 25us/sample - loss: 0.1575 - mean_absolute_error: 0.3321 - val_loss: 0.1750 - val_mean_absolute_error: 0.3514
# Epoch 143/500
# 600/600 [==============================] - 0s 20us/sample - loss: 0.1586 - mean_absolute_error: 0.3336 - val_loss: 0.1758 - val_mean_absolute_error: 0.3548
# Epoch 144/500
# 600/600 [==============================] - 0s 26us/sample - loss: 0.1578 - mean_absolute_error: 0.3333 - val_loss: 0.1752 - val_mean_absolute_error: 0.3531
# Epoch 145/500
# 600/600 [==============================] - 0s 21us/sample - loss: 0.1572 - mean_absolute_error: 0.3321 - val_loss: 0.1749 - val_mean_absolute_error: 0.3511
# Epoch 146/500
# 600/600 [==============================] - 0s 24us/sample - loss: 0.1572 - mean_absolute_error: 0.3318 - val_loss: 0.1748 - val_mean_absolute_error: 0.3515
# Epoch 147/500
# 600/600 [==============================] - 0s 22us/sample - loss: 0.1574 - mean_absolute_error: 0.3322 - val_loss: 0.1750 - val_mean_absolute_error: 0.3527
# Epoch 148/500
# 600/600 [==============================] - 0s 21us/sample - loss: 0.1572 - mean_absolute_error: 0.3324 - val_loss: 0.1751 - val_mean_absolute_error: 0.3531
# Epoch 149/500
# 600/600 [==============================] - 0s 24us/sample - loss: 0.1570 - mean_absolute_error: 0.3319 - val_loss: 0.1748 - val_mean_absolute_error: 0.3514
# Epoch 150/500
# 600/600 [==============================] - 0s 20us/sample - loss: 0.1572 - mean_absolute_error: 0.3316 - val_loss: 0.1748 - val_mean_absolute_error: 0.3513
# Epoch 151/500
# 600/600 [==============================] - 0s 26us/sample - loss: 0.1570 - mean_absolute_error: 0.3318 - val_loss: 0.1751 - val_mean_absolute_error: 0.3529
# Epoch 152/500
# 600/600 [==============================] - 0s 20us/sample - loss: 0.1568 - mean_absolute_error: 0.3318 - val_loss: 0.1749 - val_mean_absolute_error: 0.3521
# Epoch 153/500
# 600/600 [==============================] - 0s 25us/sample - loss: 0.1569 - mean_absolute_error: 0.3314 - val_loss: 0.1747 - val_mean_absolute_error: 0.3498
# Epoch 154/500
# 600/600 [==============================] - 0s 20us/sample - loss: 0.1569 - mean_absolute_error: 0.3310 - val_loss: 0.1747 - val_mean_absolute_error: 0.3513
# Epoch 155/500
# 600/600 [==============================] - 0s 24us/sample - loss: 0.1568 - mean_absolute_error: 0.3314 - val_loss: 0.1747 - val_mean_absolute_error: 0.3512
# Epoch 156/500
# 600/600 [==============================] - 0s 20us/sample - loss: 0.1565 - mean_absolute_error: 0.3310 - val_loss: 0.1746 - val_mean_absolute_error: 0.3510
# Epoch 157/500
# 600/600 [==============================] - 0s 20us/sample - loss: 0.1568 - mean_absolute_error: 0.3312 - val_loss: 0.1746 - val_mean_absolute_error: 0.3512
# Epoch 158/500
# 600/600 [==============================] - 0s 24us/sample - loss: 0.1574 - mean_absolute_error: 0.3312 - val_loss: 0.1746 - val_mean_absolute_error: 0.3491
# Epoch 159/500
# 600/600 [==============================] - 0s 20us/sample - loss: 0.1562 - mean_absolute_error: 0.3301 - val_loss: 0.1751 - val_mean_absolute_error: 0.3529
# Epoch 160/500
# 600/600 [==============================] - 0s 26us/sample - loss: 0.1568 - mean_absolute_error: 0.3311 - val_loss: 0.1748 - val_mean_absolute_error: 0.3519
# Epoch 161/500
# 600/600 [==============================] - 0s 20us/sample - loss: 0.1563 - mean_absolute_error: 0.3310 - val_loss: 0.1753 - val_mean_absolute_error: 0.3533
# Epoch 162/500
# 600/600 [==============================] - 0s 26us/sample - loss: 0.1565 - mean_absolute_error: 0.3311 - val_loss: 0.1745 - val_mean_absolute_error: 0.3511
# Epoch 163/500
# 600/600 [==============================] - 0s 21us/sample - loss: 0.1563 - mean_absolute_error: 0.3300 - val_loss: 0.1744 - val_mean_absolute_error: 0.3496
# Epoch 164/500
# 600/600 [==============================] - 0s 24us/sample - loss: 0.1563 - mean_absolute_error: 0.3304 - val_loss: 0.1745 - val_mean_absolute_error: 0.3511
# Epoch 165/500
# 600/600 [==============================] - 0s 23us/sample - loss: 0.1561 - mean_absolute_error: 0.3302 - val_loss: 0.1744 - val_mean_absolute_error: 0.3503
# Epoch 166/500
# 600/600 [==============================] - 0s 19us/sample - loss: 0.1564 - mean_absolute_error: 0.3298 - val_loss: 0.1743 - val_mean_absolute_error: 0.3491
# Epoch 167/500
# 600/600 [==============================] - 0s 26us/sample - loss: 0.1565 - mean_absolute_error: 0.3307 - val_loss: 0.1750 - val_mean_absolute_error: 0.3523
# Epoch 168/500
# 600/600 [==============================] - 0s 20us/sample - loss: 0.1564 - mean_absolute_error: 0.3301 - val_loss: 0.1742 - val_mean_absolute_error: 0.3490
# Epoch 169/500
# 600/600 [==============================] - 0s 25us/sample - loss: 0.1559 - mean_absolute_error: 0.3294 - val_loss: 0.1744 - val_mean_absolute_error: 0.3505
# Epoch 170/500
# 600/600 [==============================] - 0s 20us/sample - loss: 0.1565 - mean_absolute_error: 0.3303 - val_loss: 0.1748 - val_mean_absolute_error: 0.3519
# Epoch 171/500
# 600/600 [==============================] - 0s 24us/sample - loss: 0.1556 - mean_absolute_error: 0.3290 - val_loss: 0.1742 - val_mean_absolute_error: 0.3481
# Epoch 172/500
# 600/600 [==============================] - 0s 20us/sample - loss: 0.1564 - mean_absolute_error: 0.3286 - val_loss: 0.1742 - val_mean_absolute_error: 0.3479
# Epoch 173/500
# 600/600 [==============================] - 0s 19us/sample - loss: 0.1566 - mean_absolute_error: 0.3294 - val_loss: 0.1748 - val_mean_absolute_error: 0.3519
# Epoch 174/500
# 600/600 [==============================] - 0s 25us/sample - loss: 0.1562 - mean_absolute_error: 0.3296 - val_loss: 0.1742 - val_mean_absolute_error: 0.3497
# Epoch 175/500
# 600/600 [==============================] - 0s 20us/sample - loss: 0.1556 - mean_absolute_error: 0.3290 - val_loss: 0.1741 - val_mean_absolute_error: 0.3491
# Epoch 176/500
# 600/600 [==============================] - 0s 27us/sample - loss: 0.1560 - mean_absolute_error: 0.3293 - val_loss: 0.1742 - val_mean_absolute_error: 0.3503
# Epoch 177/500
# 600/600 [==============================] - 0s 21us/sample - loss: 0.1553 - mean_absolute_error: 0.3289 - val_loss: 0.1740 - val_mean_absolute_error: 0.3479
# Epoch 178/500
# 600/600 [==============================] - 0s 26us/sample - loss: 0.1557 - mean_absolute_error: 0.3281 - val_loss: 0.1740 - val_mean_absolute_error: 0.3477
# Epoch 179/500
# 600/600 [==============================] - 0s 21us/sample - loss: 0.1555 - mean_absolute_error: 0.3282 - val_loss: 0.1740 - val_mean_absolute_error: 0.3491
# Epoch 180/500
# 600/600 [==============================] - 0s 24us/sample - loss: 0.1554 - mean_absolute_error: 0.3285 - val_loss: 0.1741 - val_mean_absolute_error: 0.3496
# Epoch 181/500
# 600/600 [==============================] - 0s 21us/sample - loss: 0.1554 - mean_absolute_error: 0.3286 - val_loss: 0.1743 - val_mean_absolute_error: 0.3502
# Epoch 182/500
# 600/600 [==============================] - 0s 19us/sample - loss: 0.1551 - mean_absolute_error: 0.3284 - val_loss: 0.1739 - val_mean_absolute_error: 0.3486
# Epoch 183/500
# 600/600 [==============================] - 0s 24us/sample - loss: 0.1555 - mean_absolute_error: 0.3284 - val_loss: 0.1739 - val_mean_absolute_error: 0.3485
# Epoch 184/500
# 600/600 [==============================] - 0s 20us/sample - loss: 0.1551 - mean_absolute_error: 0.3279 - val_loss: 0.1738 - val_mean_absolute_error: 0.3482
# Epoch 185/500
# 600/600 [==============================] - 0s 26us/sample - loss: 0.1552 - mean_absolute_error: 0.3276 - val_loss: 0.1738 - val_mean_absolute_error: 0.3480
# Epoch 186/500
# 600/600 [==============================] - 0s 20us/sample - loss: 0.1550 - mean_absolute_error: 0.3280 - val_loss: 0.1746 - val_mean_absolute_error: 0.3509
# Epoch 187/500
# 600/600 [==============================] - 0s 24us/sample - loss: 0.1555 - mean_absolute_error: 0.3286 - val_loss: 0.1739 - val_mean_absolute_error: 0.3493
# Epoch 188/500
# 600/600 [==============================] - 0s 21us/sample - loss: 0.1550 - mean_absolute_error: 0.3276 - val_loss: 0.1737 - val_mean_absolute_error: 0.3480
# Epoch 189/500
# 600/600 [==============================] - 0s 20us/sample - loss: 0.1552 - mean_absolute_error: 0.3274 - val_loss: 0.1737 - val_mean_absolute_error: 0.3476
# Epoch 190/500
# 600/600 [==============================] - 0s 25us/sample - loss: 0.1550 - mean_absolute_error: 0.3272 - val_loss: 0.1736 - val_mean_absolute_error: 0.3476
# Epoch 191/500
# 600/600 [==============================] - 0s 21us/sample - loss: 0.1556 - mean_absolute_error: 0.3281 - val_loss: 0.1741 - val_mean_absolute_error: 0.3496
# Epoch 192/500
# 600/600 [==============================] - 0s 26us/sample - loss: 0.1548 - mean_absolute_error: 0.3274 - val_loss: 0.1737 - val_mean_absolute_error: 0.3482
# Epoch 193/500
# 600/600 [==============================] - 0s 20us/sample - loss: 0.1547 - mean_absolute_error: 0.3271 - val_loss: 0.1736 - val_mean_absolute_error: 0.3480
# Epoch 194/500
# 600/600 [==============================] - 0s 26us/sample - loss: 0.1548 - mean_absolute_error: 0.3270 - val_loss: 0.1735 - val_mean_absolute_error: 0.3470
# Epoch 195/500
# 600/600 [==============================] - 0s 20us/sample - loss: 0.1550 - mean_absolute_error: 0.3274 - val_loss: 0.1738 - val_mean_absolute_error: 0.3492
# Epoch 196/500
# 600/600 [==============================] - 0s 25us/sample - loss: 0.1545 - mean_absolute_error: 0.3270 - val_loss: 0.1735 - val_mean_absolute_error: 0.3476
# Epoch 197/500
# 600/600 [==============================] - 0s 20us/sample - loss: 0.1546 - mean_absolute_error: 0.3269 - val_loss: 0.1735 - val_mean_absolute_error: 0.3481
# Epoch 198/500
# 600/600 [==============================] - 0s 20us/sample - loss: 0.1544 - mean_absolute_error: 0.3267 - val_loss: 0.1735 - val_mean_absolute_error: 0.3478
# Epoch 199/500
# 600/600 [==============================] - 0s 26us/sample - loss: 0.1545 - mean_absolute_error: 0.3268 - val_loss: 0.1734 - val_mean_absolute_error: 0.3477
# Epoch 200/500
# 600/600 [==============================] - 0s 20us/sample - loss: 0.1543 - mean_absolute_error: 0.3267 - val_loss: 0.1735 - val_mean_absolute_error: 0.3482
# Epoch 201/500
# 600/600 [==============================] - 0s 26us/sample - loss: 0.1545 - mean_absolute_error: 0.3268 - val_loss: 0.1736 - val_mean_absolute_error: 0.3484
# Epoch 202/500
# 600/600 [==============================] - 0s 21us/sample - loss: 0.1543 - mean_absolute_error: 0.3265 - val_loss: 0.1733 - val_mean_absolute_error: 0.3464
# Epoch 203/500
# 600/600 [==============================] - 0s 26us/sample - loss: 0.1548 - mean_absolute_error: 0.3262 - val_loss: 0.1732 - val_mean_absolute_error: 0.3463
# Epoch 204/500
# 600/600 [==============================] - 0s 21us/sample - loss: 0.1551 - mean_absolute_error: 0.3273 - val_loss: 0.1746 - val_mean_absolute_error: 0.3508
# Epoch 205/500
# 600/600 [==============================] - 0s 25us/sample - loss: 0.1545 - mean_absolute_error: 0.3267 - val_loss: 0.1733 - val_mean_absolute_error: 0.3474
# Epoch 206/500
# 600/600 [==============================] - 0s 20us/sample - loss: 0.1541 - mean_absolute_error: 0.3259 - val_loss: 0.1732 - val_mean_absolute_error: 0.3458
# Epoch 207/500
# 600/600 [==============================] - 0s 20us/sample - loss: 0.1543 - mean_absolute_error: 0.3260 - val_loss: 0.1732 - val_mean_absolute_error: 0.3468
# Epoch 208/500
# 600/600 [==============================] - 0s 26us/sample - loss: 0.1544 - mean_absolute_error: 0.3260 - val_loss: 0.1732 - val_mean_absolute_error: 0.3468
# Epoch 209/500
# 600/600 [==============================] - 0s 19us/sample - loss: 0.1549 - mean_absolute_error: 0.3269 - val_loss: 0.1736 - val_mean_absolute_error: 0.3486
# Epoch 210/500
# 600/600 [==============================] - 0s 24us/sample - loss: 0.1543 - mean_absolute_error: 0.3259 - val_loss: 0.1731 - val_mean_absolute_error: 0.3463
# Epoch 211/500
# 600/600 [==============================] - 0s 21us/sample - loss: 0.1539 - mean_absolute_error: 0.3255 - val_loss: 0.1732 - val_mean_absolute_error: 0.3472
# Epoch 212/500
# 600/600 [==============================] - 0s 26us/sample - loss: 0.1545 - mean_absolute_error: 0.3265 - val_loss: 0.1735 - val_mean_absolute_error: 0.3482
# Epoch 213/500
# 600/600 [==============================] - 0s 21us/sample - loss: 0.1538 - mean_absolute_error: 0.3255 - val_loss: 0.1730 - val_mean_absolute_error: 0.3451
# Epoch 214/500
# 600/600 [==============================] - 0s 24us/sample - loss: 0.1543 - mean_absolute_error: 0.3250 - val_loss: 0.1730 - val_mean_absolute_error: 0.3443
# Epoch 215/500
# 600/600 [==============================] - 0s 21us/sample - loss: 0.1551 - mean_absolute_error: 0.3267 - val_loss: 0.1734 - val_mean_absolute_error: 0.3478
# Epoch 216/500
# 600/600 [==============================] - 0s 20us/sample - loss: 0.1536 - mean_absolute_error: 0.3250 - val_loss: 0.1729 - val_mean_absolute_error: 0.3451
# Epoch 217/500
# 600/600 [==============================] - 0s 24us/sample - loss: 0.1555 - mean_absolute_error: 0.3251 - val_loss: 0.1736 - val_mean_absolute_error: 0.3423
# Epoch 218/500
# 600/600 [==============================] - 0s 21us/sample - loss: 0.1541 - mean_absolute_error: 0.3249 - val_loss: 0.1734 - val_mean_absolute_error: 0.3478
# Epoch 219/500
# 600/600 [==============================] - 0s 26us/sample - loss: 0.1542 - mean_absolute_error: 0.3256 - val_loss: 0.1737 - val_mean_absolute_error: 0.3486
# Epoch 220/500
# 600/600 [==============================] - 0s 20us/sample - loss: 0.1538 - mean_absolute_error: 0.3251 - val_loss: 0.1731 - val_mean_absolute_error: 0.3430
# Epoch 221/500
# 600/600 [==============================] - 0s 24us/sample - loss: 0.1543 - mean_absolute_error: 0.3246 - val_loss: 0.1727 - val_mean_absolute_error: 0.3448
# Epoch 222/500
# 600/600 [==============================] - 0s 21us/sample - loss: 0.1538 - mean_absolute_error: 0.3245 - val_loss: 0.1728 - val_mean_absolute_error: 0.3454
# Epoch 223/500
# 600/600 [==============================] - 0s 20us/sample - loss: 0.1536 - mean_absolute_error: 0.3250 - val_loss: 0.1730 - val_mean_absolute_error: 0.3466
# Epoch 224/500
# 600/600 [==============================] - 0s 23us/sample - loss: 0.1535 - mean_absolute_error: 0.3244 - val_loss: 0.1727 - val_mean_absolute_error: 0.3453
# Epoch 225/500
# 600/600 [==============================] - 0s 19us/sample - loss: 0.1533 - mean_absolute_error: 0.3241 - val_loss: 0.1727 - val_mean_absolute_error: 0.3452
# Epoch 226/500
# 600/600 [==============================] - 0s 27us/sample - loss: 0.1533 - mean_absolute_error: 0.3241 - val_loss: 0.1727 - val_mean_absolute_error: 0.3455
# Epoch 227/500
# 600/600 [==============================] - 0s 21us/sample - loss: 0.1534 - mean_absolute_error: 0.3242 - val_loss: 0.1728 - val_mean_absolute_error: 0.3460
# Epoch 228/500
# 600/600 [==============================] - 0s 25us/sample - loss: 0.1540 - mean_absolute_error: 0.3250 - val_loss: 0.1734 - val_mean_absolute_error: 0.3478
# Epoch 229/500
# 600/600 [==============================] - 0s 20us/sample - loss: 0.1531 - mean_absolute_error: 0.3243 - val_loss: 0.1725 - val_mean_absolute_error: 0.3449
# Epoch 230/500
# 600/600 [==============================] - 0s 24us/sample - loss: 0.1532 - mean_absolute_error: 0.3239 - val_loss: 0.1725 - val_mean_absolute_error: 0.3446
# Epoch 231/500
# 600/600 [==============================] - 0s 22us/sample - loss: 0.1530 - mean_absolute_error: 0.3238 - val_loss: 0.1727 - val_mean_absolute_error: 0.3460
# Epoch 232/500
# 600/600 [==============================] - 0s 21us/sample - loss: 0.1534 - mean_absolute_error: 0.3246 - val_loss: 0.1730 - val_mean_absolute_error: 0.3474
# Epoch 233/500
# 600/600 [==============================] - 0s 26us/sample - loss: 0.1533 - mean_absolute_error: 0.3243 - val_loss: 0.1724 - val_mean_absolute_error: 0.3450
# Epoch 234/500
# 600/600 [==============================] - 0s 20us/sample - loss: 0.1534 - mean_absolute_error: 0.3246 - val_loss: 0.1728 - val_mean_absolute_error: 0.3465
# Epoch 235/500
# 600/600 [==============================] - 0s 26us/sample - loss: 0.1537 - mean_absolute_error: 0.3242 - val_loss: 0.1724 - val_mean_absolute_error: 0.3436
# Epoch 236/500
# 600/600 [==============================] - 0s 20us/sample - loss: 0.1534 - mean_absolute_error: 0.3238 - val_loss: 0.1723 - val_mean_absolute_error: 0.3445
# Epoch 237/500
# 600/600 [==============================] - 0s 25us/sample - loss: 0.1532 - mean_absolute_error: 0.3238 - val_loss: 0.1725 - val_mean_absolute_error: 0.3456
# Epoch 238/500
# 600/600 [==============================] - 0s 21us/sample - loss: 0.1530 - mean_absolute_error: 0.3232 - val_loss: 0.1723 - val_mean_absolute_error: 0.3431
# Epoch 239/500
# 600/600 [==============================] - 0s 25us/sample - loss: 0.1541 - mean_absolute_error: 0.3242 - val_loss: 0.1729 - val_mean_absolute_error: 0.3469
# Epoch 240/500
# 600/600 [==============================] - 0s 21us/sample - loss: 0.1533 - mean_absolute_error: 0.3237 - val_loss: 0.1722 - val_mean_absolute_error: 0.3439
# Epoch 241/500
# 600/600 [==============================] - 0s 21us/sample - loss: 0.1530 - mean_absolute_error: 0.3229 - val_loss: 0.1723 - val_mean_absolute_error: 0.3447
# Epoch 242/500
# 600/600 [==============================] - 0s 27us/sample - loss: 0.1529 - mean_absolute_error: 0.3232 - val_loss: 0.1723 - val_mean_absolute_error: 0.3449
# Epoch 243/500
# 600/600 [==============================] - 0s 21us/sample - loss: 0.1529 - mean_absolute_error: 0.3229 - val_loss: 0.1722 - val_mean_absolute_error: 0.3440
# Epoch 244/500
# 600/600 [==============================] - 0s 26us/sample - loss: 0.1528 - mean_absolute_error: 0.3236 - val_loss: 0.1736 - val_mean_absolute_error: 0.3483
# Epoch 245/500
# 600/600 [==============================] - 0s 19us/sample - loss: 0.1532 - mean_absolute_error: 0.3237 - val_loss: 0.1722 - val_mean_absolute_error: 0.3443
# Epoch 246/500
# 600/600 [==============================] - 0s 25us/sample - loss: 0.1530 - mean_absolute_error: 0.3234 - val_loss: 0.1723 - val_mean_absolute_error: 0.3452
# Epoch 247/500
# 600/600 [==============================] - 0s 20us/sample - loss: 0.1531 - mean_absolute_error: 0.3228 - val_loss: 0.1722 - val_mean_absolute_error: 0.3419
# Epoch 248/500
# 600/600 [==============================] - 0s 26us/sample - loss: 0.1528 - mean_absolute_error: 0.3228 - val_loss: 0.1726 - val_mean_absolute_error: 0.3462
# Epoch 249/500
# 600/600 [==============================] - 0s 23us/sample - loss: 0.1530 - mean_absolute_error: 0.3234 - val_loss: 0.1720 - val_mean_absolute_error: 0.3439
# Epoch 250/500
# 600/600 [==============================] - 0s 21us/sample - loss: 0.1524 - mean_absolute_error: 0.3228 - val_loss: 0.1725 - val_mean_absolute_error: 0.3461
# Epoch 251/500
# 600/600 [==============================] - 0s 22us/sample - loss: 0.1528 - mean_absolute_error: 0.3234 - val_loss: 0.1722 - val_mean_absolute_error: 0.3451
# Epoch 252/500
# 600/600 [==============================] - 0s 25us/sample - loss: 0.1524 - mean_absolute_error: 0.3225 - val_loss: 0.1720 - val_mean_absolute_error: 0.3437
# Epoch 253/500
# 600/600 [==============================] - 0s 25us/sample - loss: 0.1524 - mean_absolute_error: 0.3222 - val_loss: 0.1719 - val_mean_absolute_error: 0.3430
# Epoch 254/500
# 600/600 [==============================] - 0s 20us/sample - loss: 0.1529 - mean_absolute_error: 0.3228 - val_loss: 0.1721 - val_mean_absolute_error: 0.3446
# Epoch 255/500
# 600/600 [==============================] - 0s 25us/sample - loss: 0.1538 - mean_absolute_error: 0.3227 - val_loss: 0.1720 - val_mean_absolute_error: 0.3413
# Epoch 256/500
# 600/600 [==============================] - 0s 21us/sample - loss: 0.1521 - mean_absolute_error: 0.3218 - val_loss: 0.1724 - val_mean_absolute_error: 0.3454
# Epoch 257/500
# 600/600 [==============================] - 0s 25us/sample - loss: 0.1524 - mean_absolute_error: 0.3223 - val_loss: 0.1721 - val_mean_absolute_error: 0.3441
# Epoch 258/500
# 600/600 [==============================] - 0s 20us/sample - loss: 0.1522 - mean_absolute_error: 0.3219 - val_loss: 0.1719 - val_mean_absolute_error: 0.3434
# Epoch 259/500
# 600/600 [==============================] - 0s 25us/sample - loss: 0.1521 - mean_absolute_error: 0.3215 - val_loss: 0.1718 - val_mean_absolute_error: 0.3429
# Epoch 260/500
# 600/600 [==============================] - 0s 22us/sample - loss: 0.1522 - mean_absolute_error: 0.3215 - val_loss: 0.1719 - val_mean_absolute_error: 0.3432
# Epoch 261/500
# 600/600 [==============================] - 0s 20us/sample - loss: 0.1523 - mean_absolute_error: 0.3216 - val_loss: 0.1719 - val_mean_absolute_error: 0.3435
# Epoch 262/500
# 600/600 [==============================] - 0s 26us/sample - loss: 0.1521 - mean_absolute_error: 0.3214 - val_loss: 0.1717 - val_mean_absolute_error: 0.3424
# Epoch 263/500
# 600/600 [==============================] - 0s 24us/sample - loss: 0.1525 - mean_absolute_error: 0.3218 - val_loss: 0.1720 - val_mean_absolute_error: 0.3436
# Epoch 264/500
# 600/600 [==============================] - 0s 28us/sample - loss: 0.1523 - mean_absolute_error: 0.3209 - val_loss: 0.1720 - val_mean_absolute_error: 0.3397
# Epoch 265/500
# 600/600 [==============================] - 0s 20us/sample - loss: 0.1525 - mean_absolute_error: 0.3202 - val_loss: 0.1717 - val_mean_absolute_error: 0.3423
# Epoch 266/500
# 600/600 [==============================] - 0s 26us/sample - loss: 0.1522 - mean_absolute_error: 0.3218 - val_loss: 0.1732 - val_mean_absolute_error: 0.3464
# Epoch 267/500
# 600/600 [==============================] - 0s 19us/sample - loss: 0.1532 - mean_absolute_error: 0.3225 - val_loss: 0.1720 - val_mean_absolute_error: 0.3438
# Epoch 268/500
# 600/600 [==============================] - 0s 23us/sample - loss: 0.1539 - mean_absolute_error: 0.3217 - val_loss: 0.1720 - val_mean_absolute_error: 0.3395
# Epoch 269/500
# 600/600 [==============================] - 0s 21us/sample - loss: 0.1521 - mean_absolute_error: 0.3212 - val_loss: 0.1720 - val_mean_absolute_error: 0.3439
# Epoch 270/500
# 600/600 [==============================] - 0s 20us/sample - loss: 0.1522 - mean_absolute_error: 0.3216 - val_loss: 0.1724 - val_mean_absolute_error: 0.3452
# Epoch 271/500
# 600/600 [==============================] - 0s 26us/sample - loss: 0.1526 - mean_absolute_error: 0.3221 - val_loss: 0.1717 - val_mean_absolute_error: 0.3435
# Epoch 272/500
# 600/600 [==============================] - 0s 21us/sample - loss: 0.1521 - mean_absolute_error: 0.3212 - val_loss: 0.1715 - val_mean_absolute_error: 0.3423
# Epoch 273/500
# 600/600 [==============================] - 0s 26us/sample - loss: 0.1520 - mean_absolute_error: 0.3212 - val_loss: 0.1721 - val_mean_absolute_error: 0.3447
# Epoch 274/500
# 600/600 [==============================] - 0s 21us/sample - loss: 0.1519 - mean_absolute_error: 0.3212 - val_loss: 0.1715 - val_mean_absolute_error: 0.3428
# Epoch 275/500
# 600/600 [==============================] - 0s 26us/sample - loss: 0.1516 - mean_absolute_error: 0.3209 - val_loss: 0.1716 - val_mean_absolute_error: 0.3430
# Epoch 276/500
# 600/600 [==============================] - 0s 22us/sample - loss: 0.1524 - mean_absolute_error: 0.3217 - val_loss: 0.1717 - val_mean_absolute_error: 0.3437
# Epoch 277/500
# 600/600 [==============================] - 0s 25us/sample - loss: 0.1517 - mean_absolute_error: 0.3205 - val_loss: 0.1713 - val_mean_absolute_error: 0.3409
# Epoch 278/500
# 600/600 [==============================] - 0s 20us/sample - loss: 0.1516 - mean_absolute_error: 0.3200 - val_loss: 0.1713 - val_mean_absolute_error: 0.3414
# Epoch 279/500
# 600/600 [==============================] - 0s 20us/sample - loss: 0.1515 - mean_absolute_error: 0.3204 - val_loss: 0.1716 - val_mean_absolute_error: 0.3432
# Epoch 280/500
# 600/600 [==============================] - 0s 23us/sample - loss: 0.1516 - mean_absolute_error: 0.3207 - val_loss: 0.1716 - val_mean_absolute_error: 0.3432
# Epoch 281/500
# 600/600 [==============================] - 0s 20us/sample - loss: 0.1517 - mean_absolute_error: 0.3205 - val_loss: 0.1712 - val_mean_absolute_error: 0.3415
# Epoch 282/500
# 600/600 [==============================] - 0s 26us/sample - loss: 0.1517 - mean_absolute_error: 0.3199 - val_loss: 0.1712 - val_mean_absolute_error: 0.3414
# Epoch 283/500
# ...
# Epoch 407/500
# 600/600 [==============================] - 0s 21us/sample - loss: 0.1484 - mean_absolute_error: 0.3120 - val_loss: 0.1687 - val_mean_absolute_error: 0.3339
# Epoch 408/500
# 600/600 [==============================] - 0s 26us/sample - loss: 0.1482 - mean_absolute_error: 0.3121 - val_loss: 0.1690 - val_mean_absolute_error: 0.3353
# Epoch 409/500
# 600/600 [==============================] - 0s 20us/sample - loss: 0.1490 - mean_absolute_error: 0.3130 - val_loss: 0.1690 - val_mean_absolute_error: 0.3355
# Epoch 410/500
# 600/600 [==============================] - 0s 25us/sample - loss: 0.1486 - mean_absolute_error: 0.3128 - val_loss: 0.1691 - val_mean_absolute_error: 0.3361
# Epoch 411/500
# 600/600 [==============================] - 0s 21us/sample - loss: 0.1481 - mean_absolute_error: 0.3123 - val_loss: 0.1686 - val_mean_absolute_error: 0.3329
# Epoch 412/500
# 600/600 [==============================] - 0s 20us/sample - loss: 0.1491 - mean_absolute_error: 0.3119 - val_loss: 0.1686 - val_mean_absolute_error: 0.3333
# Epoch 413/500
# 600/600 [==============================] - 0s 22us/sample - loss: 0.1492 - mean_absolute_error: 0.3138 - val_loss: 0.1694 - val_mean_absolute_error: 0.3368
# Epoch 414/500
# 600/600 [==============================] - 0s 21us/sample - loss: 0.1479 - mean_absolute_error: 0.3119 - val_loss: 0.1686 - val_mean_absolute_error: 0.3326
# Epoch 415/500
# 600/600 [==============================] - 0s 26us/sample - loss: 0.1483 - mean_absolute_error: 0.3115 - val_loss: 0.1686 - val_mean_absolute_error: 0.3338
# Epoch 416/500
# 600/600 [==============================] - 0s 20us/sample - loss: 0.1487 - mean_absolute_error: 0.3126 - val_loss: 0.1693 - val_mean_absolute_error: 0.3362
# Epoch 417/500
# 600/600 [==============================] - 0s 26us/sample - loss: 0.1486 - mean_absolute_error: 0.3121 - val_loss: 0.1685 - val_mean_absolute_error: 0.3327
# Epoch 418/500
# 600/600 [==============================] - 0s 22us/sample - loss: 0.1481 - mean_absolute_error: 0.3117 - val_loss: 0.1686 - val_mean_absolute_error: 0.3344
# Epoch 419/500
# 600/600 [==============================] - 0s 25us/sample - loss: 0.1482 - mean_absolute_error: 0.3120 - val_loss: 0.1689 - val_mean_absolute_error: 0.3353
# Epoch 420/500
# 600/600 [==============================] - 0s 22us/sample - loss: 0.1487 - mean_absolute_error: 0.3124 - val_loss: 0.1685 - val_mean_absolute_error: 0.3336
# Epoch 421/500
# 600/600 [==============================] - 0s 21us/sample - loss: 0.1481 - mean_absolute_error: 0.3120 - val_loss: 0.1689 - val_mean_absolute_error: 0.3354
# Epoch 422/500
# 600/600 [==============================] - 0s 22us/sample - loss: 0.1482 - mean_absolute_error: 0.3122 - val_loss: 0.1686 - val_mean_absolute_error: 0.3343
# Epoch 423/500
# 600/600 [==============================] - 0s 20us/sample - loss: 0.1481 - mean_absolute_error: 0.3115 - val_loss: 0.1686 - val_mean_absolute_error: 0.3314
# Epoch 424/500
# 600/600 [==============================] - 0s 25us/sample - loss: 0.1498 - mean_absolute_error: 0.3135 - val_loss: 0.1689 - val_mean_absolute_error: 0.3354
# Epoch 425/500
# 600/600 [==============================] - 0s 20us/sample - loss: 0.1480 - mean_absolute_error: 0.3119 - val_loss: 0.1685 - val_mean_absolute_error: 0.3338
# Epoch 426/500
# 600/600 [==============================] - 0s 25us/sample - loss: 0.1493 - mean_absolute_error: 0.3116 - val_loss: 0.1685 - val_mean_absolute_error: 0.3316
# Epoch 427/500
# 600/600 [==============================] - 0s 21us/sample - loss: 0.1481 - mean_absolute_error: 0.3114 - val_loss: 0.1697 - val_mean_absolute_error: 0.3368
# Epoch 428/500
# 600/600 [==============================] - 0s 24us/sample - loss: 0.1480 - mean_absolute_error: 0.3114 - val_loss: 0.1684 - val_mean_absolute_error: 0.3327
# Epoch 429/500
# 600/600 [==============================] - 0s 23us/sample - loss: 0.1483 - mean_absolute_error: 0.3110 - val_loss: 0.1684 - val_mean_absolute_error: 0.3328
# Epoch 430/500
# 600/600 [==============================] - 0s 20us/sample - loss: 0.1479 - mean_absolute_error: 0.3111 - val_loss: 0.1687 - val_mean_absolute_error: 0.3341
# Epoch 431/500
# 600/600 [==============================] - 0s 23us/sample - loss: 0.1477 - mean_absolute_error: 0.3108 - val_loss: 0.1684 - val_mean_absolute_error: 0.3323
# Epoch 432/500
# 600/600 [==============================] - 0s 20us/sample - loss: 0.1479 - mean_absolute_error: 0.3105 - val_loss: 0.1683 - val_mean_absolute_error: 0.3319
# Epoch 433/500
# 600/600 [==============================] - 0s 26us/sample - loss: 0.1480 - mean_absolute_error: 0.3103 - val_loss: 0.1686 - val_mean_absolute_error: 0.3337
# Epoch 434/500
# 600/600 [==============================] - 0s 20us/sample - loss: 0.1480 - mean_absolute_error: 0.3112 - val_loss: 0.1688 - val_mean_absolute_error: 0.3345
# Epoch 435/500
# 600/600 [==============================] - 0s 24us/sample - loss: 0.1482 - mean_absolute_error: 0.3114 - val_loss: 0.1685 - val_mean_absolute_error: 0.3335
# Epoch 436/500
# 600/600 [==============================] - 0s 21us/sample - loss: 0.1477 - mean_absolute_error: 0.3102 - val_loss: 0.1684 - val_mean_absolute_error: 0.3308
# Epoch 437/500
# 600/600 [==============================] - 0s 25us/sample - loss: 0.1484 - mean_absolute_error: 0.3105 - val_loss: 0.1684 - val_mean_absolute_error: 0.3331
# Epoch 438/500
# 600/600 [==============================] - 0s 21us/sample - loss: 0.1483 - mean_absolute_error: 0.3117 - val_loss: 0.1689 - val_mean_absolute_error: 0.3346
# Epoch 439/500
# 600/600 [==============================] - 0s 19us/sample - loss: 0.1487 - mean_absolute_error: 0.3106 - val_loss: 0.1684 - val_mean_absolute_error: 0.3306
# Epoch 440/500
# 600/600 [==============================] - 0s 25us/sample - loss: 0.1486 - mean_absolute_error: 0.3110 - val_loss: 0.1693 - val_mean_absolute_error: 0.3356
# Epoch 441/500
# 600/600 [==============================] - 0s 20us/sample - loss: 0.1476 - mean_absolute_error: 0.3108 - val_loss: 0.1683 - val_mean_absolute_error: 0.3328
# Epoch 442/500
# 600/600 [==============================] - 0s 25us/sample - loss: 0.1477 - mean_absolute_error: 0.3101 - val_loss: 0.1682 - val_mean_absolute_error: 0.3313
# Epoch 443/500
# 600/600 [==============================] - 0s 20us/sample - loss: 0.1476 - mean_absolute_error: 0.3100 - val_loss: 0.1682 - val_mean_absolute_error: 0.3328
# Epoch 444/500
# 600/600 [==============================] - 0s 24us/sample - loss: 0.1476 - mean_absolute_error: 0.3103 - val_loss: 0.1685 - val_mean_absolute_error: 0.3340
# Epoch 445/500
# 600/600 [==============================] - 0s 21us/sample - loss: 0.1478 - mean_absolute_error: 0.3108 - val_loss: 0.1688 - val_mean_absolute_error: 0.3348
# Epoch 446/500
# 600/600 [==============================] - 0s 19us/sample - loss: 0.1477 - mean_absolute_error: 0.3105 - val_loss: 0.1682 - val_mean_absolute_error: 0.3328
# Epoch 447/500
# 600/600 [==============================] - 0s 24us/sample - loss: 0.1478 - mean_absolute_error: 0.3106 - val_loss: 0.1681 - val_mean_absolute_error: 0.3325
# Epoch 448/500
# 600/600 [==============================] - 0s 20us/sample - loss: 0.1480 - mean_absolute_error: 0.3107 - val_loss: 0.1683 - val_mean_absolute_error: 0.3334
# Epoch 449/500
# 600/600 [==============================] - 0s 25us/sample - loss: 0.1480 - mean_absolute_error: 0.3104 - val_loss: 0.1681 - val_mean_absolute_error: 0.3313
# Epoch 450/500
# 600/600 [==============================] - 0s 20us/sample - loss: 0.1481 - mean_absolute_error: 0.3110 - val_loss: 0.1690 - val_mean_absolute_error: 0.3349
# Epoch 451/500
# 600/600 [==============================] - 0s 23us/sample - loss: 0.1482 - mean_absolute_error: 0.3103 - val_loss: 0.1681 - val_mean_absolute_error: 0.3314
# Epoch 452/500
# 600/600 [==============================] - 0s 23us/sample - loss: 0.1476 - mean_absolute_error: 0.3102 - val_loss: 0.1687 - val_mean_absolute_error: 0.3342
# Epoch 453/500
# 600/600 [==============================] - 0s 20us/sample - loss: 0.1477 - mean_absolute_error: 0.3103 - val_loss: 0.1682 - val_mean_absolute_error: 0.3324
# Epoch 454/500
# 600/600 [==============================] - 0s 25us/sample - loss: 0.1483 - mean_absolute_error: 0.3101 - val_loss: 0.1680 - val_mean_absolute_error: 0.3313
# Epoch 455/500
# 600/600 [==============================] - 0s 20us/sample - loss: 0.1477 - mean_absolute_error: 0.3099 - val_loss: 0.1683 - val_mean_absolute_error: 0.3329
# Epoch 456/500
# 600/600 [==============================] - 0s 26us/sample - loss: 0.1477 - mean_absolute_error: 0.3102 - val_loss: 0.1684 - val_mean_absolute_error: 0.3334
# Epoch 457/500
# 600/600 [==============================] - 0s 20us/sample - loss: 0.1475 - mean_absolute_error: 0.3097 - val_loss: 0.1680 - val_mean_absolute_error: 0.3317
# Epoch 458/500
# 600/600 [==============================] - 0s 26us/sample - loss: 0.1476 - mean_absolute_error: 0.3098 - val_loss: 0.1681 - val_mean_absolute_error: 0.3324
# Epoch 459/500
# 600/600 [==============================] - 0s 21us/sample - loss: 0.1475 - mean_absolute_error: 0.3101 - val_loss: 0.1685 - val_mean_absolute_error: 0.3341
# Epoch 460/500
# 600/600 [==============================] - 0s 24us/sample - loss: 0.1475 - mean_absolute_error: 0.3102 - val_loss: 0.1682 - val_mean_absolute_error: 0.3331
# Epoch 461/500
# 600/600 [==============================] - 0s 21us/sample - loss: 0.1471 - mean_absolute_error: 0.3095 - val_loss: 0.1679 - val_mean_absolute_error: 0.3309
# Epoch 462/500
# 600/600 [==============================] - 0s 21us/sample - loss: 0.1476 - mean_absolute_error: 0.3096 - val_loss: 0.1680 - val_mean_absolute_error: 0.3329
# Epoch 463/500
# 600/600 [==============================] - 0s 25us/sample - loss: 0.1476 - mean_absolute_error: 0.3104 - val_loss: 0.1680 - val_mean_absolute_error: 0.3328
# Epoch 464/500
# 600/600 [==============================] - 0s 21us/sample - loss: 0.1478 - mean_absolute_error: 0.3096 - val_loss: 0.1679 - val_mean_absolute_error: 0.3310
# Epoch 465/500
# 600/600 [==============================] - 0s 26us/sample - loss: 0.1477 - mean_absolute_error: 0.3098 - val_loss: 0.1681 - val_mean_absolute_error: 0.3329
# Epoch 466/500
# 600/600 [==============================] - 0s 20us/sample - loss: 0.1473 - mean_absolute_error: 0.3095 - val_loss: 0.1682 - val_mean_absolute_error: 0.3327
# Epoch 467/500
# 600/600 [==============================] - 0s 26us/sample - loss: 0.1480 - mean_absolute_error: 0.3101 - val_loss: 0.1681 - val_mean_absolute_error: 0.3325
# Epoch 468/500
# 600/600 [==============================] - 0s 19us/sample - loss: 0.1488 - mean_absolute_error: 0.3094 - val_loss: 0.1680 - val_mean_absolute_error: 0.3292
# Epoch 469/500
# 600/600 [==============================] - 0s 25us/sample - loss: 0.1474 - mean_absolute_error: 0.3091 - val_loss: 0.1695 - val_mean_absolute_error: 0.3357
# Epoch 470/500
# 600/600 [==============================] - 0s 21us/sample - loss: 0.1478 - mean_absolute_error: 0.3102 - val_loss: 0.1678 - val_mean_absolute_error: 0.3315
# Epoch 471/500
# 600/600 [==============================] - 0s 19us/sample - loss: 0.1474 - mean_absolute_error: 0.3090 - val_loss: 0.1678 - val_mean_absolute_error: 0.3309
# Epoch 472/500
# 600/600 [==============================] - 0s 25us/sample - loss: 0.1484 - mean_absolute_error: 0.3088 - val_loss: 0.1678 - val_mean_absolute_error: 0.3301
# Epoch 473/500
# 600/600 [==============================] - 0s 19us/sample - loss: 0.1482 - mean_absolute_error: 0.3097 - val_loss: 0.1688 - val_mean_absolute_error: 0.3346
# Epoch 474/500
# 600/600 [==============================] - 0s 26us/sample - loss: 0.1472 - mean_absolute_error: 0.3096 - val_loss: 0.1677 - val_mean_absolute_error: 0.3307
# Epoch 475/500
# 600/600 [==============================] - 0s 21us/sample - loss: 0.1485 - mean_absolute_error: 0.3090 - val_loss: 0.1677 - val_mean_absolute_error: 0.3303
# Epoch 476/500
# 600/600 [==============================] - 0s 24us/sample - loss: 0.1477 - mean_absolute_error: 0.3098 - val_loss: 0.1697 - val_mean_absolute_error: 0.3360
# Epoch 477/500
# 600/600 [==============================] - 0s 21us/sample - loss: 0.1483 - mean_absolute_error: 0.3104 - val_loss: 0.1680 - val_mean_absolute_error: 0.3327
# Epoch 478/500
# 600/600 [==============================] - 0s 20us/sample - loss: 0.1473 - mean_absolute_error: 0.3095 - val_loss: 0.1679 - val_mean_absolute_error: 0.3323
# Epoch 479/500
# 600/600 [==============================] - 0s 26us/sample - loss: 0.1475 - mean_absolute_error: 0.3090 - val_loss: 0.1677 - val_mean_absolute_error: 0.3300
# Epoch 480/500
# 600/600 [==============================] - 0s 20us/sample - loss: 0.1472 - mean_absolute_error: 0.3085 - val_loss: 0.1680 - val_mean_absolute_error: 0.3326
# Epoch 481/500
# 600/600 [==============================] - 0s 24us/sample - loss: 0.1474 - mean_absolute_error: 0.3091 - val_loss: 0.1677 - val_mean_absolute_error: 0.3315
# Epoch 482/500
# 600/600 [==============================] - 0s 21us/sample - loss: 0.1475 - mean_absolute_error: 0.3091 - val_loss: 0.1683 - val_mean_absolute_error: 0.3331
# Epoch 483/500
# 600/600 [==============================] - 0s 26us/sample - loss: 0.1470 - mean_absolute_error: 0.3087 - val_loss: 0.1676 - val_mean_absolute_error: 0.3304
# Epoch 484/500
# 600/600 [==============================] - 0s 20us/sample - loss: 0.1473 - mean_absolute_error: 0.3086 - val_loss: 0.1676 - val_mean_absolute_error: 0.3306
# Epoch 485/500
# 600/600 [==============================] - 0s 25us/sample - loss: 0.1481 - mean_absolute_error: 0.3084 - val_loss: 0.1676 - val_mean_absolute_error: 0.3296
# Epoch 486/500
# 600/600 [==============================] - 0s 22us/sample - loss: 0.1486 - mean_absolute_error: 0.3100 - val_loss: 0.1694 - val_mean_absolute_error: 0.3352
# Epoch 487/500
# 600/600 [==============================] - 0s 20us/sample - loss: 0.1471 - mean_absolute_error: 0.3095 - val_loss: 0.1675 - val_mean_absolute_error: 0.3308
# Epoch 488/500
# 600/600 [==============================] - 0s 26us/sample - loss: 0.1490 - mean_absolute_error: 0.3083 - val_loss: 0.1679 - val_mean_absolute_error: 0.3285
# Epoch 489/500
# 600/600 [==============================] - 0s 21us/sample - loss: 0.1482 - mean_absolute_error: 0.3099 - val_loss: 0.1697 - val_mean_absolute_error: 0.3361
# Epoch 490/500
# 600/600 [==============================] - 0s 26us/sample - loss: 0.1476 - mean_absolute_error: 0.3097 - val_loss: 0.1675 - val_mean_absolute_error: 0.3315
# Epoch 491/500
# 600/600 [==============================] - 0s 20us/sample - loss: 0.1470 - mean_absolute_error: 0.3086 - val_loss: 0.1675 - val_mean_absolute_error: 0.3313
# Epoch 492/500
# 600/600 [==============================] - 0s 27us/sample - loss: 0.1471 - mean_absolute_error: 0.3087 - val_loss: 0.1675 - val_mean_absolute_error: 0.3303
# Epoch 493/500
# 600/600 [==============================] - 0s 21us/sample - loss: 0.1471 - mean_absolute_error: 0.3087 - val_loss: 0.1677 - val_mean_absolute_error: 0.3321
# Epoch 494/500
# 600/600 [==============================] - 0s 25us/sample - loss: 0.1470 - mean_absolute_error: 0.3088 - val_loss: 0.1677 - val_mean_absolute_error: 0.3322
# Epoch 495/500
# 600/600 [==============================] - 0s 21us/sample - loss: 0.1470 - mean_absolute_error: 0.3089 - val_loss: 0.1681 - val_mean_absolute_error: 0.3333
# Epoch 496/500
# 600/600 [==============================] - 0s 21us/sample - loss: 0.1474 - mean_absolute_error: 0.3094 - val_loss: 0.1679 - val_mean_absolute_error: 0.3328
# Epoch 497/500
# 600/600 [==============================] - 0s 23us/sample - loss: 0.1485 - mean_absolute_error: 0.3091 - val_loss: 0.1676 - val_mean_absolute_error: 0.3292
# Epoch 498/500
# 600/600 [==============================] - 0s 20us/sample - loss: 0.1480 - mean_absolute_error: 0.3102 - val_loss: 0.1685 - val_mean_absolute_error: 0.3342
# Epoch 499/500
# 600/600 [==============================] - 0s 25us/sample - loss: 0.1479 - mean_absolute_error: 0.3097 - val_loss: 0.1680 - val_mean_absolute_error: 0.3328
# Epoch 500/500
# 600/600 [==============================] - 0s 19us/sample - loss: 0.1487 - mean_absolute_error: 0.3090 - val_loss: 0.1679 - val_mean_absolute_error: 0.3278

# %% [markdown]
# ### 3. Plot Metrics

# %% [markdown]
# **1. Mean Squared Error**
#
# During training, the model's performance is constantly being measured against both our training data and the validation data that we set aside earlier. Training produces a log of data that tells us how the model's performance changed over the course of the training process.
#
# The following cells will display some of that data in a graphical form:

# %%
# Draw a graph of the loss, which is the distance between
# the predicted and actual values during training and validation.
loss = history_1.history['loss']
val_loss = history_1.history['val_loss']

epochs = range(1, len(loss) + 1)

plt.plot(epochs, loss, 'g.', label='Training loss')
plt.plot(epochs, val_loss, 'b', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %% [markdown]
# The graph shows the _loss_ (or the difference between the model's predictions and the actual data) for each epoch. There are several ways to calculate loss, and the method we have used is _mean squared error_. There is a distinct loss value given for the training and the validation data.
#
# As we can see, the amount of loss rapidly decreases over the first 25 epochs, before flattening out. This means that the model is improving and producing more accurate predictions!
#
# Our goal is to stop training when either the model is no longer improving, or when the _training loss_ is less than the _validation loss_, which would mean that the model has learned to predict the training data so well that it can no longer generalize to new data.
#
# To make the flatter part of the graph more readable, let's skip the first 50 epochs:

# %%
# Exclude the first few epochs so the graph is easier to read
SKIP = 50

plt.plot(epochs[SKIP:], loss[SKIP:], 'g.', label='Training loss')
plt.plot(epochs[SKIP:], val_loss[SKIP:], 'b.', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %% [markdown]
# From the plot, we can see that loss continues to reduce until around 200 epochs, at which point it is mostly stable. This means that there's no need to train our network beyond 200 epochs.
#
# However, we can also see that the lowest loss value is still around 0.155. This means that our network's predictions are off by an average of ~15%. In addition, the validation loss values jump around a lot, and is sometimes even higher.
#
# **2. Mean Absolute Error**
#
# To gain more insight into our model's performance we can plot some more data. This time, we'll plot the _mean absolute error_, which is another way of measuring how far the network's predictions are from the actual numbers:

# %%
plt.clf()

# Draw a graph of mean absolute error, which is another way of
# measuring the amount of error in the prediction.
mae = history_1.history['mean_absolute_error']
val_mae = history_1.history['val_mean_absolute_error']

plt.plot(epochs[SKIP:], mae[SKIP:], 'g.', label='Training MAE')
plt.plot(epochs[SKIP:], val_mae[SKIP:], 'b.', label='Validation MAE')
plt.title('Training and validation mean absolute error')
plt.xlabel('Epochs')
plt.ylabel('MAE')
plt.legend()
plt.show()

# %% [markdown]
# This graph of _mean absolute error_ tells another story. We can see that training data shows consistently lower error than validation data, which means that the network may have _overfit_, or learned the training data so rigidly that it can't make effective predictions about new data.
#
# In addition, the mean absolute error values are quite high, ~0.305 at best, which means some of the model's predictions are at least 30% off. A 30% error means we are very far from accurately modelling the sine wave function.
#
# **3. Actual vs Predicted Outputs**
#
# To get more insight into what is happening, let's check its predictions against the test dataset we set aside earlier:

# %%
# Calculate and print the loss on our test dataset
loss = model_1.evaluate(x_test, y_test)

# Make predictions based on our test dataset
predictions = model_1.predict(x_test)

# Graph the predictions against the actual values
plt.clf()
plt.title('Comparison of predictions and actual values')
plt.plot(x_test, y_test, 'b.', label='Actual')
plt.plot(x_test, predictions, 'r.', label='Predicted')
plt.legend()
plt.show()
# Out:
# 200/200 [==============================] - 0s 27us/sample - loss: 0.1460 - mean_absolute_error: 0.3073

# %% [markdown]
# Oh dear! The graph makes it clear that our network has learned to approximate the sine function in a very limited way.
#
# The rigidity of this fit suggests that the model does not have enough capacity to learn the full complexity of the sine wave function, so it's only able to approximate it in an overly simplistic way. By making our model bigger, we should be able to improve its performance.

# %% [markdown]
# ## Training a Larger Model

# %% [markdown]
# ### 1. Design the Model
# To make our model bigger, let's add an additional layer of neurons. The following cell redefines our model in the same way as earlier, but with 16 neurons in the first layer and an additional layer of 16 neurons in the middle:

# %%
model_2 = tf.keras.Sequential()

# First layer takes a scalar input and feeds it through 16 "neurons". The
# neurons decide whether to activate based on the 'relu' activation function.
model_2.add(keras.layers.Dense(16, activation='relu', input_shape=(1,)))

# The new second layer may help the network learn more complex representations
model_2.add(keras.layers.Dense(16, activation='relu'))

# Final layer is a single neuron, since we want to output a single value
model_2.add(keras.layers.Dense(1))

# Compile the model using a standard optimizer and loss function for regression
model_2.compile(optimizer='adam', loss='mse', metrics=['mae'])

# %% [markdown]
# ### 2. Train the Model ###
#
# We'll now train the new model.

# %%
history_2 = model_2.fit(x_train, y_train, epochs=500, batch_size=64,
                    validation_data=(x_validate, y_validate))
# Out:
# Train on 600 samples, validate on 200 samples
# Epoch 1/500
# 600/600 [==============================] - 0s 138us/sample - loss: 0.9532 - mean_absolute_error: 0.8469 - val_loss: 0.7688 - val_mean_absolute_error: 0.7962
# Epoch 2/500
# 600/600 [==============================] - 0s 30us/sample - loss: 0.6362 - mean_absolute_error: 0.7155 - val_loss: 0.5700 - val_mean_absolute_error: 0.6831
# Epoch 3/500
# 600/600 [==============================] - 0s 25us/sample - loss: 0.5132 - mean_absolute_error: 0.6385 - val_loss: 0.5010 - val_mean_absolute_error: 0.6189
# Epoch 4/500
# 600/600 [==============================] - 0s 31us/sample - loss: 0.4671 - mean_absolute_error: 0.5956 - val_loss: 0.4757 - val_mean_absolute_error: 0.5950
# Epoch 5/500
# 600/600 [==============================] - 0s 27us/sample - loss: 0.4493 - mean_absolute_error: 0.5734 - val_loss: 0.4579 - val_mean_absolute_error: 0.5823
# Epoch 6/500
# 600/600 [==============================] - 0s 29us/sample - loss: 0.4316 - mean_absolute_error: 0.5610 - val_loss: 0.4385 - val_mean_absolute_error: 0.5715
# Epoch 7/500
# 600/600 [==============================] - 0s 29us/sample - loss: 0.4125 - mean_absolute_error: 0.5498 - val_loss: 0.4208 - val_mean_absolute_error: 0.5609
# Epoch 8/500
# 600/600 [==============================] - 0s 26us/sample - loss: 0.3954 - mean_absolute_error: 0.5384 - val_loss: 0.4039 - val_mean_absolute_error: 0.5501
# Epoch 9/500
# 600/600 [==============================] - 0s 30us/sample - loss: 0.3792 - mean_absolute_error: 0.5274 - val_loss: 0.3877 - val_mean_absolute_error: 0.5400
# Epoch 10/500
# 600/600 [==============================] - 0s 28us/sample - loss: 0.3636 - mean_absolute_error: 0.5162 - val_loss: 0.3716 - val_mean_absolute_error: 0.5290
# Epoch 11/500
# 600/600 [==============================] - 0s 29us/sample - loss: 0.3484 - mean_absolute_error: 0.5035 - val_loss: 0.3563 - val_mean_absolute_error: 0.5179
# Epoch 12/500
# 600/600 [==============================] - 0s 25us/sample - loss: 0.3340 - mean_absolute_error: 0.4924 - val_loss: 0.3419 - val_mean_absolute_error: 0.5089
# Epoch 13/500
# 600/600 [==============================] - 0s 30us/sample - loss: 0.3202 - mean_absolute_error: 0.4825 - val_loss: 0.3282 - val_mean_absolute_error: 0.5000
# Epoch 14/500
# 600/600 [==============================] - 0s 27us/sample - loss: 0.3076 - mean_absolute_error: 0.4749 - val_loss: 0.3164 - val_mean_absolute_error: 0.4934
# Epoch 15/500
# 600/600 [==============================] - 0s 28us/sample - loss: 0.2947 - mean_absolute_error: 0.4651 - val_loss: 0.3029 - val_mean_absolute_error: 0.4831
# Epoch 16/500
# 600/600 [==============================] - 0s 30us/sample - loss: 0.2823 - mean_absolute_error: 0.4540 - val_loss: 0.2908 - val_mean_absolute_error: 0.4736
# Epoch 17/500
# 600/600 [==============================] - 0s 25us/sample - loss: 0.2718 - mean_absolute_error: 0.4446 - val_loss: 0.2797 - val_mean_absolute_error: 0.4647
# Epoch 18/500
# 600/600 [==============================] - 0s 36us/sample - loss: 0.2606 - mean_absolute_error: 0.4364 - val_loss: 0.2698 - val_mean_absolute_error: 0.4579
# Epoch 19/500
# 600/600 [==============================] - 0s 23us/sample - loss: 0.2508 - mean_absolute_error: 0.4291 - val_loss: 0.2605 - val_mean_absolute_error: 0.4509
# Epoch 20/500
# 600/600 [==============================] - 0s 33us/sample - loss: 0.2416 - mean_absolute_error: 0.4217 - val_loss: 0.2512 - val_mean_absolute_error: 0.4429
# Epoch 21/500
# 600/600 [==============================] - 0s 24us/sample - loss: 0.2326 - mean_absolute_error: 0.4145 - val_loss: 0.2430 - val_mean_absolute_error: 0.4362
# Epoch 22/500
# 600/600 [==============================] - 0s 32us/sample - loss: 0.2244 - mean_absolute_error: 0.4071 - val_loss: 0.2349 - val_mean_absolute_error: 0.4281
# Epoch 23/500
# 600/600 [==============================] - 0s 24us/sample - loss: 0.2178 - mean_absolute_error: 0.4020 - val_loss: 0.2281 - val_mean_absolute_error: 0.4237
# Epoch 24/500
# 600/600 [==============================] - 0s 27us/sample - loss: 0.2096 - mean_absolute_error: 0.3945 - val_loss: 0.2214 - val_mean_absolute_error: 0.4169
# Epoch 25/500
# 600/600 [==============================] - 0s 26us/sample - loss: 0.2030 - mean_absolute_error: 0.3885 - val_loss: 0.2157 - val_mean_absolute_error: 0.4119
# Epoch 26/500
# 600/600 [==============================] - 0s 27us/sample - loss: 0.1974 - mean_absolute_error: 0.3832 - val_loss: 0.2103 - val_mean_absolute_error: 0.4067
# Epoch 27/500
# 600/600 [==============================] - 0s 33us/sample - loss: 0.1918 - mean_absolute_error: 0.3778 - val_loss: 0.2051 - val_mean_absolute_error: 0.4011
# Epoch 28/500
# 600/600 [==============================] - 0s 25us/sample - loss: 0.1864 - mean_absolute_error: 0.3719 - val_loss: 0.2006 - val_mean_absolute_error: 0.3958
# Epoch 29/500
# 600/600 [==============================] - 0s 31us/sample - loss: 0.1821 - mean_absolute_error: 0.3672 - val_loss: 0.1970 - val_mean_absolute_error: 0.3920
# Epoch 30/500
# 600/600 [==============================] - 0s 24us/sample - loss: 0.1782 - mean_absolute_error: 0.3627 - val_loss: 0.1935 - val_mean_absolute_error: 0.3878
# Epoch 31/500
# 600/600 [==============================] - 0s 32us/sample - loss: 0.1743 - mean_absolute_error: 0.3578 - val_loss: 0.1901 - val_mean_absolute_error: 0.3829
# Epoch 32/500
# 600/600 [==============================] - 0s 24us/sample - loss: 0.1709 - mean_absolute_error: 0.3534 - val_loss: 0.1869 - val_mean_absolute_error: 0.3777
# Epoch 33/500
# 600/600 [==============================] - 0s 32us/sample - loss: 0.1688 - mean_absolute_error: 0.3496 - val_loss: 0.1844 - val_mean_absolute_error: 0.3737
# Epoch 34/500
# 600/600 [==============================] - 0s 21us/sample - loss: 0.1671 - mean_absolute_error: 0.3478 - val_loss: 0.1844 - val_mean_absolute_error: 0.3755
# Epoch 35/500
# 600/600 [==============================] - 0s 32us/sample - loss: 0.1638 - mean_absolute_error: 0.3434 - val_loss: 0.1802 - val_mean_absolute_error: 0.3653
# Epoch 36/500
# 600/600 [==============================] - 0s 24us/sample - loss: 0.1614 - mean_absolute_error: 0.3393 - val_loss: 0.1787 - val_mean_absolute_error: 0.3648
# Epoch 37/500
# 600/600 [==============================] - 0s 36us/sample - loss: 0.1593 - mean_absolute_error: 0.3358 - val_loss: 0.1770 - val_mean_absolute_error: 0.3613
# Epoch 38/500
# 600/600 [==============================] - 0s 28us/sample - loss: 0.1594 - mean_absolute_error: 0.3337 - val_loss: 0.1758 - val_mean_absolute_error: 0.3560
# Epoch 39/500
# 600/600 [==============================] - 0s 23us/sample - loss: 0.1558 - mean_absolute_error: 0.3297 - val_loss: 0.1765 - val_mean_absolute_error: 0.3605
# Epoch 40/500
# 600/600 [==============================] - 0s 30us/sample - loss: 0.1552 - mean_absolute_error: 0.3289 - val_loss: 0.1738 - val_mean_absolute_error: 0.3547
# Epoch 41/500
# 600/600 [==============================] - 0s 23us/sample - loss: 0.1548 - mean_absolute_error: 0.3261 - val_loss: 0.1726 - val_mean_absolute_error: 0.3490
# Epoch 42/500
# 600/600 [==============================] - 0s 29us/sample - loss: 0.1529 - mean_absolute_error: 0.3234 - val_loss: 0.1728 - val_mean_absolute_error: 0.3520
# Epoch 43/500
# 600/600 [==============================] - 0s 23us/sample - loss: 0.1519 - mean_absolute_error: 0.3216 - val_loss: 0.1711 - val_mean_absolute_error: 0.3466
# Epoch 44/500
# 600/600 [==============================] - 0s 30us/sample - loss: 0.1510 - mean_absolute_error: 0.3189 - val_loss: 0.1707 - val_mean_absolute_error: 0.3460
# Epoch 45/500
# 600/600 [==============================] - 0s 23us/sample - loss: 0.1510 - mean_absolute_error: 0.3190 - val_loss: 0.1702 - val_mean_absolute_error: 0.3443
# Epoch 46/500
# 600/600 [==============================] - 0s 29us/sample - loss: 0.1514 - mean_absolute_error: 0.3162 - val_loss: 0.1695 - val_mean_absolute_error: 0.3409
# Epoch 47/500
# 600/600 [==============================] - 0s 24us/sample - loss: 0.1488 - mean_absolute_error: 0.3144 - val_loss: 0.1695 - val_mean_absolute_error: 0.3419
# Epoch 48/500
# 600/600 [==============================] - 0s 27us/sample - loss: 0.1483 - mean_absolute_error: 0.3131 - val_loss: 0.1687 - val_mean_absolute_error: 0.3389
# Epoch 49/500
# 600/600 [==============================] - 0s 24us/sample - loss: 0.1481 - mean_absolute_error: 0.3112 - val_loss: 0.1683 - val_mean_absolute_error: 0.3370
# Epoch 50/500
# 600/600 [==============================] - 0s 26us/sample - loss: 0.1473 - mean_absolute_error: 0.3101 - val_loss: 0.1687 - val_mean_absolute_error: 0.3383
# Epoch 51/500
# 600/600 [==============================] - 0s 24us/sample - loss: 0.1476 - mean_absolute_error: 0.3094 - val_loss: 0.1676 - val_mean_absolute_error: 0.3334
# Epoch 52/500
# 600/600 [==============================] - 0s 26us/sample - loss: 0.1470 - mean_absolute_error: 0.3070 - val_loss: 0.1672 - val_mean_absolute_error: 0.3346
# Epoch 53/500
# 600/600 [==============================] - 0s 23us/sample - loss: 0.1461 - mean_absolute_error: 0.3068 - val_loss: 0.1661 - val_mean_absolute_error: 0.3306
# Epoch 54/500
# 600/600 [==============================] - 0s 27us/sample - loss: 0.1464 - mean_absolute_error: 0.3063 - val_loss: 0.1658 - val_mean_absolute_error: 0.3310
# Epoch 55/500
# 600/600 [==============================] - 0s 23us/sample - loss: 0.1454 - mean_absolute_error: 0.3033 - val_loss: 0.1652 - val_mean_absolute_error: 0.3280
# Epoch 56/500
# 600/600 [==============================] - 0s 27us/sample - loss: 0.1449 - mean_absolute_error: 0.3026 - val_loss: 0.1654 - val_mean_absolute_error: 0.3301
# Epoch 57/500
# 600/600 [==============================] - 0s 24us/sample - loss: 0.1453 - mean_absolute_error: 0.3026 - val_loss: 0.1646 - val_mean_absolute_error: 0.3278
# Epoch 58/500
# 600/600 [==============================] - 0s 26us/sample - loss: 0.1438 - mean_absolute_error: 0.3017 - val_loss: 0.1649 - val_mean_absolute_error: 0.3292
# Epoch 59/500
# 600/600 [==============================] - 0s 23us/sample - loss: 0.1460 - mean_absolute_error: 0.3013 - val_loss: 0.1637 - val_mean_absolute_error: 0.3240
# Epoch 60/500
# 600/600 [==============================] - 0s 26us/sample - loss: 0.1426 - mean_absolute_error: 0.2989 - val_loss: 0.1644 - val_mean_absolute_error: 0.3278
# Epoch 61/500
# 600/600 [==============================] - 0s 22us/sample - loss: 0.1431 - mean_absolute_error: 0.2985 - val_loss: 0.1630 - val_mean_absolute_error: 0.3218
# Epoch 62/500
# 600/600 [==============================] - 0s 23us/sample - loss: 0.1427 - mean_absolute_error: 0.2979 - val_loss: 0.1625 - val_mean_absolute_error: 0.3215
# Epoch 63/500
# 600/600 [==============================] - 0s 22us/sample - loss: 0.1425 - mean_absolute_error: 0.2967 - val_loss: 0.1623 - val_mean_absolute_error: 0.3219
# Epoch 64/500
# 600/600 [==============================] - 0s 24us/sample - loss: 0.1414 - mean_absolute_error: 0.2965 - val_loss: 0.1620 - val_mean_absolute_error: 0.3213
# Epoch 65/500
# 600/600 [==============================] - 0s 25us/sample - loss: 0.1420 - mean_absolute_error: 0.2952 - val_loss: 0.1614 - val_mean_absolute_error: 0.3194
# Epoch 66/500
# 600/600 [==============================] - 0s 22us/sample - loss: 0.1408 - mean_absolute_error: 0.2957 - val_loss: 0.1612 - val_mean_absolute_error: 0.3204
# Epoch 67/500
# 600/600 [==============================] - 0s 26us/sample - loss: 0.1409 - mean_absolute_error: 0.2956 - val_loss: 0.1606 - val_mean_absolute_error: 0.3191
# Epoch 68/500
# 600/600 [==============================] - 0s 21us/sample - loss: 0.1401 - mean_absolute_error: 0.2940 - val_loss: 0.1601 - val_mean_absolute_error: 0.3180
# Epoch 69/500
# 600/600 [==============================] - 0s 27us/sample - loss: 0.1409 - mean_absolute_error: 0.2947 - val_loss: 0.1597 - val_mean_absolute_error: 0.3172
# Epoch 70/500
# 600/600 [==============================] - 0s 22us/sample - loss: 0.1410 - mean_absolute_error: 0.2920 - val_loss: 0.1592 - val_mean_absolute_error: 0.3158
# Epoch 71/500
# 600/600 [==============================] - 0s 26us/sample - loss: 0.1384 - mean_absolute_error: 0.2922 - val_loss: 0.1596 - val_mean_absolute_error: 0.3191
# Epoch 72/500
# 600/600 [==============================] - 0s 21us/sample - loss: 0.1399 - mean_absolute_error: 0.2933 - val_loss: 0.1584 - val_mean_absolute_error: 0.3141
# Epoch 73/500
# 600/600 [==============================] - 0s 26us/sample - loss: 0.1382 - mean_absolute_error: 0.2916 - val_loss: 0.1582 - val_mean_absolute_error: 0.3162
# Epoch 74/500
# 600/600 [==============================] - 0s 22us/sample - loss: 0.1383 - mean_absolute_error: 0.2911 - val_loss: 0.1575 - val_mean_absolute_error: 0.3152
# Epoch 75/500
# 600/600 [==============================] - 0s 22us/sample - loss: 0.1376 - mean_absolute_error: 0.2901 - val_loss: 0.1568 - val_mean_absolute_error: 0.3128
# Epoch 76/500
# 600/600 [==============================] - 0s 22us/sample - loss: 0.1366 - mean_absolute_error: 0.2895 - val_loss: 0.1567 - val_mean_absolute_error: 0.3147
# Epoch 77/500
# 600/600 [==============================] - 0s 24us/sample - loss: 0.1360 - mean_absolute_error: 0.2892 - val_loss: 0.1557 - val_mean_absolute_error: 0.3115
# Epoch 78/500
# 600/600 [==============================] - 0s 25us/sample - loss: 0.1364 - mean_absolute_error: 0.2875 - val_loss: 0.1553 - val_mean_absolute_error: 0.3095
# Epoch 79/500
# 600/600 [==============================] - 0s 21us/sample - loss: 0.1358 - mean_absolute_error: 0.2889 - val_loss: 0.1560 - val_mean_absolute_error: 0.3150
# Epoch 80/500
# 600/600 [==============================] - 0s 27us/sample - loss: 0.1358 - mean_absolute_error: 0.2881 - val_loss: 0.1540 - val_mean_absolute_error: 0.3090
# Epoch 81/500
# 600/600 [==============================] - 0s 23us/sample - loss: 0.1339 - mean_absolute_error: 0.2860 - val_loss: 0.1539 - val_mean_absolute_error: 0.3111
# Epoch 82/500
# 600/600 [==============================] - 0s 26us/sample - loss: 0.1338 - mean_absolute_error: 0.2859 - val_loss: 0.1529 - val_mean_absolute_error: 0.3085
# Epoch 83/500
# 600/600 [==============================] - 0s 120us/sample - loss: 0.1337 - mean_absolute_error: 0.2849 - val_loss: 0.1521 - val_mean_absolute_error: 0.3075
# Epoch 84/500
# 600/600 [==============================] - 0s 27us/sample - loss: 0.1330 - mean_absolute_error: 0.2846 - val_loss: 0.1517 - val_mean_absolute_error: 0.3076
# Epoch 85/500
# 600/600 [==============================] - 0s 23us/sample - loss: 0.1326 - mean_absolute_error: 0.2849 - val_loss: 0.1517 - val_mean_absolute_error: 0.3092
# Epoch 86/500
# 600/600 [==============================] - 0s 25us/sample - loss: 0.1314 - mean_absolute_error: 0.2831 - val_loss: 0.1501 - val_mean_absolute_error: 0.3040
# Epoch 87/500
# 600/600 [==============================] - 0s 25us/sample - loss: 0.1329 - mean_absolute_error: 0.2827 - val_loss: 0.1495 - val_mean_absolute_error: 0.3060
# Epoch 88/500
# 600/600 [==============================] - 0s 23us/sample - loss: 0.1304 - mean_absolute_error: 0.2822 - val_loss: 0.1486 - val_mean_absolute_error: 0.3043
# Epoch 89/500
# 600/600 [==============================] - 0s 27us/sample - loss: 0.1299 - mean_absolute_error: 0.2821 - val_loss: 0.1482 - val_mean_absolute_error: 0.3045
# Epoch 90/500
# 600/600 [==============================] - 0s 25us/sample - loss: 0.1288 - mean_absolute_error: 0.2797 - val_loss: 0.1474 - val_mean_absolute_error: 0.2995
# Epoch 91/500
# 600/600 [==============================] - 0s 26us/sample - loss: 0.1302 - mean_absolute_error: 0.2820 - val_loss: 0.1467 - val_mean_absolute_error: 0.3028
# Epoch 92/500
# 600/600 [==============================] - 0s 22us/sample - loss: 0.1279 - mean_absolute_error: 0.2777 - val_loss: 0.1456 - val_mean_absolute_error: 0.2984
# Epoch 93/500
# 600/600 [==============================] - 0s 27us/sample - loss: 0.1273 - mean_absolute_error: 0.2783 - val_loss: 0.1450 - val_mean_absolute_error: 0.3005
# Epoch 94/500
# 600/600 [==============================] - 0s 21us/sample - loss: 0.1259 - mean_absolute_error: 0.2766 - val_loss: 0.1440 - val_mean_absolute_error: 0.2976
# Epoch 95/500
# 600/600 [==============================] - 0s 26us/sample - loss: 0.1261 - mean_absolute_error: 0.2773 - val_loss: 0.1437 - val_mean_absolute_error: 0.3003
# Epoch 96/500
# 600/600 [==============================] - 0s 21us/sample - loss: 0.1275 - mean_absolute_error: 0.2757 - val_loss: 0.1422 - val_mean_absolute_error: 0.2958
# Epoch 97/500
# 600/600 [==============================] - 0s 26us/sample - loss: 0.1236 - mean_absolute_error: 0.2740 - val_loss: 0.1425 - val_mean_absolute_error: 0.3000
# Epoch 98/500
# 600/600 [==============================] - 0s 23us/sample - loss: 0.1251 - mean_absolute_error: 0.2768 - val_loss: 0.1410 - val_mean_absolute_error: 0.2972
# Epoch 99/500
# 600/600 [==============================] - 0s 27us/sample - loss: 0.1230 - mean_absolute_error: 0.2714 - val_loss: 0.1400 - val_mean_absolute_error: 0.2914
# Epoch 100/500
# 600/600 [==============================] - 0s 23us/sample - loss: 0.1218 - mean_absolute_error: 0.2723 - val_loss: 0.1395 - val_mean_absolute_error: 0.2964
# Epoch 101/500
# 600/600 [==============================] - 0s 26us/sample - loss: 0.1204 - mean_absolute_error: 0.2708 - val_loss: 0.1378 - val_mean_absolute_error: 0.2905
# Epoch 102/500
# 600/600 [==============================] - 0s 23us/sample - loss: 0.1214 - mean_absolute_error: 0.2692 - val_loss: 0.1371 - val_mean_absolute_error: 0.2911
# Epoch 103/500
# 600/600 [==============================] - 0s 27us/sample - loss: 0.1190 - mean_absolute_error: 0.2692 - val_loss: 0.1368 - val_mean_absolute_error: 0.2930
# Epoch 104/500
# 600/600 [==============================] - 0s 22us/sample - loss: 0.1192 - mean_absolute_error: 0.2688 - val_loss: 0.1351 - val_mean_absolute_error: 0.2863
# Epoch 105/500
# 600/600 [==============================] - 0s 27us/sample - loss: 0.1189 - mean_absolute_error: 0.2688 - val_loss: 0.1347 - val_mean_absolute_error: 0.2909
# Epoch 106/500
# 600/600 [==============================] - 0s 22us/sample - loss: 0.1181 - mean_absolute_error: 0.2657 - val_loss: 0.1332 - val_mean_absolute_error: 0.2860
# Epoch 107/500
# 600/600 [==============================] - 0s 22us/sample - loss: 0.1156 - mean_absolute_error: 0.2647 - val_loss: 0.1327 - val_mean_absolute_error: 0.2884
# Epoch 108/500
# 600/600 [==============================] - 0s 27us/sample - loss: 0.1150 - mean_absolute_error: 0.2641 - val_loss: 0.1310 - val_mean_absolute_error: 0.2842
# Epoch 109/500
# 600/600 [==============================] - 0s 26us/sample - loss: 0.1145 - mean_absolute_error: 0.2626 - val_loss: 0.1301 - val_mean_absolute_error: 0.2836
# Epoch 110/500
# 600/600 [==============================] - 0s 22us/sample - loss: 0.1131 - mean_absolute_error: 0.2614 - val_loss: 0.1291 - val_mean_absolute_error: 0.2811
# Epoch 111/500
# 600/600 [==============================] - 0s 21us/sample - loss: 0.1130 - mean_absolute_error: 0.2612 - val_loss: 0.1279 - val_mean_absolute_error: 0.2804
# Epoch 112/500
# 600/600 [==============================] - 0s 28us/sample - loss: 0.1113 - mean_absolute_error: 0.2595 - val_loss: 0.1270 - val_mean_absolute_error: 0.2813
# Epoch 113/500
# 600/600 [==============================] - 0s 21us/sample - loss: 0.1101 - mean_absolute_error: 0.2580 - val_loss: 0.1257 - val_mean_absolute_error: 0.2780
# Epoch 114/500
# 600/600 [==============================] - 0s 28us/sample - loss: 0.1104 - mean_absolute_error: 0.2584 - val_loss: 0.1247 - val_mean_absolute_error: 0.2763
# Epoch 115/500
# 600/600 [==============================] - 0s 22us/sample - loss: 0.1089 - mean_absolute_error: 0.2568 - val_loss: 0.1236 - val_mean_absolute_error: 0.2756
# Epoch 116/500
# 600/600 [==============================] - 0s 27us/sample - loss: 0.1079 - mean_absolute_error: 0.2540 - val_loss: 0.1226 - val_mean_absolute_error: 0.2753
# Epoch 117/500
# 600/600 [==============================] - 0s 23us/sample - loss: 0.1082 - mean_absolute_error: 0.2552 - val_loss: 0.1215 - val_mean_absolute_error: 0.2742
# Epoch 118/500
# 600/600 [==============================] - 0s 28us/sample - loss: 0.1058 - mean_absolute_error: 0.2528 - val_loss: 0.1204 - val_mean_absolute_error: 0.2735
# Epoch 119/500
# 600/600 [==============================] - 0s 22us/sample - loss: 0.1051 - mean_absolute_error: 0.2506 - val_loss: 0.1191 - val_mean_absolute_error: 0.2693
# Epoch 120/500
# 600/600 [==============================] - 0s 26us/sample - loss: 0.1032 - mean_absolute_error: 0.2497 - val_loss: 0.1186 - val_mean_absolute_error: 0.2724
# Epoch 121/500
# 600/600 [==============================] - 0s 21us/sample - loss: 0.1029 - mean_absolute_error: 0.2486 - val_loss: 0.1170 - val_mean_absolute_error: 0.2675
# Epoch 122/500
# 600/600 [==============================] - 0s 25us/sample - loss: 0.1013 - mean_absolute_error: 0.2470 - val_loss: 0.1162 - val_mean_absolute_error: 0.2693
# Epoch 123/500
# 600/600 [==============================] - 0s 22us/sample - loss: 0.1004 - mean_absolute_error: 0.2461 - val_loss: 0.1146 - val_mean_absolute_error: 0.2643
# Epoch 124/500
# 600/600 [==============================] - 0s 23us/sample - loss: 0.0994 - mean_absolute_error: 0.2445 - val_loss: 0.1136 - val_mean_absolute_error: 0.2652
# Epoch 125/500
# 600/600 [==============================] - 0s 23us/sample - loss: 0.0983 - mean_absolute_error: 0.2435 - val_loss: 0.1123 - val_mean_absolute_error: 0.2629
# Epoch 126/500
# 600/600 [==============================] - 0s 25us/sample - loss: 0.0989 - mean_absolute_error: 0.2416 - val_loss: 0.1115 - val_mean_absolute_error: 0.2610
# Epoch 127/500
# 600/600 [==============================] - 0s 25us/sample - loss: 0.0963 - mean_absolute_error: 0.2404 - val_loss: 0.1109 - val_mean_absolute_error: 0.2633
# Epoch 128/500
# 600/600 [==============================] - 0s 23us/sample - loss: 0.0960 - mean_absolute_error: 0.2396 - val_loss: 0.1096 - val_mean_absolute_error: 0.2545
# Epoch 129/500
# 600/600 [==============================] - 0s 26us/sample - loss: 0.0953 - mean_absolute_error: 0.2384 - val_loss: 0.1081 - val_mean_absolute_error: 0.2579
# Epoch 130/500
# 600/600 [==============================] - 0s 22us/sample - loss: 0.0951 - mean_absolute_error: 0.2359 - val_loss: 0.1070 - val_mean_absolute_error: 0.2537
# Epoch 131/500
# 600/600 [==============================] - 0s 25us/sample - loss: 0.0929 - mean_absolute_error: 0.2353 - val_loss: 0.1063 - val_mean_absolute_error: 0.2567
# Epoch 132/500
# 600/600 [==============================] - 0s 24us/sample - loss: 0.0917 - mean_absolute_error: 0.2341 - val_loss: 0.1044 - val_mean_absolute_error: 0.2525
# Epoch 133/500
# 600/600 [==============================] - 0s 29us/sample - loss: 0.0906 - mean_absolute_error: 0.2329 - val_loss: 0.1032 - val_mean_absolute_error: 0.2514
# Epoch 134/500
# 600/600 [==============================] - 0s 23us/sample - loss: 0.0896 - mean_absolute_error: 0.2304 - val_loss: 0.1020 - val_mean_absolute_error: 0.2490
# Epoch 135/500
# 600/600 [==============================] - 0s 28us/sample - loss: 0.0882 - mean_absolute_error: 0.2292 - val_loss: 0.1009 - val_mean_absolute_error: 0.2478
# Epoch 136/500
# 600/600 [==============================] - 0s 23us/sample - loss: 0.0870 - mean_absolute_error: 0.2273 - val_loss: 0.0997 - val_mean_absolute_error: 0.2470
# Epoch 137/500
# 600/600 [==============================] - 0s 30us/sample - loss: 0.0865 - mean_absolute_error: 0.2262 - val_loss: 0.0987 - val_mean_absolute_error: 0.2457
# Epoch 138/500
# 600/600 [==============================] - 0s 24us/sample - loss: 0.0876 - mean_absolute_error: 0.2286 - val_loss: 0.0972 - val_mean_absolute_error: 0.2441
# Epoch 139/500
# 600/600 [==============================] - 0s 34us/sample - loss: 0.0853 - mean_absolute_error: 0.2241 - val_loss: 0.0961 - val_mean_absolute_error: 0.2425
# Epoch 140/500
# 600/600 [==============================] - 0s 23us/sample - loss: 0.0832 - mean_absolute_error: 0.2219 - val_loss: 0.0953 - val_mean_absolute_error: 0.2416
# Epoch 141/500
# 600/600 [==============================] - 0s 34us/sample - loss: 0.0819 - mean_absolute_error: 0.2201 - val_loss: 0.0938 - val_mean_absolute_error: 0.2377
# Epoch 142/500
# 600/600 [==============================] - 0s 25us/sample - loss: 0.0813 - mean_absolute_error: 0.2192 - val_loss: 0.0925 - val_mean_absolute_error: 0.2363
# Epoch 143/500
# 600/600 [==============================] - 0s 31us/sample - loss: 0.0806 - mean_absolute_error: 0.2183 - val_loss: 0.0916 - val_mean_absolute_error: 0.2347
# Epoch 144/500
# 600/600 [==============================] - 0s 31us/sample - loss: 0.0788 - mean_absolute_error: 0.2150 - val_loss: 0.0906 - val_mean_absolute_error: 0.2332
# Epoch 145/500
# 600/600 [==============================] - 0s 25us/sample - loss: 0.0779 - mean_absolute_error: 0.2134 - val_loss: 0.0891 - val_mean_absolute_error: 0.2323
# Epoch 146/500
# 600/600 [==============================] - 0s 28us/sample - loss: 0.0769 - mean_absolute_error: 0.2126 - val_loss: 0.0880 - val_mean_absolute_error: 0.2294
# Epoch 147/500
# 600/600 [==============================] - 0s 23us/sample - loss: 0.0759 - mean_absolute_error: 0.2104 - val_loss: 0.0869 - val_mean_absolute_error: 0.2287
# Epoch 148/500
# 600/600 [==============================] - 0s 29us/sample - loss: 0.0760 - mean_absolute_error: 0.2119 - val_loss: 0.0856 - val_mean_absolute_error: 0.2267
# Epoch 149/500
# 600/600 [==============================] - 0s 22us/sample - loss: 0.0752 - mean_absolute_error: 0.2080 - val_loss: 0.0847 - val_mean_absolute_error: 0.2264
# Epoch 150/500
# 600/600 [==============================] - 0s 27us/sample - loss: 0.0746 - mean_absolute_error: 0.2087 - val_loss: 0.0835 - val_mean_absolute_error: 0.2240
# Epoch 151/500
# 600/600 [==============================] - 0s 21us/sample - loss: 0.0719 - mean_absolute_error: 0.2044 - val_loss: 0.0823 - val_mean_absolute_error: 0.2240
# Epoch 152/500
# 600/600 [==============================] - 0s 27us/sample - loss: 0.0713 - mean_absolute_error: 0.2045 - val_loss: 0.0811 - val_mean_absolute_error: 0.2218
# Epoch 153/500
# 600/600 [==============================] - 0s 23us/sample - loss: 0.0706 - mean_absolute_error: 0.2032 - val_loss: 0.0801 - val_mean_absolute_error: 0.2202
# Epoch 154/500
# 600/600 [==============================] - 0s 27us/sample - loss: 0.0702 - mean_absolute_error: 0.2002 - val_loss: 0.0789 - val_mean_absolute_error: 0.2174
# Epoch 155/500
# 600/600 [==============================] - 0s 21us/sample - loss: 0.0690 - mean_absolute_error: 0.2009 - val_loss: 0.0777 - val_mean_absolute_error: 0.2167
# Epoch 156/500
# 600/600 [==============================] - 0s 28us/sample - loss: 0.0694 - mean_absolute_error: 0.1955 - val_loss: 0.0770 - val_mean_absolute_error: 0.2128
# Epoch 157/500
# 600/600 [==============================] - 0s 22us/sample - loss: 0.0686 - mean_absolute_error: 0.1993 - val_loss: 0.0755 - val_mean_absolute_error: 0.2141
# Epoch 158/500
# 600/600 [==============================] - 0s 27us/sample - loss: 0.0672 - mean_absolute_error: 0.1938 - val_loss: 0.0745 - val_mean_absolute_error: 0.2108
# Epoch 159/500
# 600/600 [==============================] - 0s 24us/sample - loss: 0.0646 - mean_absolute_error: 0.1939 - val_loss: 0.0734 - val_mean_absolute_error: 0.2109
# Epoch 160/500
# 600/600 [==============================] - 0s 27us/sample - loss: 0.0639 - mean_absolute_error: 0.1911 - val_loss: 0.0723 - val_mean_absolute_error: 0.2091
# Epoch 161/500
# 600/600 [==============================] - 0s 22us/sample - loss: 0.0625 - mean_absolute_error: 0.1909 - val_loss: 0.0712 - val_mean_absolute_error: 0.2076
# Epoch 162/500
# 600/600 [==============================] - 0s 24us/sample - loss: 0.0623 - mean_absolute_error: 0.1877 - val_loss: 0.0703 - val_mean_absolute_error: 0.2056
# Epoch 163/500
# 600/600 [==============================] - 0s 23us/sample - loss: 0.0609 - mean_absolute_error: 0.1873 - val_loss: 0.0694 - val_mean_absolute_error: 0.2060
# Epoch 164/500
# 600/600 [==============================] - 0s 23us/sample - loss: 0.0601 - mean_absolute_error: 0.1860 - val_loss: 0.0681 - val_mean_absolute_error: 0.2010
# Epoch 165/500
# 600/600 [==============================] - 0s 28us/sample - loss: 0.0586 - mean_absolute_error: 0.1832 - val_loss: 0.0672 - val_mean_absolute_error: 0.2018
# Epoch 166/500
# 600/600 [==============================] - 0s 23us/sample - loss: 0.0578 - mean_absolute_error: 0.1827 - val_loss: 0.0659 - val_mean_absolute_error: 0.1984
# Epoch 167/500
# 600/600 [==============================] - 0s 27us/sample - loss: 0.0570 - mean_absolute_error: 0.1799 - val_loss: 0.0649 - val_mean_absolute_error: 0.1978
# Epoch 168/500
# 600/600 [==============================] - 0s 27us/sample - loss: 0.0560 - mean_absolute_error: 0.1790 - val_loss: 0.0639 - val_mean_absolute_error: 0.1960
# Epoch 169/500
# 600/600 [==============================] - 0s 28us/sample - loss: 0.0553 - mean_absolute_error: 0.1770 - val_loss: 0.0630 - val_mean_absolute_error: 0.1947
# Epoch 170/500
# 600/600 [==============================] - 0s 30us/sample - loss: 0.0544 - mean_absolute_error: 0.1764 - val_loss: 0.0619 - val_mean_absolute_error: 0.1929
# Epoch 171/500
# 600/600 [==============================] - 0s 28us/sample - loss: 0.0538 - mean_absolute_error: 0.1752 - val_loss: 0.0609 - val_mean_absolute_error: 0.1914
# Epoch 172/500
# 600/600 [==============================] - 0s 30us/sample - loss: 0.0535 - mean_absolute_error: 0.1726 - val_loss: 0.0601 - val_mean_absolute_error: 0.1887
# Epoch 173/500
# 600/600 [==============================] - 0s 25us/sample - loss: 0.0520 - mean_absolute_error: 0.1730 - val_loss: 0.0593 - val_mean_absolute_error: 0.1887
# Epoch 174/500
# 600/600 [==============================] - 0s 32us/sample - loss: 0.0521 - mean_absolute_error: 0.1690 - val_loss: 0.0581 - val_mean_absolute_error: 0.1861
# Epoch 175/500
# 600/600 [==============================] - 0s 24us/sample - loss: 0.0522 - mean_absolute_error: 0.1733 - val_loss: 0.0572 - val_mean_absolute_error: 0.1866
# Epoch 176/500
# 600/600 [==============================] - 0s 27us/sample - loss: 0.0505 - mean_absolute_error: 0.1673 - val_loss: 0.0562 - val_mean_absolute_error: 0.1830
# Epoch 177/500
# 600/600 [==============================] - 0s 27us/sample - loss: 0.0488 - mean_absolute_error: 0.1665 - val_loss: 0.0552 - val_mean_absolute_error: 0.1817
# Epoch 178/500
# 600/600 [==============================] - 0s 24us/sample - loss: 0.0478 - mean_absolute_error: 0.1646 - val_loss: 0.0543 - val_mean_absolute_error: 0.1800
# Epoch 179/500
# 600/600 [==============================] - 0s 22us/sample - loss: 0.0469 - mean_absolute_error: 0.1627 - val_loss: 0.0534 - val_mean_absolute_error: 0.1781
# Epoch 180/500
# 600/600 [==============================] - 0s 25us/sample - loss: 0.0464 - mean_absolute_error: 0.1629 - val_loss: 0.0525 - val_mean_absolute_error: 0.1779
# Epoch 181/500
# 600/600 [==============================] - 0s 23us/sample - loss: 0.0456 - mean_absolute_error: 0.1606 - val_loss: 0.0516 - val_mean_absolute_error: 0.1755
# Epoch 182/500
# 600/600 [==============================] - 0s 28us/sample - loss: 0.0447 - mean_absolute_error: 0.1592 - val_loss: 0.0510 - val_mean_absolute_error: 0.1739
# Epoch 183/500
# 600/600 [==============================] - 0s 23us/sample - loss: 0.0444 - mean_absolute_error: 0.1584 - val_loss: 0.0502 - val_mean_absolute_error: 0.1707
# Epoch 184/500
# 600/600 [==============================] - 0s 25us/sample - loss: 0.0436 - mean_absolute_error: 0.1547 - val_loss: 0.0494 - val_mean_absolute_error: 0.1732
# Epoch 185/500
# 600/600 [==============================] - 0s 23us/sample - loss: 0.0466 - mean_absolute_error: 0.1629 - val_loss: 0.0482 - val_mean_absolute_error: 0.1690
# Epoch 186/500
# 600/600 [==============================] - 0s 26us/sample - loss: 0.0449 - mean_absolute_error: 0.1532 - val_loss: 0.0475 - val_mean_absolute_error: 0.1665
# Epoch 187/500
# 600/600 [==============================] - 0s 24us/sample - loss: 0.0412 - mean_absolute_error: 0.1527 - val_loss: 0.0469 - val_mean_absolute_error: 0.1689
# Epoch 188/500
# 600/600 [==============================] - 0s 27us/sample - loss: 0.0409 - mean_absolute_error: 0.1512 - val_loss: 0.0459 - val_mean_absolute_error: 0.1641
# Epoch 189/500
# 600/600 [==============================] - 0s 21us/sample - loss: 0.0402 - mean_absolute_error: 0.1504 - val_loss: 0.0450 - val_mean_absolute_error: 0.1635
# Epoch 190/500
# 600/600 [==============================] - 0s 25us/sample - loss: 0.0406 - mean_absolute_error: 0.1487 - val_loss: 0.0448 - val_mean_absolute_error: 0.1652
# Epoch 191/500
# 600/600 [==============================] - 0s 23us/sample - loss: 0.0403 - mean_absolute_error: 0.1517 - val_loss: 0.0439 - val_mean_absolute_error: 0.1592
# Epoch 192/500
# 600/600 [==============================] - 0s 29us/sample - loss: 0.0384 - mean_absolute_error: 0.1450 - val_loss: 0.0430 - val_mean_absolute_error: 0.1613
# Epoch 193/500
# 600/600 [==============================] - 0s 23us/sample - loss: 0.0396 - mean_absolute_error: 0.1500 - val_loss: 0.0422 - val_mean_absolute_error: 0.1578
# Epoch 194/500
# 600/600 [==============================] - 0s 25us/sample - loss: 0.0391 - mean_absolute_error: 0.1438 - val_loss: 0.0416 - val_mean_absolute_error: 0.1575
# Epoch 195/500
# 600/600 [==============================] - 0s 24us/sample - loss: 0.0369 - mean_absolute_error: 0.1442 - val_loss: 0.0408 - val_mean_absolute_error: 0.1557
# Epoch 196/500
# 600/600 [==============================] - 0s 24us/sample - loss: 0.0359 - mean_absolute_error: 0.1414 - val_loss: 0.0403 - val_mean_absolute_error: 0.1546
# Epoch 197/500
# 600/600 [==============================] - 0s 26us/sample - loss: 0.0354 - mean_absolute_error: 0.1414 - val_loss: 0.0395 - val_mean_absolute_error: 0.1524
# Epoch 198/500
# 600/600 [==============================] - 0s 24us/sample - loss: 0.0350 - mean_absolute_error: 0.1385 - val_loss: 0.0389 - val_mean_absolute_error: 0.1517
# Epoch 199/500
# 600/600 [==============================] - 0s 23us/sample - loss: 0.0348 - mean_absolute_error: 0.1398 - val_loss: 0.0383 - val_mean_absolute_error: 0.1514
# Epoch 200/500
# 600/600 [==============================] - 0s 21us/sample - loss: 0.0345 - mean_absolute_error: 0.1372 - val_loss: 0.0376 - val_mean_absolute_error: 0.1498
# Epoch 201/500
# 600/600 [==============================] - 0s 25us/sample - loss: 0.0333 - mean_absolute_error: 0.1369 - val_loss: 0.0374 - val_mean_absolute_error: 0.1513
# Epoch 202/500
# 600/600 [==============================] - 0s 25us/sample - loss: 0.0330 - mean_absolute_error: 0.1356 - val_loss: 0.0366 - val_mean_absolute_error: 0.1463
# Epoch 203/500
# 600/600 [==============================] - 0s 25us/sample - loss: 0.0321 - mean_absolute_error: 0.1335 - val_loss: 0.0359 - val_mean_absolute_error: 0.1478
# Epoch 204/500
# 600/600 [==============================] - 0s 25us/sample - loss: 0.0324 - mean_absolute_error: 0.1355 - val_loss: 0.0358 - val_mean_absolute_error: 0.1435
# Epoch 205/500
# 600/600 [==============================] - 0s 27us/sample - loss: 0.0329 - mean_absolute_error: 0.1322 - val_loss: 0.0349 - val_mean_absolute_error: 0.1459
# Epoch 206/500
# 600/600 [==============================] - 0s 22us/sample - loss: 0.0312 - mean_absolute_error: 0.1324 - val_loss: 0.0345 - val_mean_absolute_error: 0.1422
# Epoch 207/500
# 600/600 [==============================] - 0s 29us/sample - loss: 0.0315 - mean_absolute_error: 0.1309 - val_loss: 0.0341 - val_mean_absolute_error: 0.1451
# Epoch 208/500
# 600/600 [==============================] - 0s 21us/sample - loss: 0.0306 - mean_absolute_error: 0.1307 - val_loss: 0.0335 - val_mean_absolute_error: 0.1401
# Epoch 209/500
# 600/600 [==============================] - 0s 27us/sample - loss: 0.0295 - mean_absolute_error: 0.1282 - val_loss: 0.0328 - val_mean_absolute_error: 0.1412
# Epoch 210/500
# 600/600 [==============================] - 0s 22us/sample - loss: 0.0296 - mean_absolute_error: 0.1279 - val_loss: 0.0323 - val_mean_absolute_error: 0.1382
# Epoch 211/500
# 600/600 [==============================] - 0s 27us/sample - loss: 0.0286 - mean_absolute_error: 0.1264 - val_loss: 0.0320 - val_mean_absolute_error: 0.1407
# Epoch 212/500
# 600/600 [==============================] - 0s 22us/sample - loss: 0.0285 - mean_absolute_error: 0.1268 - val_loss: 0.0316 - val_mean_absolute_error: 0.1360
# Epoch 213/500
# 600/600 [==============================] - 0s 24us/sample - loss: 0.0288 - mean_absolute_error: 0.1250 - val_loss: 0.0311 - val_mean_absolute_error: 0.1386
# Epoch 214/500
# 600/600 [==============================] - 0s 24us/sample - loss: 0.0281 - mean_absolute_error: 0.1261 - val_loss: 0.0305 - val_mean_absolute_error: 0.1348
# Epoch 215/500
# 600/600 [==============================] - 0s 25us/sample - loss: 0.0273 - mean_absolute_error: 0.1233 - val_loss: 0.0298 - val_mean_absolute_error: 0.1342
# Epoch 216/500
# 600/600 [==============================] - 0s 24us/sample - loss: 0.0269 - mean_absolute_error: 0.1219 - val_loss: 0.0294 - val_mean_absolute_error: 0.1334
# Epoch 217/500
# 600/600 [==============================] - 0s 23us/sample - loss: 0.0267 - mean_absolute_error: 0.1226 - val_loss: 0.0290 - val_mean_absolute_error: 0.1328
# Epoch 218/500
# 600/600 [==============================] - 0s 23us/sample - loss: 0.0266 - mean_absolute_error: 0.1209 - val_loss: 0.0286 - val_mean_absolute_error: 0.1329
# Epoch 219/500
# 600/600 [==============================] - 0s 27us/sample - loss: 0.0274 - mean_absolute_error: 0.1249 - val_loss: 0.0283 - val_mean_absolute_error: 0.1301
# Epoch 220/500
# 600/600 [==============================] - 0s 24us/sample - loss: 0.0259 - mean_absolute_error: 0.1196 - val_loss: 0.0279 - val_mean_absolute_error: 0.1292
# Epoch 221/500
# 600/600 [==============================] - 0s 24us/sample - loss: 0.0253 - mean_absolute_error: 0.1182 - val_loss: 0.0275 - val_mean_absolute_error: 0.1294
# Epoch 222/500
# 600/600 [==============================] - 0s 23us/sample - loss: 0.0250 - mean_absolute_error: 0.1184 - val_loss: 0.0269 - val_mean_absolute_error: 0.1288
# Epoch 223/500
# 600/600 [==============================] - 0s 25us/sample - loss: 0.0248 - mean_absolute_error: 0.1177 - val_loss: 0.0266 - val_mean_absolute_error: 0.1276
# Epoch 224/500
# 600/600 [==============================] - 0s 26us/sample - loss: 0.0243 - mean_absolute_error: 0.1162 - val_loss: 0.0263 - val_mean_absolute_error: 0.1269
# Epoch 225/500
# 600/600 [==============================] - 0s 23us/sample - loss: 0.0241 - mean_absolute_error: 0.1160 - val_loss: 0.0258 - val_mean_absolute_error: 0.1266
# Epoch 226/500
# 600/600 [==============================] - 0s 26us/sample - loss: 0.0239 - mean_absolute_error: 0.1153 - val_loss: 0.0255 - val_mean_absolute_error: 0.1259
# Epoch 227/500
# 600/600 [==============================] - 0s 22us/sample - loss: 0.0238 - mean_absolute_error: 0.1157 - val_loss: 0.0259 - val_mean_absolute_error: 0.1239
# Epoch 228/500
# 600/600 [==============================] - 0s 28us/sample - loss: 0.0235 - mean_absolute_error: 0.1144 - val_loss: 0.0253 - val_mean_absolute_error: 0.1263
# Epoch 229/500
# 600/600 [==============================] - 0s 21us/sample - loss: 0.0234 - mean_absolute_error: 0.1156 - val_loss: 0.0248 - val_mean_absolute_error: 0.1232
# Epoch 230/500
# 600/600 [==============================] - 0s 28us/sample - loss: 0.0228 - mean_absolute_error: 0.1129 - val_loss: 0.0242 - val_mean_absolute_error: 0.1233
# Epoch 231/500
# 600/600 [==============================] - 0s 22us/sample - loss: 0.0232 - mean_absolute_error: 0.1134 - val_loss: 0.0242 - val_mean_absolute_error: 0.1239
# Epoch 232/500
# 600/600 [==============================] - 0s 25us/sample - loss: 0.0228 - mean_absolute_error: 0.1135 - val_loss: 0.0240 - val_mean_absolute_error: 0.1209
# Epoch 233/500
# 600/600 [==============================] - 0s 25us/sample - loss: 0.0222 - mean_absolute_error: 0.1119 - val_loss: 0.0232 - val_mean_absolute_error: 0.1214
# Epoch 234/500
# 600/600 [==============================] - 0s 25us/sample - loss: 0.0218 - mean_absolute_error: 0.1113 - val_loss: 0.0232 - val_mean_absolute_error: 0.1201
# Epoch 235/500
# 600/600 [==============================] - 0s 24us/sample - loss: 0.0219 - mean_absolute_error: 0.1110 - val_loss: 0.0231 - val_mean_absolute_error: 0.1214
# Epoch 236/500
# 600/600 [==============================] - 0s 25us/sample - loss: 0.0220 - mean_absolute_error: 0.1132 - val_loss: 0.0231 - val_mean_absolute_error: 0.1187
# Epoch 237/500
# 600/600 [==============================] - 0s 21us/sample - loss: 0.0227 - mean_absolute_error: 0.1120 - val_loss: 0.0225 - val_mean_absolute_error: 0.1203
# Epoch 238/500
# 600/600 [==============================] - 0s 25us/sample - loss: 0.0215 - mean_absolute_error: 0.1108 - val_loss: 0.0225 - val_mean_absolute_error: 0.1176
# Epoch 239/500
# 600/600 [==============================] - 0s 23us/sample - loss: 0.0210 - mean_absolute_error: 0.1093 - val_loss: 0.0218 - val_mean_absolute_error: 0.1179
# Epoch 240/500
# 600/600 [==============================] - 0s 24us/sample - loss: 0.0206 - mean_absolute_error: 0.1080 - val_loss: 0.0215 - val_mean_absolute_error: 0.1174
# Epoch 241/500
# 600/600 [==============================] - 0s 24us/sample - loss: 0.0205 - mean_absolute_error: 0.1082 - val_loss: 0.0213 - val_mean_absolute_error: 0.1169
# Epoch 242/500
# 600/600 [==============================] - 0s 21us/sample - loss: 0.0204 - mean_absolute_error: 0.1083 - val_loss: 0.0217 - val_mean_absolute_error: 0.1157
# Epoch 243/500
# 600/600 [==============================] - 0s 28us/sample - loss: 0.0205 - mean_absolute_error: 0.1077 - val_loss: 0.0210 - val_mean_absolute_error: 0.1167
# Epoch 244/500
# 600/600 [==============================] - 0s 23us/sample - loss: 0.0202 - mean_absolute_error: 0.1075 - val_loss: 0.0210 - val_mean_absolute_error: 0.1149
# Epoch 245/500
# 600/600 [==============================] - 0s 27us/sample - loss: 0.0206 - mean_absolute_error: 0.1087 - val_loss: 0.0204 - val_mean_absolute_error: 0.1149
# Epoch 246/500
# 600/600 [==============================] - 0s 22us/sample - loss: 0.0200 - mean_absolute_error: 0.1067 - val_loss: 0.0203 - val_mean_absolute_error: 0.1149
# Epoch 247/500
# 600/600 [==============================] - 0s 24us/sample - loss: 0.0196 - mean_absolute_error: 0.1064 - val_loss: 0.0200 - val_mean_absolute_error: 0.1141
# Epoch 248/500
# 600/600 [==============================] - 0s 23us/sample - loss: 0.0197 - mean_absolute_error: 0.1064 - val_loss: 0.0200 - val_mean_absolute_error: 0.1137
# Epoch 249/500
# 600/600 [==============================] - 0s 24us/sample - loss: 0.0197 - mean_absolute_error: 0.1065 - val_loss: 0.0199 - val_mean_absolute_error: 0.1129
# Epoch 250/500
# 600/600 [==============================] - 0s 25us/sample - loss: 0.0194 - mean_absolute_error: 0.1062 - val_loss: 0.0198 - val_mean_absolute_error: 0.1126
# Epoch 251/500
# 600/600 [==============================] - 0s 25us/sample - loss: 0.0193 - mean_absolute_error: 0.1059 - val_loss: 0.0194 - val_mean_absolute_error: 0.1127
# Epoch 252/500
# 600/600 [==============================] - 0s 21us/sample - loss: 0.0194 - mean_absolute_error: 0.1073 - val_loss: 0.0199 - val_mean_absolute_error: 0.1116
# Epoch 253/500
# 600/600 [==============================] - 0s 25us/sample - loss: 0.0195 - mean_absolute_error: 0.1054 - val_loss: 0.0191 - val_mean_absolute_error: 0.1120
# Epoch 254/500
# 600/600 [==============================] - 0s 22us/sample - loss: 0.0194 - mean_absolute_error: 0.1064 - val_loss: 0.0203 - val_mean_absolute_error: 0.1110
# Epoch 255/500
# 600/600 [==============================] - 0s 27us/sample - loss: 0.0191 - mean_absolute_error: 0.1058 - val_loss: 0.0188 - val_mean_absolute_error: 0.1114
# Epoch 256/500
# 600/600 [==============================] - 0s 22us/sample - loss: 0.0185 - mean_absolute_error: 0.1045 - val_loss: 0.0196 - val_mean_absolute_error: 0.1104
# Epoch 257/500
# 600/600 [==============================] - 0s 22us/sample - loss: 0.0190 - mean_absolute_error: 0.1054 - val_loss: 0.0183 - val_mean_absolute_error: 0.1098
# Epoch 258/500
# 600/600 [==============================] - 0s 31us/sample - loss: 0.0183 - mean_absolute_error: 0.1034 - val_loss: 0.0184 - val_mean_absolute_error: 0.1096
# Epoch 259/500
# 600/600 [==============================] - 0s 32us/sample - loss: 0.0182 - mean_absolute_error: 0.1041 - val_loss: 0.0183 - val_mean_absolute_error: 0.1092
# Epoch 260/500
# 600/600 [==============================] - 0s 23us/sample - loss: 0.0182 - mean_absolute_error: 0.1034 - val_loss: 0.0180 - val_mean_absolute_error: 0.1092
# Epoch 261/500
# 600/600 [==============================] - 0s 29us/sample - loss: 0.0179 - mean_absolute_error: 0.1029 - val_loss: 0.0182 - val_mean_absolute_error: 0.1084
# Epoch 262/500
# 600/600 [==============================] - 0s 24us/sample - loss: 0.0179 - mean_absolute_error: 0.1023 - val_loss: 0.0177 - val_mean_absolute_error: 0.1082
# Epoch 263/500
# 600/600 [==============================] - 0s 25us/sample - loss: 0.0179 - mean_absolute_error: 0.1033 - val_loss: 0.0179 - val_mean_absolute_error: 0.1078
# Epoch 264/500
# 600/600 [==============================] - 0s 25us/sample - loss: 0.0178 - mean_absolute_error: 0.1035 - val_loss: 0.0177 - val_mean_absolute_error: 0.1078
# Epoch 265/500
# 600/600 [==============================] - 0s 25us/sample - loss: 0.0175 - mean_absolute_error: 0.1023 - val_loss: 0.0173 - val_mean_absolute_error: 0.1067
# Epoch 266/500
# 600/600 [==============================] - 0s 27us/sample - loss: 0.0175 - mean_absolute_error: 0.1019 - val_loss: 0.0172 - val_mean_absolute_error: 0.1068
# Epoch 267/500
# 600/600 [==============================] - 0s 25us/sample - loss: 0.0174 - mean_absolute_error: 0.1023 - val_loss: 0.0174 - val_mean_absolute_error: 0.1066
# Epoch 268/500
# 600/600 [==============================] - 0s 28us/sample - loss: 0.0176 - mean_absolute_error: 0.1025 - val_loss: 0.0174 - val_mean_absolute_error: 0.1063
# Epoch 269/500
# 600/600 [==============================] - 0s 27us/sample - loss: 0.0175 - mean_absolute_error: 0.1018 - val_loss: 0.0173 - val_mean_absolute_error: 0.1065
# Epoch 270/500
# 600/600 [==============================] - 0s 24us/sample - loss: 0.0179 - mean_absolute_error: 0.1042 - val_loss: 0.0185 - val_mean_absolute_error: 0.1065
# Epoch 271/500
# 600/600 [==============================] - 0s 28us/sample - loss: 0.0176 - mean_absolute_error: 0.1020 - val_loss: 0.0170 - val_mean_absolute_error: 0.1059
# Epoch 272/500
# 600/600 [==============================] - 0s 23us/sample - loss: 0.0171 - mean_absolute_error: 0.1019 - val_loss: 0.0169 - val_mean_absolute_error: 0.1050
# Epoch 273/500
# 600/600 [==============================] - 0s 30us/sample - loss: 0.0170 - mean_absolute_error: 0.1011 - val_loss: 0.0165 - val_mean_absolute_error: 0.1048
# Epoch 274/500
# 600/600 [==============================] - 0s 21us/sample - loss: 0.0170 - mean_absolute_error: 0.1019 - val_loss: 0.0167 - val_mean_absolute_error: 0.1045
# Epoch 275/500
# 600/600 [==============================] - 0s 28us/sample - loss: 0.0169 - mean_absolute_error: 0.1015 - val_loss: 0.0165 - val_mean_absolute_error: 0.1042
# Epoch 276/500
# 600/600 [==============================] - 0s 22us/sample - loss: 0.0171 - mean_absolute_error: 0.1019 - val_loss: 0.0164 - val_mean_absolute_error: 0.1045
# Epoch 277/500
# 600/600 [==============================] - 0s 26us/sample - loss: 0.0168 - mean_absolute_error: 0.1017 - val_loss: 0.0174 - val_mean_absolute_error: 0.1043
# Epoch 278/500
# 600/600 [==============================] - 0s 22us/sample - loss: 0.0167 - mean_absolute_error: 0.1016 - val_loss: 0.0160 - val_mean_absolute_error: 0.1033
# Epoch 279/500
# 600/600 [==============================] - 0s 24us/sample - loss: 0.0165 - mean_absolute_error: 0.1004 - val_loss: 0.0160 - val_mean_absolute_error: 0.1030
# Epoch 280/500
# 600/600 [==============================] - 0s 23us/sample - loss: 0.0163 - mean_absolute_error: 0.1002 - val_loss: 0.0158 - val_mean_absolute_error: 0.1029
# Epoch 281/500
# 600/600 [==============================] - 0s 27us/sample - loss: 0.0162 - mean_absolute_error: 0.0999 - val_loss: 0.0160 - val_mean_absolute_error: 0.1028
# Epoch 282/500
# 600/600 [==============================] - 0s 24us/sample - loss: 0.0163 - mean_absolute_error: 0.1001 - val_loss: 0.0157 - val_mean_absolute_error: 0.1023
# Epoch 283/500
# ...
# Epoch 407/500
# 600/600 [==============================] - 0s 26us/sample - loss: 0.0142 - mean_absolute_error: 0.0948 - val_loss: 0.0129 - val_mean_absolute_error: 0.0926
# Epoch 408/500
# 600/600 [==============================] - 0s 21us/sample - loss: 0.0140 - mean_absolute_error: 0.0940 - val_loss: 0.0134 - val_mean_absolute_error: 0.0942
# Epoch 409/500
# 600/600 [==============================] - 0s 29us/sample - loss: 0.0142 - mean_absolute_error: 0.0952 - val_loss: 0.0127 - val_mean_absolute_error: 0.0908
# Epoch 410/500
# 600/600 [==============================] - 0s 24us/sample - loss: 0.0141 - mean_absolute_error: 0.0944 - val_loss: 0.0129 - val_mean_absolute_error: 0.0913
# Epoch 411/500
# 600/600 [==============================] - 0s 29us/sample - loss: 0.0139 - mean_absolute_error: 0.0937 - val_loss: 0.0125 - val_mean_absolute_error: 0.0905
# Epoch 412/500
# 600/600 [==============================] - 0s 27us/sample - loss: 0.0143 - mean_absolute_error: 0.0946 - val_loss: 0.0125 - val_mean_absolute_error: 0.0906
# Epoch 413/500
# 600/600 [==============================] - 0s 28us/sample - loss: 0.0139 - mean_absolute_error: 0.0934 - val_loss: 0.0138 - val_mean_absolute_error: 0.0954
# Epoch 414/500
# 600/600 [==============================] - 0s 22us/sample - loss: 0.0149 - mean_absolute_error: 0.0963 - val_loss: 0.0126 - val_mean_absolute_error: 0.0908
# Epoch 415/500
# 600/600 [==============================] - 0s 28us/sample - loss: 0.0140 - mean_absolute_error: 0.0936 - val_loss: 0.0126 - val_mean_absolute_error: 0.0909
# Epoch 416/500
# 600/600 [==============================] - 0s 24us/sample - loss: 0.0140 - mean_absolute_error: 0.0936 - val_loss: 0.0131 - val_mean_absolute_error: 0.0931
# Epoch 417/500
# 600/600 [==============================] - 0s 29us/sample - loss: 0.0139 - mean_absolute_error: 0.0937 - val_loss: 0.0131 - val_mean_absolute_error: 0.0934
# Epoch 418/500
# 600/600 [==============================] - 0s 22us/sample - loss: 0.0144 - mean_absolute_error: 0.0951 - val_loss: 0.0141 - val_mean_absolute_error: 0.0964
# Epoch 419/500
# 600/600 [==============================] - 0s 27us/sample - loss: 0.0143 - mean_absolute_error: 0.0944 - val_loss: 0.0127 - val_mean_absolute_error: 0.0908
# Epoch 420/500
# 600/600 [==============================] - 0s 24us/sample - loss: 0.0142 - mean_absolute_error: 0.0945 - val_loss: 0.0127 - val_mean_absolute_error: 0.0910
# Epoch 421/500
# 600/600 [==============================] - 0s 27us/sample - loss: 0.0140 - mean_absolute_error: 0.0942 - val_loss: 0.0125 - val_mean_absolute_error: 0.0908
# Epoch 422/500
# 600/600 [==============================] - 0s 21us/sample - loss: 0.0139 - mean_absolute_error: 0.0939 - val_loss: 0.0144 - val_mean_absolute_error: 0.0972
# Epoch 423/500
# 600/600 [==============================] - 0s 28us/sample - loss: 0.0160 - mean_absolute_error: 0.0996 - val_loss: 0.0128 - val_mean_absolute_error: 0.0915
# Epoch 424/500
# 600/600 [==============================] - 0s 22us/sample - loss: 0.0144 - mean_absolute_error: 0.0955 - val_loss: 0.0131 - val_mean_absolute_error: 0.0919
# Epoch 425/500
# 600/600 [==============================] - 0s 26us/sample - loss: 0.0147 - mean_absolute_error: 0.0958 - val_loss: 0.0129 - val_mean_absolute_error: 0.0924
# Epoch 426/500
# 600/600 [==============================] - 0s 22us/sample - loss: 0.0142 - mean_absolute_error: 0.0946 - val_loss: 0.0126 - val_mean_absolute_error: 0.0915
# Epoch 427/500
# 600/600 [==============================] - 0s 26us/sample - loss: 0.0144 - mean_absolute_error: 0.0954 - val_loss: 0.0133 - val_mean_absolute_error: 0.0927
# Epoch 428/500
# 600/600 [==============================] - 0s 23us/sample - loss: 0.0144 - mean_absolute_error: 0.0948 - val_loss: 0.0129 - val_mean_absolute_error: 0.0922
# Epoch 429/500
# 600/600 [==============================] - 0s 25us/sample - loss: 0.0141 - mean_absolute_error: 0.0937 - val_loss: 0.0125 - val_mean_absolute_error: 0.0908
# Epoch 430/500
# 600/600 [==============================] - 0s 24us/sample - loss: 0.0138 - mean_absolute_error: 0.0930 - val_loss: 0.0129 - val_mean_absolute_error: 0.0922
# Epoch 431/500
# 600/600 [==============================] - 0s 27us/sample - loss: 0.0140 - mean_absolute_error: 0.0940 - val_loss: 0.0128 - val_mean_absolute_error: 0.0922
# Epoch 432/500
# 600/600 [==============================] - 0s 24us/sample - loss: 0.0139 - mean_absolute_error: 0.0938 - val_loss: 0.0126 - val_mean_absolute_error: 0.0913
# Epoch 433/500
# 600/600 [==============================] - 0s 21us/sample - loss: 0.0140 - mean_absolute_error: 0.0936 - val_loss: 0.0134 - val_mean_absolute_error: 0.0942
# Epoch 434/500
# 600/600 [==============================] - 0s 25us/sample - loss: 0.0141 - mean_absolute_error: 0.0945 - val_loss: 0.0129 - val_mean_absolute_error: 0.0914
# Epoch 435/500
# 600/600 [==============================] - 0s 22us/sample - loss: 0.0140 - mean_absolute_error: 0.0939 - val_loss: 0.0124 - val_mean_absolute_error: 0.0905
# Epoch 436/500
# 600/600 [==============================] - 0s 29us/sample - loss: 0.0139 - mean_absolute_error: 0.0933 - val_loss: 0.0133 - val_mean_absolute_error: 0.0939
# Epoch 437/500
# 600/600 [==============================] - 0s 22us/sample - loss: 0.0142 - mean_absolute_error: 0.0946 - val_loss: 0.0127 - val_mean_absolute_error: 0.0919
# Epoch 438/500
# 600/600 [==============================] - 0s 28us/sample - loss: 0.0154 - mean_absolute_error: 0.0976 - val_loss: 0.0126 - val_mean_absolute_error: 0.0908
# Epoch 439/500
# 600/600 [==============================] - 0s 22us/sample - loss: 0.0148 - mean_absolute_error: 0.0959 - val_loss: 0.0137 - val_mean_absolute_error: 0.0941
# Epoch 440/500
# 600/600 [==============================] - 0s 27us/sample - loss: 0.0158 - mean_absolute_error: 0.0994 - val_loss: 0.0131 - val_mean_absolute_error: 0.0928
# Epoch 441/500
# 600/600 [==============================] - 0s 23us/sample - loss: 0.0142 - mean_absolute_error: 0.0944 - val_loss: 0.0131 - val_mean_absolute_error: 0.0929
# Epoch 442/500
# 600/600 [==============================] - 0s 28us/sample - loss: 0.0138 - mean_absolute_error: 0.0935 - val_loss: 0.0128 - val_mean_absolute_error: 0.0912
# Epoch 443/500
# 600/600 [==============================] - 0s 23us/sample - loss: 0.0139 - mean_absolute_error: 0.0937 - val_loss: 0.0127 - val_mean_absolute_error: 0.0909
# Epoch 444/500
# 600/600 [==============================] - 0s 27us/sample - loss: 0.0139 - mean_absolute_error: 0.0936 - val_loss: 0.0125 - val_mean_absolute_error: 0.0906
# Epoch 445/500
# 600/600 [==============================] - 0s 21us/sample - loss: 0.0139 - mean_absolute_error: 0.0937 - val_loss: 0.0126 - val_mean_absolute_error: 0.0911
# Epoch 446/500
# 600/600 [==============================] - 0s 27us/sample - loss: 0.0139 - mean_absolute_error: 0.0937 - val_loss: 0.0125 - val_mean_absolute_error: 0.0906
# Epoch 447/500
# 600/600 [==============================] - 0s 24us/sample - loss: 0.0139 - mean_absolute_error: 0.0935 - val_loss: 0.0126 - val_mean_absolute_error: 0.0908
# Epoch 448/500
# 600/600 [==============================] - 0s 29us/sample - loss: 0.0140 - mean_absolute_error: 0.0945 - val_loss: 0.0132 - val_mean_absolute_error: 0.0935
# Epoch 449/500
# 600/600 [==============================] - 0s 23us/sample - loss: 0.0140 - mean_absolute_error: 0.0940 - val_loss: 0.0130 - val_mean_absolute_error: 0.0931
# Epoch 450/500
# 600/600 [==============================] - 0s 29us/sample - loss: 0.0141 - mean_absolute_error: 0.0933 - val_loss: 0.0124 - val_mean_absolute_error: 0.0905
# Epoch 451/500
# 600/600 [==============================] - 0s 22us/sample - loss: 0.0140 - mean_absolute_error: 0.0940 - val_loss: 0.0129 - val_mean_absolute_error: 0.0912
# Epoch 452/500
# 600/600 [==============================] - 0s 27us/sample - loss: 0.0140 - mean_absolute_error: 0.0942 - val_loss: 0.0125 - val_mean_absolute_error: 0.0909
# Epoch 453/500
# 600/600 [==============================] - 0s 22us/sample - loss: 0.0138 - mean_absolute_error: 0.0933 - val_loss: 0.0134 - val_mean_absolute_error: 0.0939
# Epoch 454/500
# 600/600 [==============================] - 0s 28us/sample - loss: 0.0140 - mean_absolute_error: 0.0943 - val_loss: 0.0127 - val_mean_absolute_error: 0.0915
# Epoch 455/500
# 600/600 [==============================] - 0s 22us/sample - loss: 0.0148 - mean_absolute_error: 0.0956 - val_loss: 0.0130 - val_mean_absolute_error: 0.0921
# Epoch 456/500
# 600/600 [==============================] - 0s 26us/sample - loss: 0.0143 - mean_absolute_error: 0.0942 - val_loss: 0.0127 - val_mean_absolute_error: 0.0908
# Epoch 457/500
# 600/600 [==============================] - 0s 23us/sample - loss: 0.0140 - mean_absolute_error: 0.0940 - val_loss: 0.0133 - val_mean_absolute_error: 0.0938
# Epoch 458/500
# 600/600 [==============================] - 0s 26us/sample - loss: 0.0139 - mean_absolute_error: 0.0939 - val_loss: 0.0129 - val_mean_absolute_error: 0.0917
# Epoch 459/500
# 600/600 [==============================] - 0s 23us/sample - loss: 0.0145 - mean_absolute_error: 0.0956 - val_loss: 0.0132 - val_mean_absolute_error: 0.0934
# Epoch 460/500
# 600/600 [==============================] - 0s 20us/sample - loss: 0.0138 - mean_absolute_error: 0.0934 - val_loss: 0.0127 - val_mean_absolute_error: 0.0918
# Epoch 461/500
# 600/600 [==============================] - 0s 29us/sample - loss: 0.0138 - mean_absolute_error: 0.0936 - val_loss: 0.0126 - val_mean_absolute_error: 0.0908
# Epoch 462/500
# 600/600 [==============================] - 0s 22us/sample - loss: 0.0142 - mean_absolute_error: 0.0942 - val_loss: 0.0138 - val_mean_absolute_error: 0.0953
# Epoch 463/500
# 600/600 [==============================] - 0s 26us/sample - loss: 0.0143 - mean_absolute_error: 0.0945 - val_loss: 0.0135 - val_mean_absolute_error: 0.0946
# Epoch 464/500
# 600/600 [==============================] - 0s 21us/sample - loss: 0.0139 - mean_absolute_error: 0.0934 - val_loss: 0.0126 - val_mean_absolute_error: 0.0906
# Epoch 465/500
# 600/600 [==============================] - 0s 26us/sample - loss: 0.0142 - mean_absolute_error: 0.0950 - val_loss: 0.0127 - val_mean_absolute_error: 0.0911
# Epoch 466/500
# 600/600 [==============================] - 0s 20us/sample - loss: 0.0142 - mean_absolute_error: 0.0942 - val_loss: 0.0138 - val_mean_absolute_error: 0.0955
# Epoch 467/500
# 600/600 [==============================] - 0s 27us/sample - loss: 0.0140 - mean_absolute_error: 0.0940 - val_loss: 0.0127 - val_mean_absolute_error: 0.0919
# Epoch 468/500
# 600/600 [==============================] - 0s 22us/sample - loss: 0.0138 - mean_absolute_error: 0.0931 - val_loss: 0.0125 - val_mean_absolute_error: 0.0907
# Epoch 469/500
# 600/600 [==============================] - 0s 26us/sample - loss: 0.0140 - mean_absolute_error: 0.0943 - val_loss: 0.0133 - val_mean_absolute_error: 0.0940
# Epoch 470/500
# 600/600 [==============================] - 0s 23us/sample - loss: 0.0141 - mean_absolute_error: 0.0944 - val_loss: 0.0131 - val_mean_absolute_error: 0.0929
# Epoch 471/500
# 600/600 [==============================] - 0s 25us/sample - loss: 0.0143 - mean_absolute_error: 0.0941 - val_loss: 0.0127 - val_mean_absolute_error: 0.0913
# Epoch 472/500
# 600/600 [==============================] - 0s 23us/sample - loss: 0.0141 - mean_absolute_error: 0.0943 - val_loss: 0.0127 - val_mean_absolute_error: 0.0910
# Epoch 473/500
# 600/600 [==============================] - 0s 27us/sample - loss: 0.0142 - mean_absolute_error: 0.0947 - val_loss: 0.0127 - val_mean_absolute_error: 0.0915
# Epoch 474/500
# 600/600 [==============================] - 0s 22us/sample - loss: 0.0143 - mean_absolute_error: 0.0949 - val_loss: 0.0141 - val_mean_absolute_error: 0.0961
# Epoch 475/500
# 600/600 [==============================] - 0s 21us/sample - loss: 0.0146 - mean_absolute_error: 0.0961 - val_loss: 0.0132 - val_mean_absolute_error: 0.0935
# Epoch 476/500
# 600/600 [==============================] - 0s 23us/sample - loss: 0.0141 - mean_absolute_error: 0.0940 - val_loss: 0.0126 - val_mean_absolute_error: 0.0907
# Epoch 477/500
# 600/600 [==============================] - 0s 24us/sample - loss: 0.0138 - mean_absolute_error: 0.0935 - val_loss: 0.0125 - val_mean_absolute_error: 0.0905
# Epoch 478/500
# 600/600 [==============================] - 0s 28us/sample - loss: 0.0140 - mean_absolute_error: 0.0943 - val_loss: 0.0131 - val_mean_absolute_error: 0.0933
# Epoch 479/500
# 600/600 [==============================] - 0s 22us/sample - loss: 0.0145 - mean_absolute_error: 0.0956 - val_loss: 0.0144 - val_mean_absolute_error: 0.0970
# Epoch 480/500
# 600/600 [==============================] - 0s 27us/sample - loss: 0.0140 - mean_absolute_error: 0.0936 - val_loss: 0.0125 - val_mean_absolute_error: 0.0908
# Epoch 481/500
# 600/600 [==============================] - 0s 22us/sample - loss: 0.0139 - mean_absolute_error: 0.0936 - val_loss: 0.0132 - val_mean_absolute_error: 0.0934
# Epoch 482/500
# 600/600 [==============================] - 0s 27us/sample - loss: 0.0137 - mean_absolute_error: 0.0929 - val_loss: 0.0126 - val_mean_absolute_error: 0.0905
# Epoch 483/500
# 600/600 [==============================] - 0s 24us/sample - loss: 0.0138 - mean_absolute_error: 0.0933 - val_loss: 0.0125 - val_mean_absolute_error: 0.0906
# Epoch 484/500
# 600/600 [==============================] - 0s 28us/sample - loss: 0.0138 - mean_absolute_error: 0.0932 - val_loss: 0.0132 - val_mean_absolute_error: 0.0935
# Epoch 485/500
# 600/600 [==============================] - 0s 22us/sample - loss: 0.0140 - mean_absolute_error: 0.0935 - val_loss: 0.0125 - val_mean_absolute_error: 0.0906
# Epoch 486/500
# 600/600 [==============================] - 0s 28us/sample - loss: 0.0142 - mean_absolute_error: 0.0943 - val_loss: 0.0129 - val_mean_absolute_error: 0.0925
# Epoch 487/500
# 600/600 [==============================] - 0s 23us/sample - loss: 0.0138 - mean_absolute_error: 0.0936 - val_loss: 0.0129 - val_mean_absolute_error: 0.0915
# Epoch 488/500
# 600/600 [==============================] - 0s 27us/sample - loss: 0.0143 - mean_absolute_error: 0.0943 - val_loss: 0.0124 - val_mean_absolute_error: 0.0904
# Epoch 489/500
# 600/600 [==============================] - 0s 23us/sample - loss: 0.0142 - mean_absolute_error: 0.0952 - val_loss: 0.0129 - val_mean_absolute_error: 0.0917
# Epoch 490/500
# 600/600 [==============================] - 0s 27us/sample - loss: 0.0144 - mean_absolute_error: 0.0960 - val_loss: 0.0138 - val_mean_absolute_error: 0.0951
# Epoch 491/500
# 600/600 [==============================] - 0s 25us/sample - loss: 0.0138 - mean_absolute_error: 0.0933 - val_loss: 0.0128 - val_mean_absolute_error: 0.0912
# Epoch 492/500
# 600/600 [==============================] - 0s 27us/sample - loss: 0.0140 - mean_absolute_error: 0.0943 - val_loss: 0.0126 - val_mean_absolute_error: 0.0911
# Epoch 493/500
# 600/600 [==============================] - 0s 22us/sample - loss: 0.0138 - mean_absolute_error: 0.0930 - val_loss: 0.0125 - val_mean_absolute_error: 0.0909
# Epoch 494/500
# 600/600 [==============================] - 0s 26us/sample - loss: 0.0138 - mean_absolute_error: 0.0936 - val_loss: 0.0128 - val_mean_absolute_error: 0.0917
# Epoch 495/500
# 600/600 [==============================] - 0s 21us/sample - loss: 0.0140 - mean_absolute_error: 0.0938 - val_loss: 0.0124 - val_mean_absolute_error: 0.0904
# Epoch 496/500
# 600/600 [==============================] - 0s 28us/sample - loss: 0.0142 - mean_absolute_error: 0.0947 - val_loss: 0.0138 - val_mean_absolute_error: 0.0952
# Epoch 497/500
# 600/600 [==============================] - 0s 22us/sample - loss: 0.0142 - mean_absolute_error: 0.0946 - val_loss: 0.0124 - val_mean_absolute_error: 0.0906
# Epoch 498/500
# 600/600 [==============================] - 0s 27us/sample - loss: 0.0140 - mean_absolute_error: 0.0941 - val_loss: 0.0128 - val_mean_absolute_error: 0.0914
# Epoch 499/500
# 600/600 [==============================] - 0s 23us/sample - loss: 0.0139 - mean_absolute_error: 0.0938 - val_loss: 0.0125 - val_mean_absolute_error: 0.0907
# Epoch 500/500
# 600/600 [==============================] - 0s 27us/sample - loss: 0.0143 - mean_absolute_error: 0.0943 - val_loss: 0.0130 - val_mean_absolute_error: 0.0919

# %% [markdown]
# ### 3. Plot Metrics
# Each training epoch, the model prints out its loss and mean absolute error for training and validation. You can read this in the output above (note that your exact numbers may differ):
#
# ```
# Epoch 500/500
# 600/600 [==============================] - 0s 51us/sample - loss: 0.0118 - mae: 0.0873 - val_loss: 0.0105 - val_mae: 0.0832
# ```
#
# You can see that we've already got a huge improvement - validation loss has dropped from 0.15 to 0.01, and validation MAE has dropped from 0.33 to 0.08.
#
# The following cell will print the same graphs we used to evaluate our original model, but showing our new training history:

# %%
# Draw a graph of the loss, which is the distance between
# the predicted and actual values during training and validation.
loss = history_2.history['loss']
val_loss = history_2.history['val_loss']

epochs = range(1, len(loss) + 1)

# Exclude the first few epochs so the graph is easier to read
SKIP = 100

plt.figure(figsize=(10, 4))
plt.subplot(1, 2, 1)

plt.plot(epochs[SKIP:], loss[SKIP:], 'g.', label='Training loss')
plt.plot(epochs[SKIP:], val_loss[SKIP:], 'b.', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.subplot(1, 2, 2)

# Draw a graph of mean absolute error, which is another way of
# measuring the amount of error in the prediction.
mae = history_2.history['mean_absolute_error']
val_mae = history_2.history['val_mean_absolute_error']

plt.plot(epochs[SKIP:], mae[SKIP:], 'g.', label='Training MAE')
plt.plot(epochs[SKIP:], val_mae[SKIP:], 'b.', label='Validation MAE')
plt.title('Training and validation mean absolute error')
plt.xlabel('Epochs')
plt.ylabel('MAE')
plt.legend()

plt.tight_layout()

# %% [markdown]
# Great results! From these graphs, we can see several exciting things:
#
# *   The overall loss and MAE are much better than our previous network
# *   Metrics are better for validation than training, which means the network is not overfitting
#
# The reason the metrics for validation are better than those for training is that validation metrics are calculated at the end of each epoch, while training metrics are calculated throughout the epoch, so validation happens on a model that has been trained slightly longer.
#
# This all means our network seems to be performing well! To confirm, let's check its predictions against the test dataset we set aside earlier:

# %%
# Calculate and print the loss on our test dataset
loss = model_2.evaluate(x_test, y_test)

# Make predictions based on our test dataset
predictions = model_2.predict(x_test)

# Graph the predictions against the actual values
plt.clf()
plt.title('Comparison of predictions and actual values')
plt.plot(x_test, y_test, 'b.', label='Actual')
plt.plot(x_test, predictions, 'r.', label='Predicted')
plt.legend()
plt.show()
# Out:
# 200/200 [==============================] - 0s 24us/sample - loss: 0.0135 - mean_absolute_error: 0.0941

# %% [markdown]
# Much better! The evaluation metrics we printed show that the model has a low loss and MAE on the test data, and the predictions line up visually with our data fairly well.
#
# The model isn't perfect; its predictions don't form a smooth sine curve. For instance, the line is almost straight when `x` is between 4.2 and 5.2. If we wanted to go further, we could try further increasing the capacity of the model, perhaps using some techniques to defend from overfitting.
#
# However, an important part of machine learning is knowing when to quit, and this model is good enough for our use case - which is to make some LEDs blink in a pleasing pattern.
#
# ## Generate a TensorFlow Lite Model

# %% [markdown]
# ### 1. Generate Models with or without Quantization
# We now have an acceptably accurate model. We'll use the [TensorFlow Lite Converter](https://www.tensorflow.org/lite/convert) to convert the model into a special, space-efficient format for use on memory-constrained devices.
#
# Since this model is going to be deployed on a microcontroller, we want it to be as tiny as possible! One technique for reducing the size of models is called [quantization](https://www.tensorflow.org/lite/performance/post_training_quantization) while converting the model. It reduces the precision of the model's weights, and possibly the activations (output of each layer) as well, which saves memory, often without much impact on accuracy. Quantized models also run faster, since the calculations required are simpler.
#
# *Note: Currently, TFLite Converter produces TFlite models with float interfaces (input and output ops are always float). This is a blocker for users who require TFlite models with pure int8 or uint8 inputs/outputs. Refer to https://github.com/tensorflow/tensorflow/issues/38285*
#
# In the following cell, we'll convert the model twice: once with quantization, once without.

# %%
# Convert the model to the TensorFlow Lite format without quantization
converter = tf.lite.TFLiteConverter.from_keras_model(model_2)
model_no_quant_tflite = converter.convert()

# # Save the model to disk
open(MODEL_NO_QUANT_TFLITE, "wb").write(model_no_quant_tflite)

# Convert the model to the TensorFlow Lite format with quantization
def representative_dataset():
  for i in range(500):
    yield([x_train[i].reshape(1, 1)])
# Set the optimization flag.
converter.optimizations = [tf.lite.Optimize.DEFAULT]
# Enforce full-int8 quantization (except inputs/outputs which are always float)
converter.target_spec.supported_ops = [tf.lite.OpsSet.TFLITE_BUILTINS_INT8]
# Provide a representative dataset to ensure we quantize correctly.
converter.representative_dataset = representative_dataset
model_tflite = converter.convert()

# Save the model to disk
open(MODEL_TFLITE, "wb").write(model_tflite)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-28-758ebb82bcc2> in <module>
#       1 # Convert the model to the TensorFlow Lite format without quantization
# ----> 2 converter = tf.lite.TFLiteConverter.from_keras_model(model_2)
#       3 model_no_quant_tflite = converter.convert()
#       4
#       5 # # Save the model to disk
#
# AttributeError: type object 'TFLiteConverter' has no attribute 'from_keras_model'

# %% [markdown]
# ### 2. Compare Model Sizes

# %%
import os
model_no_quant_size = os.path.getsize(MODEL_NO_QUANT_TFLITE)
print("Model is %d bytes" % model_no_quant_size)
model_size = os.path.getsize(MODEL_TFLITE)
print("Quantized model is %d bytes" % model_size)
difference = model_no_quant_size - model_size
print("Difference is %d bytes" % difference)
# Out:
# Model is 2736 bytes
# Quantized model is 2512 bytes
# Difference is 224 bytes

# %% [markdown]
# Our quantized model is only 224 bytes smaller than the original version, which only a tiny reduction in size! At around 2.5 kilobytes, this model is already so small that the weights make up only a small fraction of the overall size, meaning quantization has little effect.
#
# More complex models have many more weights, meaning the space saving from quantization will be much higher, approaching 4x for most sophisticated models.
#
# Regardless, our quantized model will take less time to execute than the original version, which is important on a tiny microcontroller!

# %% [markdown]
# ### 3. Test the Models
#
# To prove these models are still accurate after conversion and quantization, we'll use both of them to make predictions and compare these against our test results:

# %%
# Instantiate an interpreter for each model
model_no_quant = tf.lite.Interpreter(MODEL_NO_QUANT_TFLITE)
model = tf.lite.Interpreter(MODEL_TFLITE)

# Allocate memory for each model
model_no_quant.allocate_tensors()
model.allocate_tensors()

# Get the input and output tensors so we can feed in values and get the results
model_no_quant_input = model_no_quant.tensor(model_no_quant.get_input_details()[0]["index"])
model_no_quant_output = model_no_quant.tensor(model_no_quant.get_output_details()[0]["index"])
model_input = model.tensor(model.get_input_details()[0]["index"])
model_output = model.tensor(model.get_output_details()[0]["index"])

# Create arrays to store the results
model_no_quant_predictions = np.empty(x_test.size)
model_predictions = np.empty(x_test.size)

# Run each model's interpreter for each value and store the results in arrays
for i in range(x_test.size):
  model_no_quant_input().fill(x_test[i])
  model_no_quant.invoke()
  model_no_quant_predictions[i] = model_no_quant_output()[0]

  model_input().fill(x_test[i])
  model.invoke()
  model_predictions[i] = model_output()[0]

# See how they line up with the data
plt.clf()
plt.title('Comparison of various models against actual values')
plt.plot(x_test, y_test, 'bo', label='Actual values')
plt.plot(x_test, predictions, 'ro', label='Original predictions')
plt.plot(x_test, model_no_quant_predictions, 'bx', label='Lite predictions')
plt.plot(x_test, model_predictions, 'gx', label='Lite quantized predictions')
plt.legend()
plt.show()

# %% [markdown]
# We can see from the graph that the predictions for the original model, the converted model, and the quantized model are all close enough to be indistinguishable. This means that our quantized model is ready to use!

# %% [markdown]
# ## Generate a TensorFlow Lite for Microcontrollers Model
# Convert the TensorFlow Lite quantized model into a C source file that can be loaded by TensorFlow Lite for Microcontrollers.

# %%
# Install xxd if it is not available
# !apt-get update && apt-get -qq install xxd
# Convert to a C source file
# !xxd -i {MODEL_TFLITE} > {MODEL_TFLITE_MICRO}
# Update variable names
REPLACE_TEXT = MODEL_TFLITE.replace('/', '_').replace('.', '_')
# !sed -i 's/'{REPLACE_TEXT}'/g_model/g' {MODEL_TFLITE_MICRO}
# Out:
# Get:1 https://cloud.r-project.org/bin/linux/ubuntu bionic-cran35/ InRelease [3,626 B]
# Ign:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  InRelease
# Hit:3 http://archive.ubuntu.com/ubuntu bionic InRelease
# Get:4 http://security.ubuntu.com/ubuntu bionic-security InRelease [88.7 kB]
# Hit:5 http://ppa.launchpad.net/graphics-drivers/ppa/ubuntu bionic InRelease
# Ign:6 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  InRelease
# Hit:7 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  Release
# Hit:8 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  Release
# Get:9 http://archive.ubuntu.com/ubuntu bionic-updates InRelease [88.7 kB]
# Get:10 http://ppa.launchpad.net/marutter/c2d4u3.5/ubuntu bionic InRelease [15.4 kB]
# Get:11 http://archive.ubuntu.com/ubuntu bionic-backports InRelease [74.6 kB]
# Get:14 http://ppa.launchpad.net/marutter/c2d4u3.5/ubuntu bionic/main Sources [1,810 kB]
# Get:15 http://security.ubuntu.com/ubuntu bionic-security/restricted amd64 Packages [38.5 kB]
# Get:16 http://security.ubuntu.com/ubuntu bionic-security/main amd64 Packages [873 kB]
# Get:17 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 Packages [1,368 kB]
# Get:18 http://security.ubuntu.com/ubuntu bionic-security/universe amd64 Packages [835 kB]
# Get:19 http://archive.ubuntu.com/ubuntu bionic-updates/restricted amd64 Packages [57.5 kB]
# Get:20 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 Packages [1,176 kB]
# Get:21 http://ppa.launchpad.net/marutter/c2d4u3.5/ubuntu bionic/main amd64 Packages [873 kB]
# Fetched 7,301 kB in 3s (2,475 kB/s)
# Reading package lists... Done
# Selecting previously unselected package xxd.
# (Reading database ... 144568 files and directories currently installed.)
# Preparing to unpack .../xxd_2%3a8.0.1453-1ubuntu1.3_amd64.deb ...
# Unpacking xxd (2:8.0.1453-1ubuntu1.3) ...
# Setting up xxd (2:8.0.1453-1ubuntu1.3) ...
# Processing triggers for man-db (2.8.3-2ubuntu0.1) ...

# %% [markdown]
# ## Deploy to a Microcontroller
#
# Follow the instructions in the [hello_world](https://github.com/tensorflow/tensorflow/tree/master/tensorflow/lite/micro/examples/hello_world) README.md for [TensorFlow Lite for MicroControllers](https://www.tensorflow.org/lite/microcontrollers/overview) to deploy this model on a specific microcontroller.
#
# **Reference Model:** If you have not modified this notebook, you can follow the instructions as is, to deploy the model. Refer to the [`hello_world/train/models`](https://github.com/tensorflow/tensorflow/blob/master/tensorflow/lite/micro/examples/hello_world/train/models) directory to access the models generated in this notebook.
#
# **New Model:** If you have generated a new model, then update the values assigned to the variables defined in [`hello_world/model.cc`](https://github.com/tensorflow/tensorflow/blob/master/tensorflow/lite/micro/examples/hello_world/model.cc) with values displayed after running the following cell.

# %%
# Print the C source file
# !cat {MODEL_TFLITE_MICRO}
# Out:
# unsigned char g_model[] = {
#   0x1c, 0x00, 0x00, 0x00, 0x54, 0x46, 0x4c, 0x33, 0x00, 0x00, 0x12, 0x00,
#   0x1c, 0x00, 0x04, 0x00, 0x08, 0x00, 0x0c, 0x00, 0x10, 0x00, 0x14, 0x00,
#   0x00, 0x00, 0x18, 0x00, 0x12, 0x00, 0x00, 0x00, 0x03, 0x00, 0x00, 0x00,
#   0x60, 0x09, 0x00, 0x00, 0xa8, 0x02, 0x00, 0x00, 0x90, 0x02, 0x00, 0x00,
#   0x3c, 0x00, 0x00, 0x00, 0x04, 0x00, 0x00, 0x00, 0x01, 0x00, 0x00, 0x00,
#   0x0c, 0x00, 0x00, 0x00, 0x08, 0x00, 0x0c, 0x00, 0x04, 0x00, 0x08, 0x00,
#   0x08, 0x00, 0x00, 0x00, 0x08, 0x00, 0x00, 0x00, 0x0b, 0x00, 0x00, 0x00,
#   0x13, 0x00, 0x00, 0x00, 0x6d, 0x69, 0x6e, 0x5f, 0x72, 0x75, 0x6e, 0x74,
#   0x69, 0x6d, 0x65, 0x5f, 0x76, 0x65, 0x72, 0x73, 0x69, 0x6f, 0x6e, 0x00,
#   0x0c, 0x00, 0x00, 0x00, 0x48, 0x02, 0x00, 0x00, 0x34, 0x02, 0x00, 0x00,
#   0x0c, 0x02, 0x00, 0x00, 0xfc, 0x00, 0x00, 0x00, 0xac, 0x00, 0x00, 0x00,
#   0x8c, 0x00, 0x00, 0x00, 0x3c, 0x00, 0x00, 0x00, 0x34, 0x00, 0x00, 0x00,
#   0x2c, 0x00, 0x00, 0x00, 0x24, 0x00, 0x00, 0x00, 0x1c, 0x00, 0x00, 0x00,
#   0x04, 0x00, 0x00, 0x00, 0xfe, 0xfd, 0xff, 0xff, 0x04, 0x00, 0x00, 0x00,
#   0x05, 0x00, 0x00, 0x00, 0x31, 0x2e, 0x35, 0x2e, 0x30, 0x00, 0x00, 0x00,
#   0x7c, 0xfd, 0xff, 0xff, 0x80, 0xfd, 0xff, 0xff, 0x84, 0xfd, 0xff, 0xff,
#   0x88, 0xfd, 0xff, 0xff, 0x22, 0xfe, 0xff, 0xff, 0x04, 0x00, 0x00, 0x00,
#   0x40, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0xfc, 0x04, 0x00, 0x00,
#   0x9f, 0x0a, 0x00, 0x00, 0x65, 0x06, 0x00, 0x00, 0x3d, 0xf8, 0xff, 0xff,
#   0x00, 0x00, 0x00, 0x00, 0xeb, 0x0a, 0x00, 0x00, 0x2f, 0xf8, 0xff, 0xff,
#   0xe8, 0x04, 0x00, 0x00, 0x21, 0x0a, 0x00, 0x00, 0x46, 0xfe, 0xff, 0xff,
#   0xc8, 0x04, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0xa3, 0xf7, 0xff, 0xff,
#   0x28, 0xf9, 0xff, 0xff, 0x9a, 0x05, 0x00, 0x00, 0x6e, 0xfe, 0xff, 0xff,
#   0x04, 0x00, 0x00, 0x00, 0x10, 0x00, 0x00, 0x00, 0x73, 0x1c, 0x11, 0xe1,
#   0x0c, 0x81, 0xa5, 0x43, 0xfe, 0xd5, 0xd5, 0xb2, 0x60, 0x77, 0x19, 0xdf,
#   0x8a, 0xfe, 0xff, 0xff, 0x04, 0x00, 0x00, 0x00, 0x40, 0x00, 0x00, 0x00,
#   0x01, 0x00, 0x00, 0x00, 0x51, 0x0b, 0x00, 0x00, 0x47, 0xf6, 0xff, 0xff,
#   0x00, 0x00, 0x00, 0x00, 0x1c, 0x0c, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00,
#   0x00, 0x00, 0x00, 0x00, 0x9b, 0x05, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00,
#   0x00, 0x00, 0x00, 0x00, 0xe7, 0x20, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00,
#   0x92, 0x07, 0x00, 0x00, 0xf4, 0xf4, 0xff, 0xff, 0x55, 0xf0, 0xff, 0xff,
#   0x00, 0x00, 0x00, 0x00, 0xd6, 0xfe, 0xff, 0xff, 0x04, 0x00, 0x00, 0x00,
#   0x00, 0x01, 0x00, 0x00, 0xee, 0xfc, 0x00, 0xec, 0x05, 0x16, 0xef, 0xec,
#   0xe6, 0xf8, 0x03, 0x01, 0x00, 0xfa, 0xf8, 0xf5, 0xda, 0xeb, 0x27, 0x14,
#   0xef, 0xde, 0xe2, 0xda, 0xf0, 0xdf, 0x32, 0x06, 0x01, 0xe6, 0xee, 0xf9,
#   0x00, 0x16, 0x07, 0xe0, 0xfe, 0xff, 0xe9, 0x05, 0xe7, 0xef, 0x81, 0x1b,
#   0x18, 0xea, 0xca, 0x01, 0x0f, 0x00, 0xdb, 0xf7, 0x0e, 0xec, 0x12, 0x1e,
#   0x04, 0x13, 0xb2, 0xe7, 0xfd, 0x06, 0xbb, 0xe0, 0x0c, 0xec, 0xf0, 0xdf,
#   0xeb, 0xf7, 0x05, 0x26, 0x19, 0xe4, 0x70, 0x1a, 0xea, 0x1e, 0x34, 0xdf,
#   0x19, 0xf3, 0xf1, 0x19, 0x0e, 0x03, 0x1b, 0xe1, 0xde, 0x13, 0xf6, 0x19,
#   0xff, 0xf6, 0x1a, 0x17, 0xf1, 0x1c, 0xdb, 0x1a, 0x1a, 0x20, 0xe6, 0x19,
#   0xf5, 0xff, 0x97, 0x0b, 0x00, 0x00, 0xce, 0xdf, 0x0d, 0xf7, 0x15, 0xe4,
#   0xed, 0xfc, 0x0d, 0xe9, 0xfb, 0xec, 0x5c, 0xfc, 0x1d, 0x02, 0x58, 0xe3,
#   0xe0, 0xf4, 0x15, 0xec, 0xf9, 0x00, 0x13, 0x05, 0xec, 0x0c, 0x1c, 0x14,
#   0x0c, 0xe9, 0x0a, 0xf4, 0x18, 0x00, 0xd7, 0x05, 0x27, 0x02, 0x15, 0xea,
#   0xea, 0x02, 0x9b, 0x00, 0x0c, 0xfa, 0xe9, 0xea, 0xfe, 0x01, 0x14, 0xfd,
#   0x0b, 0x02, 0xf0, 0xef, 0x06, 0xee, 0x01, 0x0d, 0x06, 0xe7, 0xf7, 0x11,
#   0xf5, 0x0a, 0xf9, 0xf1, 0x23, 0xff, 0x0d, 0xf2, 0xec, 0x11, 0x26, 0x1d,
#   0xf2, 0xea, 0x28, 0x18, 0xe0, 0xfb, 0xf3, 0xf4, 0x05, 0x1c, 0x1d, 0xfb,
#   0xfd, 0x1e, 0xfc, 0x11, 0xe8, 0x06, 0x09, 0x03, 0x12, 0xf2, 0x35, 0xfb,
#   0xdd, 0x1b, 0xf9, 0xef, 0xf3, 0xe7, 0x6f, 0x0c, 0x1d, 0x00, 0x43, 0xfd,
#   0x0d, 0xf1, 0x0a, 0x19, 0x1a, 0xfa, 0xe0, 0x18, 0x1e, 0x13, 0x37, 0x1c,
#   0x12, 0xec, 0x3a, 0x0c, 0xb6, 0xcb, 0xe6, 0x13, 0xf7, 0xeb, 0xf1, 0x05,
#   0x1b, 0xfa, 0x19, 0xe5, 0xec, 0xcf, 0x0c, 0xf4, 0xe2, 0xff, 0xff, 0xff,
#   0x04, 0x00, 0x00, 0x00, 0x10, 0x00, 0x00, 0x00, 0x21, 0xa2, 0x8c, 0xc9,
#   0x5f, 0x1d, 0xce, 0x41, 0x9f, 0xcd, 0x20, 0xb1, 0xdf, 0x53, 0x2f, 0x81,
#   0x00, 0x00, 0x06, 0x00, 0x08, 0x00, 0x04, 0x00, 0x06, 0x00, 0x00, 0x00,
#   0x04, 0x00, 0x00, 0x00, 0x04, 0x00, 0x00, 0x00, 0xe2, 0xee, 0xff, 0xff,
#   0x80, 0xff, 0xff, 0xff, 0x0f, 0x00, 0x00, 0x00, 0x54, 0x4f, 0x43, 0x4f,
#   0x20, 0x43, 0x6f, 0x6e, 0x76, 0x65, 0x72, 0x74, 0x65, 0x64, 0x2e, 0x00,
#   0x01, 0x00, 0x00, 0x00, 0x04, 0x00, 0x00, 0x00, 0xbc, 0xf9, 0xff, 0xff,
#   0x48, 0x01, 0x00, 0x00, 0x3c, 0x01, 0x00, 0x00, 0x30, 0x01, 0x00, 0x00,
#   0x04, 0x00, 0x00, 0x00, 0x05, 0x00, 0x00, 0x00, 0x04, 0x01, 0x00, 0x00,
#   0xb8, 0x00, 0x00, 0x00, 0x70, 0x00, 0x00, 0x00, 0x28, 0x00, 0x00, 0x00,
#   0x04, 0x00, 0x00, 0x00, 0x1a, 0xff, 0xff, 0xff, 0x02, 0x00, 0x00, 0x00,
#   0x10, 0x00, 0x00, 0x00, 0x04, 0x00, 0x00, 0x00, 0x01, 0x00, 0x00, 0x00,
#   0x0b, 0x00, 0x00, 0x00, 0x01, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00,
#   0xca, 0xff, 0xff, 0xff, 0x00, 0x00, 0x00, 0x08, 0x1c, 0x00, 0x00, 0x00,
#   0x10, 0x00, 0x00, 0x00, 0x08, 0x00, 0x00, 0x00, 0x04, 0x00, 0x04, 0x00,
#   0x04, 0x00, 0x00, 0x00, 0x01, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00,
#   0x03, 0x00, 0x00, 0x00, 0x07, 0x00, 0x00, 0x00, 0x08, 0x00, 0x00, 0x00,
#   0x09, 0x00, 0x00, 0x00, 0x00, 0x00, 0x0e, 0x00, 0x14, 0x00, 0x00, 0x00,
#   0x08, 0x00, 0x0c, 0x00, 0x07, 0x00, 0x10, 0x00, 0x0e, 0x00, 0x00, 0x00,
#   0x00, 0x00, 0x00, 0x08, 0x1c, 0x00, 0x00, 0x00, 0x10, 0x00, 0x00, 0x00,
#   0x04, 0x00, 0x00, 0x00, 0xba, 0xff, 0xff, 0xff, 0x00, 0x00, 0x00, 0x01,
#   0x01, 0x00, 0x00, 0x00, 0x07, 0x00, 0x00, 0x00, 0x03, 0x00, 0x00, 0x00,
#   0x04, 0x00, 0x00, 0x00, 0x05, 0x00, 0x00, 0x00, 0x06, 0x00, 0x00, 0x00,
#   0x00, 0x00, 0x0e, 0x00, 0x16, 0x00, 0x00, 0x00, 0x08, 0x00, 0x0c, 0x00,
#   0x07, 0x00, 0x10, 0x00, 0x0e, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x08,
#   0x24, 0x00, 0x00, 0x00, 0x18, 0x00, 0x00, 0x00, 0x0c, 0x00, 0x00, 0x00,
#   0x00, 0x00, 0x06, 0x00, 0x08, 0x00, 0x07, 0x00, 0x06, 0x00, 0x00, 0x00,
#   0x00, 0x00, 0x00, 0x01, 0x01, 0x00, 0x00, 0x00, 0x04, 0x00, 0x00, 0x00,
#   0x03, 0x00, 0x00, 0x00, 0x01, 0x00, 0x00, 0x00, 0x02, 0x00, 0x00, 0x00,
#   0x03, 0x00, 0x00, 0x00, 0x00, 0x00, 0x0a, 0x00, 0x10, 0x00, 0x04, 0x00,
#   0x08, 0x00, 0x0c, 0x00, 0x0a, 0x00, 0x00, 0x00, 0x01, 0x00, 0x00, 0x00,
#   0x10, 0x00, 0x00, 0x00, 0x04, 0x00, 0x00, 0x00, 0x01, 0x00, 0x00, 0x00,
#   0x01, 0x00, 0x00, 0x00, 0x01, 0x00, 0x00, 0x00, 0x0a, 0x00, 0x00, 0x00,
#   0x01, 0x00, 0x00, 0x00, 0x0b, 0x00, 0x00, 0x00, 0x01, 0x00, 0x00, 0x00,
#   0x0a, 0x00, 0x00, 0x00, 0x0c, 0x00, 0x00, 0x00, 0xdc, 0x04, 0x00, 0x00,
#   0x54, 0x04, 0x00, 0x00, 0xc4, 0x03, 0x00, 0x00, 0x54, 0x03, 0x00, 0x00,
#   0xd0, 0x02, 0x00, 0x00, 0x4c, 0x02, 0x00, 0x00, 0xe0, 0x01, 0x00, 0x00,
#   0x5c, 0x01, 0x00, 0x00, 0xd8, 0x00, 0x00, 0x00, 0x6c, 0x00, 0x00, 0x00,
#   0x3c, 0x00, 0x00, 0x00, 0x04, 0x00, 0x00, 0x00, 0xd8, 0xff, 0xff, 0xff,
#   0x18, 0x00, 0x00, 0x00, 0x04, 0x00, 0x00, 0x00, 0x08, 0x00, 0x00, 0x00,
#   0x49, 0x64, 0x65, 0x6e, 0x74, 0x69, 0x74, 0x79, 0x00, 0x00, 0x00, 0x00,
#   0x02, 0x00, 0x00, 0x00, 0x01, 0x00, 0x00, 0x00, 0x01, 0x00, 0x00, 0x00,
#   0x0c, 0x00, 0x0c, 0x00, 0x04, 0x00, 0x00, 0x00, 0x00, 0x00, 0x08, 0x00,
#   0x0c, 0x00, 0x00, 0x00, 0x1c, 0x00, 0x00, 0x00, 0x04, 0x00, 0x00, 0x00,
#   0x0d, 0x00, 0x00, 0x00, 0x64, 0x65, 0x6e, 0x73, 0x65, 0x5f, 0x32, 0x5f,
#   0x69, 0x6e, 0x70, 0x75, 0x74, 0x00, 0x00, 0x00, 0x02, 0x00, 0x00, 0x00,
#   0x01, 0x00, 0x00, 0x00, 0x01, 0x00, 0x00, 0x00, 0xc2, 0xfb, 0xff, 0xff,
#   0x00, 0x00, 0x00, 0x02, 0x58, 0x00, 0x00, 0x00, 0x01, 0x00, 0x00, 0x00,
#   0x28, 0x00, 0x00, 0x00, 0x04, 0x00, 0x00, 0x00, 0xc4, 0xfc, 0xff, 0xff,
#   0x14, 0x00, 0x00, 0x00, 0x04, 0x00, 0x00, 0x00, 0x01, 0x00, 0x00, 0x00,
#   0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x01, 0x00, 0x00, 0x00,
#   0xba, 0x2b, 0x4f, 0x38, 0x20, 0x00, 0x00, 0x00, 0x73, 0x65, 0x71, 0x75,
#   0x65, 0x6e, 0x74, 0x69, 0x61, 0x6c, 0x5f, 0x31, 0x2f, 0x64, 0x65, 0x6e,
#   0x73, 0x65, 0x5f, 0x34, 0x2f, 0x4d, 0x61, 0x74, 0x4d, 0x75, 0x6c, 0x5f,
#   0x62, 0x69, 0x61, 0x73, 0x00, 0x00, 0x00, 0x00, 0x01, 0x00, 0x00, 0x00,
#   0x01, 0x00, 0x00, 0x00, 0x2a, 0xfc, 0xff, 0xff, 0x00, 0x00, 0x00, 0x09,
#   0x6c, 0x00, 0x00, 0x00, 0x02, 0x00, 0x00, 0x00, 0x28, 0x00, 0x00, 0x00,
#   0x04, 0x00, 0x00, 0x00, 0x2c, 0xfd, 0xff, 0xff, 0x14, 0x00, 0x00, 0x00,
#   0x04, 0x00, 0x00, 0x00, 0x01, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00,
#   0x00, 0x00, 0x00, 0x00, 0x01, 0x00, 0x00, 0x00, 0xb9, 0x36, 0x0b, 0x3c,
#   0x34, 0x00, 0x00, 0x00, 0x73, 0x65, 0x71, 0x75, 0x65, 0x6e, 0x74, 0x69,
#   0x61, 0x6c, 0x5f, 0x31, 0x2f, 0x64, 0x65, 0x6e, 0x73, 0x65, 0x5f, 0x34,
#   0x2f, 0x4d, 0x61, 0x74, 0x4d, 0x75, 0x6c, 0x2f, 0x52, 0x65, 0x61, 0x64,
#   0x56, 0x61, 0x72, 0x69, 0x61, 0x62, 0x6c, 0x65, 0x4f, 0x70, 0x2f, 0x74,
#   0x72, 0x61, 0x6e, 0x73, 0x70, 0x6f, 0x73, 0x65, 0x00, 0x00, 0x00, 0x00,
#   0x02, 0x00, 0x00, 0x00, 0x01, 0x00, 0x00, 0x00, 0x10, 0x00, 0x00, 0x00,
#   0xaa, 0xfc, 0xff, 0xff, 0x00, 0x00, 0x00, 0x09, 0x6c, 0x00, 0x00, 0x00,
#   0x09, 0x00, 0x00, 0x00, 0x44, 0x00, 0x00, 0x00, 0x04, 0x00, 0x00, 0x00,
#   0x9c, 0xfc, 0xff, 0xff, 0x30, 0x00, 0x00, 0x00, 0x24, 0x00, 0x00, 0x00,
#   0x18, 0x00, 0x00, 0x00, 0x04, 0x00, 0x00, 0x00, 0x01, 0x00, 0x00, 0x00,
#   0x80, 0xff, 0xff, 0xff, 0xff, 0xff, 0xff, 0xff, 0x00, 0x00, 0x00, 0x00,
#   0x01, 0x00, 0x00, 0x00, 0xaa, 0x7b, 0xbe, 0x3b, 0x01, 0x00, 0x00, 0x00,
#   0x2e, 0xbd, 0xbd, 0x3f, 0x01, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00,
#   0x19, 0x00, 0x00, 0x00, 0x73, 0x65, 0x71, 0x75, 0x65, 0x6e, 0x74, 0x69,
#   0x61, 0x6c, 0x5f, 0x31, 0x2f, 0x64, 0x65, 0x6e, 0x73, 0x65, 0x5f, 0x33,
#   0x2f, 0x52, 0x65, 0x6c, 0x75, 0x00, 0x00, 0x00, 0x02, 0x00, 0x00, 0x00,
#   0x01, 0x00, 0x00, 0x00, 0x10, 0x00, 0x00, 0x00, 0x2a, 0xfd, 0xff, 0xff,
#   0x00, 0x00, 0x00, 0x02, 0x58, 0x00, 0x00, 0x00, 0x06, 0x00, 0x00, 0x00,
#   0x28, 0x00, 0x00, 0x00, 0x04, 0x00, 0x00, 0x00, 0x2c, 0xfe, 0xff, 0xff,
#   0x14, 0x00, 0x00, 0x00, 0x04, 0x00, 0x00, 0x00, 0x01, 0x00, 0x00, 0x00,
#   0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x01, 0x00, 0x00, 0x00,
#   0xe3, 0x04, 0x20, 0x39, 0x20, 0x00, 0x00, 0x00, 0x73, 0x65, 0x71, 0x75,
#   0x65, 0x6e, 0x74, 0x69, 0x61, 0x6c, 0x5f, 0x31, 0x2f, 0x64, 0x65, 0x6e,
#   0x73, 0x65, 0x5f, 0x33, 0x2f, 0x4d, 0x61, 0x74, 0x4d, 0x75, 0x6c, 0x5f,
#   0x62, 0x69, 0x61, 0x73, 0x00, 0x00, 0x00, 0x00, 0x01, 0x00, 0x00, 0x00,
#   0x10, 0x00, 0x00, 0x00, 0x92, 0xfd, 0xff, 0xff, 0x00, 0x00, 0x00, 0x09,
#   0x6c, 0x00, 0x00, 0x00, 0x03, 0x00, 0x00, 0x00, 0x28, 0x00, 0x00, 0x00,
#   0x04, 0x00, 0x00, 0x00, 0x94, 0xfe, 0xff, 0xff, 0x14, 0x00, 0x00, 0x00,
#   0x04, 0x00, 0x00, 0x00, 0x01, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00,
#   0x00, 0x00, 0x00, 0x00, 0x01, 0x00, 0x00, 0x00, 0xe8, 0x76, 0x51, 0x3c,
#   0x34, 0x00, 0x00, 0x00, 0x73, 0x65, 0x71, 0x75, 0x65, 0x6e, 0x74, 0x69,
#   0x61, 0x6c, 0x5f, 0x31, 0x2f, 0x64, 0x65, 0x6e, 0x73, 0x65, 0x5f, 0x33,
#   0x2f, 0x4d, 0x61, 0x74, 0x4d, 0x75, 0x6c, 0x2f, 0x52, 0x65, 0x61, 0x64,
#   0x56, 0x61, 0x72, 0x69, 0x61, 0x62, 0x6c, 0x65, 0x4f, 0x70, 0x2f, 0x74,
#   0x72, 0x61, 0x6e, 0x73, 0x70, 0x6f, 0x73, 0x65, 0x00, 0x00, 0x00, 0x00,
#   0x02, 0x00, 0x00, 0x00, 0x10, 0x00, 0x00, 0x00, 0x10, 0x00, 0x00, 0x00,
#   0x12, 0xfe, 0xff, 0xff, 0x00, 0x00, 0x00, 0x09, 0x6c, 0x00, 0x00, 0x00,
#   0x07, 0x00, 0x00, 0x00, 0x44, 0x00, 0x00, 0x00, 0x04, 0x00, 0x00, 0x00,
#   0x04, 0xfe, 0xff, 0xff, 0x30, 0x00, 0x00, 0x00, 0x24, 0x00, 0x00, 0x00,
#   0x18, 0x00, 0x00, 0x00, 0x04, 0x00, 0x00, 0x00, 0x01, 0x00, 0x00, 0x00,
#   0x80, 0xff, 0xff, 0xff, 0xff, 0xff, 0xff, 0xff, 0x00, 0x00, 0x00, 0x00,
#   0x01, 0x00, 0x00, 0x00, 0xd2, 0x91, 0x43, 0x3c, 0x01, 0x00, 0x00, 0x00,
#   0x40, 0xce, 0x42, 0x40, 0x01, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00,
#   0x19, 0x00, 0x00, 0x00, 0x73, 0x65, 0x71, 0x75, 0x65, 0x6e, 0x74, 0x69,
#   0x61, 0x6c, 0x5f, 0x31, 0x2f, 0x64, 0x65, 0x6e, 0x73, 0x65, 0x5f, 0x32,
#   0x2f, 0x52, 0x65, 0x6c, 0x75, 0x00, 0x00, 0x00, 0x02, 0x00, 0x00, 0x00,
#   0x01, 0x00, 0x00, 0x00, 0x10, 0x00, 0x00, 0x00, 0x92, 0xfe, 0xff, 0xff,
#   0x00, 0x00, 0x00, 0x02, 0x5c, 0x00, 0x00, 0x00, 0x04, 0x00, 0x00, 0x00,
#   0x2c, 0x00, 0x00, 0x00, 0x04, 0x00, 0x00, 0x00, 0x94, 0xff, 0xff, 0xff,
#   0x18, 0x00, 0x00, 0x00, 0x04, 0x00, 0x00, 0x00, 0x01, 0x00, 0x00, 0x00,
#   0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00,
#   0x01, 0x00, 0x00, 0x00, 0x28, 0xb3, 0xd9, 0x38, 0x20, 0x00, 0x00, 0x00,
#   0x73, 0x65, 0x71, 0x75, 0x65, 0x6e, 0x74, 0x69, 0x61, 0x6c, 0x5f, 0x31,
#   0x2f, 0x64, 0x65, 0x6e, 0x73, 0x65, 0x5f, 0x32, 0x2f, 0x4d, 0x61, 0x74,
#   0x4d, 0x75, 0x6c, 0x5f, 0x62, 0x69, 0x61, 0x73, 0x00, 0x00, 0x00, 0x00,
#   0x01, 0x00, 0x00, 0x00, 0x10, 0x00, 0x00, 0x00, 0xfe, 0xfe, 0xff, 0xff,
#   0x00, 0x00, 0x00, 0x09, 0x78, 0x00, 0x00, 0x00, 0x05, 0x00, 0x00, 0x00,
#   0x34, 0x00, 0x00, 0x00, 0x10, 0x00, 0x00, 0x00, 0x0c, 0x00, 0x0c, 0x00,
#   0x00, 0x00, 0x00, 0x00, 0x04, 0x00, 0x08, 0x00, 0x0c, 0x00, 0x00, 0x00,
#   0x14, 0x00, 0x00, 0x00, 0x04, 0x00, 0x00, 0x00, 0x01, 0x00, 0x00, 0x00,
#   0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x01, 0x00, 0x00, 0x00,
#   0xd5, 0x6b, 0x8a, 0x3b, 0x34, 0x00, 0x00, 0x00, 0x73, 0x65, 0x71, 0x75,
#   0x65, 0x6e, 0x74, 0x69, 0x61, 0x6c, 0x5f, 0x31, 0x2f, 0x64, 0x65, 0x6e,
#   0x73, 0x65, 0x5f, 0x32, 0x2f, 0x4d, 0x61, 0x74, 0x4d, 0x75, 0x6c, 0x2f,
#   0x52, 0x65, 0x61, 0x64, 0x56, 0x61, 0x72, 0x69, 0x61, 0x62, 0x6c, 0x65,
#   0x4f, 0x70, 0x2f, 0x74, 0x72, 0x61, 0x6e, 0x73, 0x70, 0x6f, 0x73, 0x65,
#   0x00, 0x00, 0x00, 0x00, 0x02, 0x00, 0x00, 0x00, 0x10, 0x00, 0x00, 0x00,
#   0x01, 0x00, 0x00, 0x00, 0x8a, 0xff, 0xff, 0xff, 0x00, 0x00, 0x00, 0x09,
#   0x60, 0x00, 0x00, 0x00, 0x08, 0x00, 0x00, 0x00, 0x40, 0x00, 0x00, 0x00,
#   0x04, 0x00, 0x00, 0x00, 0x7c, 0xff, 0xff, 0xff, 0x2c, 0x00, 0x00, 0x00,
#   0x20, 0x00, 0x00, 0x00, 0x14, 0x00, 0x00, 0x00, 0x04, 0x00, 0x00, 0x00,
#   0x01, 0x00, 0x00, 0x00, 0x80, 0xff, 0xff, 0xff, 0xff, 0xff, 0xff, 0xff,
#   0x01, 0x00, 0x00, 0x00, 0x5d, 0x4f, 0xc9, 0x3c, 0x01, 0x00, 0x00, 0x00,
#   0x0e, 0x86, 0xc8, 0x40, 0x01, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00,
#   0x12, 0x00, 0x00, 0x00, 0x64, 0x65, 0x6e, 0x73, 0x65, 0x5f, 0x32, 0x5f,
#   0x69, 0x6e, 0x70, 0x75, 0x74, 0x5f, 0x69, 0x6e, 0x74, 0x38, 0x00, 0x00,
#   0x02, 0x00, 0x00, 0x00, 0x01, 0x00, 0x00, 0x00, 0x01, 0x00, 0x00, 0x00,
#   0x00, 0x00, 0x0e, 0x00, 0x18, 0x00, 0x08, 0x00, 0x07, 0x00, 0x0c, 0x00,
#   0x10, 0x00, 0x14, 0x00, 0x0e, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x09,
#   0x6c, 0x00, 0x00, 0x00, 0x0a, 0x00, 0x00, 0x00, 0x50, 0x00, 0x00, 0x00,
#   0x10, 0x00, 0x00, 0x00, 0x0c, 0x00, 0x14, 0x00, 0x04, 0x00, 0x08, 0x00,
#   0x0c, 0x00, 0x10, 0x00, 0x0c, 0x00, 0x00, 0x00, 0x30, 0x00, 0x00, 0x00,
#   0x24, 0x00, 0x00, 0x00, 0x18, 0x00, 0x00, 0x00, 0x04, 0x00, 0x00, 0x00,
#   0x01, 0x00, 0x00, 0x00, 0x02, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00,
#   0x00, 0x00, 0x00, 0x00, 0x01, 0x00, 0x00, 0x00, 0x1a, 0xde, 0x0a, 0x3c,
#   0x01, 0x00, 0x00, 0x00, 0x66, 0x64, 0x87, 0x3f, 0x01, 0x00, 0x00, 0x00,
#   0x13, 0x42, 0x8d, 0xbf, 0x0d, 0x00, 0x00, 0x00, 0x49, 0x64, 0x65, 0x6e,
#   0x74, 0x69, 0x74, 0x79, 0x5f, 0x69, 0x6e, 0x74, 0x38, 0x00, 0x00, 0x00,
#   0x02, 0x00, 0x00, 0x00, 0x01, 0x00, 0x00, 0x00, 0x01, 0x00, 0x00, 0x00,
#   0x03, 0x00, 0x00, 0x00, 0x3c, 0x00, 0x00, 0x00, 0x28, 0x00, 0x00, 0x00,
#   0x10, 0x00, 0x00, 0x00, 0x00, 0x00, 0x0a, 0x00, 0x0e, 0x00, 0x07, 0x00,
#   0x00, 0x00, 0x08, 0x00, 0x0a, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x06,
#   0x02, 0x00, 0x00, 0x00, 0x00, 0x00, 0x06, 0x00, 0x06, 0x00, 0x05, 0x00,
#   0x06, 0x00, 0x00, 0x00, 0x00, 0x72, 0x0a, 0x00, 0x0c, 0x00, 0x07, 0x00,
#   0x00, 0x00, 0x08, 0x00, 0x0a, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x09,
#   0x04, 0x00, 0x00, 0x00
# };
# unsigned int g_model_len = 2512;
